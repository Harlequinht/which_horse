# %%
import pandas as pd

# %%
# !pwd
# Out:
# /home/tomi/code/Harlequinht/Whose_Horse . csv/Whose Horse . csv

# %%
import os
import glob
import pandas as pd

# %%
os.chdir("/home/tomi/code/Harlequinht/Whose_Horse . csv/Whose Horse . csv")

# %%
# !ls
# Out:
# 01-2019.csv  03-2019.csv  05-2021.csv  07-2021.csv  09-2021.csv  11-2022.csv
# 01-2020.csv  03-2020.csv  05-2022.csv  07-2022.csv  09-2022.csv  12-2019.csv
# 01-2021.csv  03-2021.csv  05-2023.csv  07-2023.csv  09-2023.csv  12-2020.csv
# 01-2022.csv  03-2022.csv  06-2019.csv  08-2019.csv  10-2019.csv  12-2021.csv
# 01-2023.csv  03-2023.csv  06-2020.csv  08-2020.csv  10-2020.csv  12-2022.csv
# 02-2019.csv  04-2019.csv  06-2021.csv  08-2021.csv  10-2021.csv
# 02-2020.csv  04-2021.csv  06-2022.csv  08-2022.csv  10-2022.csv
# 02-2021.csv  04-2022.csv  06-2023.csv  08-2023.csv  11-2019.csv
# 02-2022.csv  04-2023.csv  07-2019.csv  09-2019.csv  11-2020.csv
# 02-2023.csv  05-2019.csv  07-2020.csv  09-2020.csv  11-2021.csv

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#create function to read csv split csv and then concat
# Out:
# /tmp/ipykernel_82597/4261394971.py:2: DtypeWarning: Columns (53,62,71) have mixed types. Specify dtype option on import or set low_memory=False.
#   combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
# /tmp/ipykernel_82597/4261394971.py:2: DtypeWarning: Columns (71,80,98) have mixed types. Specify dtype option on import or set low_memory=False.
#   combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
# /tmp/ipykernel_82597/4261394971.py:2: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
# /tmp/ipykernel_82597/4261394971.py:2: DtypeWarning: Columns (53,62,89) have mixed types. Specify dtype option on import or set low_memory=False.
#   combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
# /tmp/ipykernel_82597/4261394971.py:2: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
# /tmp/ipykernel_82597/4261394971.py:2: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
# /tmp/ipykernel_82597/4261394971.py:2: DtypeWarning: Columns (53,62,71,80,89,98,107,116) have mixed types. Specify dtype option on import or set low_memory=False.
#   combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
# /tmp/ipykernel_82597/4261394971.py:2: DtypeWarning: Columns (62) have mixed types. Specify dtype option on import or set low_memory=False.
#   combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
# /tmp/ipykernel_82597/4261394971.py:2: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
# /tmp/ipykernel_82597/4261394971.py:2: DtypeWarning: Columns (62,80,89,107,116) have mixed types. Specify dtype option on import or set low_memory=False.
#   combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
# /tmp/ipykernel_82597/4261394971.py:2: DtypeWarning: Columns (62,71,80,89,98,107,116) have mixed types. Specify dtype option on import or set low_memory=False.
#   combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
# /tmp/ipykernel_82597/4261394971.py:2: DtypeWarning: Columns (53,62,68,71,77,80,89,98,107,116) have mixed types. Specify dtype option on import or set low_memory=False.
#   combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
# /tmp/ipykernel_82597/4261394971.py:2: DtypeWarning: Columns (20,47,50,53,59,62,68,71,80,89,95,98,107,113,116) have mixed types. Specify dtype option on import or set low_memory=False.
#   combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
# /tmp/ipykernel_82597/4261394971.py:2: DtypeWarning: Columns (53,62,71,80,89) have mixed types. Specify dtype option on import or set low_memory=False.
#   combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
# /tmp/ipykernel_82597/4261394971.py:2: DtypeWarning: Columns (53,62,71,80,89,98,107,116) have mixed types. Specify dtype option on import or set low_memory=False.
#   combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
# /tmp/ipykernel_82597/4261394971.py:2: DtypeWarning: Columns (53) have mixed types. Specify dtype option on import or set low_memory=False.
#   combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])

# %%
all_filenames
# Out:
# ['10-2021.csv',
#  '04-2023.csv',
#  '11-2020.csv',
#  '11-2021.csv',
#  '09-2020.csv',
#  '03-2020.csv',
#  '12-2021.csv',
#  '09-2021.csv',
#  '04-2019.csv',
#  '07-2019.csv',
#  '06-2021.csv',
#  '05-2019.csv',
#  '10-2020.csv',
#  '01-2021.csv',
#  '12-2020.csv',
#  '08-2019.csv',
#  '02-2022.csv',
#  '12-2019.csv',
#  '03-2019.csv',
#  '12-2022.csv',
#  '05-2021.csv',
#  '06-2023.csv',
#  '02-2021.csv',
#  '10-2019.csv',
#  '08-2020.csv',
#  '02-2019.csv',
#  '07-2023.csv',
#  '06-2019.csv',
#  '08-2023.csv',
#  '01-2023.csv',
#  '09-2022.csv',
#  '05-2023.csv',
#  '01-2020.csv',
#  '03-2022.csv',
#  '08-2021.csv',
#  '11-2019.csv',
#  '01-2019.csv',
#  '04-2021.csv',
#  '01-2022.csv',
#  '10-2022.csv',
#  '05-2022.csv',
#  '02-2020.csv',
#  '06-2020.csv',
#  '08-2022.csv',
#  '06-2022.csv',
#  '04-2022.csv',
#  '02-2023.csv',
#  '07-2021.csv',
#  '09-2023.csv',
#  '07-2022.csv',
#  '11-2022.csv',
#  '03-2023.csv',
#  '03-2021.csv',
#  '07-2020.csv',
#  '09-2019.csv']

# %%
combined_csv.shape
# Out:
# (409638, 121)

# %% [markdown]
# # Jump Data

# %%
filter_condition_jump = (combined_csv['race_type'] == 'JUMP') | (combined_csv['race_type'] == 'STEEPLECHASE') | (combined_csv['race_type'] == 'CROSS_COUNTRY')

# %%
data_jump = combined_csv[filter_condition_jump]

# %%
data_jump.race_type.unique()
# Out:
# array(['JUMP', 'STEEPLECHASE', 'CROSS_COUNTRY'], dtype=object)

# %%
data_jump_sort = data_jump.sort_values(by=['meeting_id'], ascending=True)

# %%
data_jump_sort
# Out:
#       meeting_id  meeting_name        date country_code  event_number  \
# 82          3671  MARKET RASEN  2020-07-20          GBR             1
# 107         3671  MARKET RASEN  2020-07-20          GBR             4
# 108         3671  MARKET RASEN  2020-07-20          GBR             4
# 109         3671  MARKET RASEN  2020-07-20          GBR             4
# 110         3671  MARKET RASEN  2020-07-20          GBR             4
# ...          ...           ...         ...          ...           ...
# 7358       37980  MARKET RASEN  2023-09-30          GBR             4
# 7359       37980  MARKET RASEN  2023-09-30          GBR             4
# 7360       37980  MARKET RASEN  2023-09-30          GBR             4
# 7362       37980  MARKET RASEN  2023-09-30          GBR             4
# 7569       37980  MARKET RASEN  2023-09-30          GBR             7
#
#       distance distance_unit distance_furlongs  distance_raw_furlongs  \
# 82        3645         yards            2m0.5f                   16.6
# 107       5251         yards              2m8f                   23.9
# 108       5251         yards              2m8f                   23.9
# 109       5251         yards              2m8f                   23.9
# 110       5251         yards              2m8f                   23.9
# ...        ...           ...               ...                    ...
# 7358      4709         yards            2m5.5f                   21.4
# 7359      4709         yards            2m5.5f                   21.4
# 7360      4709         yards            2m5.5f                   21.4
# 7362      4709         yards            2m5.5f                   21.4
# 7569      4100         yards            2m2.5f                   18.6
#
#      race_class  ... run_7_dsr run_8_raw_post_race_rating_int  \
# 82            4  ...       NaN                            NaN
# 107           3  ...     440.0                          113.0
# 108           3  ...    1161.0                            NaN
# 109           3  ...     605.0                            NaN
# 110           3  ...     454.0                            NaN
# ...         ...  ...       ...                            ...
# 7358          3  ...     557.0                          106.0
# 7359          3  ...     336.0                          122.0
# 7360          3  ...     134.0                          121.0
# 7362          3  ...     296.0                            NaN
# 7569          5  ...     260.0                           85.0
#
#       run_8_raw_post_race_rating_symbol run_8_final_rating_int  \
# 82                                  NaN                    NaN
# 107                                 NaN                  118.0
# 108                                 NaN                    NaN
# 109                                 NaN                    NaN
# 110                                 NaN                    NaN
# ...                                 ...                    ...
# 7358                                NaN                  108.0
# 7359                                  +                  129.0
# 7360                                NaN                  130.0
# 7362                                NaN                    NaN
# 7569                                NaN                  106.0
#
#      run_8_race_type run_8_race_class  run_8_race_class_normalised  \
# 82               NaN              NaN                          NaN
# 107             JUMP                3                     Handicap
# 108              NaN              NaN                          NaN
# 109     STEEPLECHASE                3                     Handicap
# 110     STEEPLECHASE                4                     Handicap
# ...              ...              ...                          ...
# 7358    STEEPLECHASE                4                       Novice
# 7359            JUMP                4                     Handicap
# 7360    STEEPLECHASE                3                     Handicap
# 7362            JUMP                3                     Handicap
# 7569            JUMP                5                     Handicap
#
#       run_8_track_type  run_8_win_lose  run_8_dsr
# 82                 NaN             NaN        NaN
# 107               TURF             0.0      454.0
# 108                NaN             NaN        NaN
# 109               TURF             1.0      781.0
# 110               TURF             0.0      627.0
# ...                ...             ...        ...
# 7358              TURF             0.0      581.0
# 7359              TURF             1.0      511.0
# 7360              TURF             0.0      155.0
# 7362              TURF             0.0      310.0
# 7569              TURF             0.0      296.0
#
# [127632 rows x 121 columns]

# %%
data_jump_sort.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 127632 entries, 82 to 7569
# Columns: 121 entries, meeting_id to run_8_dsr
# dtypes: float64(48), int64(10), object(63)
# memory usage: 118.8+ MB

# %%
data_jump_sort
# Out:
#       meeting_id  meeting_name        date country_code  event_number  \
# 82          3671  MARKET RASEN  2020-07-20          GBR             1
# 107         3671  MARKET RASEN  2020-07-20          GBR             4
# 108         3671  MARKET RASEN  2020-07-20          GBR             4
# 109         3671  MARKET RASEN  2020-07-20          GBR             4
# 110         3671  MARKET RASEN  2020-07-20          GBR             4
# ...          ...           ...         ...          ...           ...
# 7358       37980  MARKET RASEN  2023-09-30          GBR             4
# 7359       37980  MARKET RASEN  2023-09-30          GBR             4
# 7360       37980  MARKET RASEN  2023-09-30          GBR             4
# 7362       37980  MARKET RASEN  2023-09-30          GBR             4
# 7569       37980  MARKET RASEN  2023-09-30          GBR             7
#
#       distance distance_unit distance_furlongs  distance_raw_furlongs  \
# 82        3645         yards            2m0.5f                   16.6
# 107       5251         yards              2m8f                   23.9
# 108       5251         yards              2m8f                   23.9
# 109       5251         yards              2m8f                   23.9
# 110       5251         yards              2m8f                   23.9
# ...        ...           ...               ...                    ...
# 7358      4709         yards            2m5.5f                   21.4
# 7359      4709         yards            2m5.5f                   21.4
# 7360      4709         yards            2m5.5f                   21.4
# 7362      4709         yards            2m5.5f                   21.4
# 7569      4100         yards            2m2.5f                   18.6
#
#      race_class  ... run_7_dsr run_8_raw_post_race_rating_int  \
# 82            4  ...       NaN                            NaN
# 107           3  ...     440.0                          113.0
# 108           3  ...    1161.0                            NaN
# 109           3  ...     605.0                            NaN
# 110           3  ...     454.0                            NaN
# ...         ...  ...       ...                            ...
# 7358          3  ...     557.0                          106.0
# 7359          3  ...     336.0                          122.0
# 7360          3  ...     134.0                          121.0
# 7362          3  ...     296.0                            NaN
# 7569          5  ...     260.0                           85.0
#
#       run_8_raw_post_race_rating_symbol run_8_final_rating_int  \
# 82                                  NaN                    NaN
# 107                                 NaN                  118.0
# 108                                 NaN                    NaN
# 109                                 NaN                    NaN
# 110                                 NaN                    NaN
# ...                                 ...                    ...
# 7358                                NaN                  108.0
# 7359                                  +                  129.0
# 7360                                NaN                  130.0
# 7362                                NaN                    NaN
# 7569                                NaN                  106.0
#
#      run_8_race_type run_8_race_class  run_8_race_class_normalised  \
# 82               NaN              NaN                          NaN
# 107             JUMP                3                     Handicap
# 108              NaN              NaN                          NaN
# 109     STEEPLECHASE                3                     Handicap
# 110     STEEPLECHASE                4                     Handicap
# ...              ...              ...                          ...
# 7358    STEEPLECHASE                4                       Novice
# 7359            JUMP                4                     Handicap
# 7360    STEEPLECHASE                3                     Handicap
# 7362            JUMP                3                     Handicap
# 7569            JUMP                5                     Handicap
#
#       run_8_track_type  run_8_win_lose  run_8_dsr
# 82                 NaN             NaN        NaN
# 107               TURF             0.0      454.0
# 108                NaN             NaN        NaN
# 109               TURF             1.0      781.0
# 110               TURF             0.0      627.0
# ...                ...             ...        ...
# 7358              TURF             0.0      581.0
# 7359              TURF             1.0      511.0
# 7360              TURF             0.0      155.0
# 7362              TURF             0.0      310.0
# 7569              TURF             0.0      296.0
#
# [127632 rows x 121 columns]

# %%
jump_combined_csv2 =data_jump_sort.to_csv( "../../combined_data/combined_jump_csv.csv", index=False, encoding='utf-8-sig')

# %% [markdown]
# # Flat Data

# %%
filter_condition_flat = (combined_csv['race_type'] == 'FLAT') | (combined_csv['race_type'] == 'NATIONAL_HUNT_FLAT')

# %%
data_flat = combined_csv[filter_condition_flat]

# %%
data_flat_sort = data_flat.sort_values(by=['meeting_id'], ascending=True)

# %%
data_flat_sort['race_type'].unique()
# Out:
# array(['FLAT', 'NATIONAL_HUNT_FLAT'], dtype=object)

# %%
flat_combined_csv2 =data_flat_sort.to_csv( "../../combined_data/combined_flat2_csv.csv", index=False, encoding='utf-8-sig')

# %%
data_flat_sort.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 282006 entries, 0 to 7488
# Columns: 121 entries, meeting_id to run_8_dsr
# dtypes: float64(48), int64(10), object(63)
# memory usage: 262.5+ MB

# %%
data_flat_sort.shape
# Out:
# (282006, 121)

# %%
data_flat.race_type.unique()
# Out:
# array(['FLAT', 'NATIONAL_HUNT_FLAT'], dtype=object)

# %% [markdown]
# # Working Data

# %%
combined_csv2 =all_filenames.to_csv( "../../combined_data/combined_csv.csv", index=False, encoding='utf-8-sig')

# %%
# filter_condition = (data['race_type'] == 'JUMP') | (data['race_type'] == 'STEEPLECHASE')

# %%
filtered_df = data[filter_condition]

# %%
# filter_condition = (data['race_type'] == 'FLAT') | (data['race_type'] == 'NATIONAL_HUNT_DATA')

# %%
#export to csv
combined_csv2 =combined_csv.to_csv( "../../combined_data/combined_csv.csv", index=False, encoding='utf-8-sig')

# %%
# !ls

# %%
combined_csv['race_type'].unique()

# %%
test = pd.read_csv("../../combined_data/combined_jump_csv.csv").race_type.unique()
# Out:
# /tmp/ipykernel_82597/3051574486.py:1: DtypeWarning: Columns (9,22,53,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   test = pd.read_csv("../../combined_data/combined_jump_csv.csv").race_type.unique()

# %%
test
# Out:
# array(['JUMP', 'STEEPLECHASE', 'CROSS_COUNTRY'], dtype=object)
