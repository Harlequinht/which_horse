# %%
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
import datetime as dt
import matplotlib.pyplot as plt

# %%
# !pwd
# Out:
# /home/tomi/code/Harlequinht

# %%
#Read CSV of raw flats data to ensure imputing doesn't affect correlation
df = pd.read_csv('combined_data/combined_flat2_csv.csv')
# Out:
# /tmp/ipykernel_1228/1565615824.py:2: DtypeWarning: Columns (22,53,62,71,80,89,98,107,116) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('combined_data/combined_flat2_csv.csv')

# %%
#ensuring win/loss is still within data as this is our y
df['win_or_lose']
# Out:
# 0         0.0
# 1         0.0
# 2         0.0
# 3         1.0
# 4         0.0
#          ...
# 282001    0.0
# 282002    0.0
# 282003    0.0
# 282004    0.0
# 282005    0.0
# Name: win_or_lose, Length: 282006, dtype: float64

# %%
#work out correlation between the features in the data set and y
win_lose_all_data = np.abs(df.corr(method = 'pearson'))
df_win_loss = win_lose[['win_or_lose']] #correlation between y and other vaiables

# %%
win_lose.stack().reset_index() #correlation between all features to check for self-correlation
# Out:
#          level_0                         level_1         0
# 0     meeting_id                      meeting_id  1.000000
# 1     meeting_id                    event_number  0.053186
# 2     meeting_id                        distance  0.020122
# 3     meeting_id           distance_raw_furlongs  0.020183
# 4     meeting_id                      race_class  0.027277
# ...          ...                             ...       ...
# 3359   run_8_dsr                       run_7_dsr  0.932725
# 3360   run_8_dsr  run_8_raw_post_race_rating_int  0.189099
# 3361   run_8_dsr          run_8_final_rating_int  0.174833
# 3362   run_8_dsr                  run_8_win_lose  0.069755
# 3363   run_8_dsr                       run_8_dsr  1.000000
#
# [3364 rows x 3 columns]

# %%
df_win_loss.sort_values(by='win_or_lose', ascending=False) #correlation for all values against win/loss to see what is affecting it
# Out:
#                                 win_or_lose
# win_or_lose                        1.000000
# finish_position                    0.459894
# post_race_master_rating_int        0.315602
# starting_price                     0.154336
# run_1_raw_post_race_rating_int     0.134732
# bet365_odds                        0.127429
# run_1_final_rating_int             0.112617
# betfair_starting_price             0.110876
# number                             0.100044
# run_1_win_lose                     0.092000
# run_2_raw_post_race_rating_int     0.089560
# pre_race_master_rating_int         0.081541
# run_2_final_rating_int             0.067211
# barrier                            0.059536
# weight_adjustment                  0.058478
# run_3_raw_post_race_rating_int     0.058265
# official rating                    0.055101
# handicap_weight                    0.044786
# run_2_win_lose                     0.043913
# run_4_raw_post_race_rating_int     0.037128
# run_3_final_rating_int             0.036426
# jockey_id                          0.029957
# run_5_raw_post_race_rating_int     0.029362
# jockey_allowance                   0.028241
# run_3_dsr                          0.027148
# run_3_win_lose                     0.026474
# run_2_dsr                          0.026002
# run_4_dsr                          0.025181
# run_5_dsr                          0.023333
# age                                0.022402
# run_7_dsr                          0.021457
# run_8_dsr                          0.021387
# run_6_dsr                          0.021081
# run_6_raw_post_race_rating_int     0.020767
# dslr                               0.020367
# run_1_dsr                          0.020364
# wfa                                0.017178
# margin                             0.016767
# run_4_final_rating_int             0.015427
# run_7_raw_post_race_rating_int     0.015150
# run_8_raw_post_race_rating_int     0.013442
# run_4_win_lose                     0.012335
# horse_id                           0.011906
# race_class                         0.011722
# total_prize_money                  0.009872
# meeting_id                         0.008943
# run_5_win_lose                     0.007921
# run_8_final_rating_int             0.007717
# run_5_final_rating_int             0.007569
# tainer_id                          0.007420
# distance                           0.007320
# distance_raw_furlongs              0.007287
# event_number                       0.006531
# run_7_final_rating_int             0.006020
# run_6_win_lose                     0.001716
# run_7_win_lose                     0.001517
# run_8_win_lose                     0.000749
# run_6_final_rating_int             0.000725
# pmu_odds                                NaN

# %%
# Converting the correlation matrix into a DataFrame for all data
corr_df = win_lose_all_data.stack().reset_index()

# Renaming the columns
corr_df.columns = ['feature_1', 'feature_2', 'correlation']

# Remove "self correlations"
no_self_correlation = (corr_df['feature_1'] != corr_df['feature_2'])
corr_df = corr_df[no_self_correlation]

# %%
corr_df.sort_values(by='correlation', ascending=False).head(20)
# Out:
#                            feature_1                       feature_2  \
# 176            distance_raw_furlongs                        distance
# 119                         distance           distance_raw_furlongs
# 1697                       run_1_dsr                            dslr
# 899                             dslr                       run_1_dsr
# 1592          run_1_final_rating_int  run_1_raw_post_race_rating_int
# 1535  run_1_raw_post_race_rating_int          run_1_final_rating_int
# 1828          run_2_final_rating_int  run_2_raw_post_race_rating_int
# 1771  run_2_raw_post_race_rating_int          run_2_final_rating_int
# 2064          run_3_final_rating_int  run_3_raw_post_race_rating_int
# 2007  run_3_raw_post_race_rating_int          run_3_final_rating_int
# 2243  run_4_raw_post_race_rating_int          run_4_final_rating_int
# 2300          run_4_final_rating_int  run_4_raw_post_race_rating_int
# 2536          run_5_final_rating_int  run_5_raw_post_race_rating_int
# 2479  run_5_raw_post_race_rating_int          run_5_final_rating_int
# 2715  run_6_raw_post_race_rating_int          run_6_final_rating_int
# 2772          run_6_final_rating_int  run_6_raw_post_race_rating_int
# 2951  run_7_raw_post_race_rating_int          run_7_final_rating_int
# 3008          run_7_final_rating_int  run_7_raw_post_race_rating_int
# 3187  run_8_raw_post_race_rating_int          run_8_final_rating_int
# 3244          run_8_final_rating_int  run_8_raw_post_race_rating_int
#
#       correlation
# 176      0.999974
# 119      0.999974
# 1697     0.999602
# 899      0.999602
# 1592     0.952085
# 1535     0.952085
# 1828     0.948956
# 1771     0.948956
# 2064     0.946594
# 2007     0.946594
# 2243     0.945141
# 2300     0.945141
# 2536     0.943805
# 2479     0.943805
# 2715     0.942866
# 2772     0.942866
# 2951     0.942053
# 3008     0.942053
# 3187     0.940967
# 3244     0.940967

# %%
# # # new_df = pd.DataFrame() - self correlation

# df_temp_col_names = win_lose.columns.tolist()
# lst = []

# for i in range(len(win_lose)):
#     for j in range(len(win_lose.columns)):
#         if win_lose.iloc[i, j] != 0 and win_lose.iloc[i, j] != 1:
#             lst.append(f'{df_temp_col_names[i]} - {df_temp_col_names[j]} - {win_lose.iloc[i, j]}')

# lst
# Out:
# ['Unnamed: 0 - meeting_id - 0.9506987836369463',
#  'Unnamed: 0 - event_number - 0.03610220204736725',
#  'Unnamed: 0 - distance - 0.02150568692720936',
#  'Unnamed: 0 - distance_raw_furlongs - 0.02152113872469036',
#  'Unnamed: 0 - race_class_normalised - 0.010392371951843261',
#  'Unnamed: 0 - total_prize_money - 0.04543058443178062',
#  'Unnamed: 0 - track_condition - 0.03843198908719944',
#  'Unnamed: 0 - race_type - 0.015967083042205617',
#  'Unnamed: 0 - track_type - 0.05461420408979158',
#  'Unnamed: 0 - barrier - 0.030637374139352858',
#  'Unnamed: 0 - number - 0.030463707887419512',
#  'Unnamed: 0 - finish_position - 0.02536718239232971',
#  'Unnamed: 0 - win_or_lose - 0.006554757784340701',
#  'Unnamed: 0 - failed_to_finish_reason - 0.003642010728211993',
#  'Unnamed: 0 - gear - 0.19078300723229036',
#  'Unnamed: 0 - jockey_allowance - 0.016810210277771354',
#  'Unnamed: 0 - handicap_weight - 0.1510328349610514',
#  'Unnamed: 0 - jockey_id - 0.12475421780166049',
#  'Unnamed: 0 - tainer_id - 0.17638526934950177',
#  'Unnamed: 0 - horse_id - 0.6599835854524742',
#  'Unnamed: 0 - age - 0.035231005863501585',
#  'Unnamed: 0 - wfa - 0.005312909188165956',
#  'Unnamed: 0 - weight_adjustment - 0.20787943230113914',
#  'Unnamed: 0 - post_race_master_rating_int - 0.024826070070063464',
#  'Unnamed: 0 - starting_price - 0.015391964612728386',
#  'Unnamed: 0 - run_1_track_type - 0.058760325181353344',
#  'Unnamed: 0 - run_2_track_type - 0.052381252250946295',
#  'Unnamed: 0 - run_3_track_type - 0.03792597922357497',
#  'Unnamed: 0 - run_4_track_type - 0.023060750799909057',
#  'Unnamed: 0 - run_5_final_rating_int - 0.06959256158499666',
#  'Unnamed: 0 - run_5_track_type - 0.009532630445586379',
#  'Unnamed: 0 - dam_id - 0.006184224662624213',
#  'Unnamed: 0 - sire_id - 0.01797842269301862',
#  'Unnamed: 0 - betfair_starting_price - 0.008862261044396769',
#  'Unnamed: 0 - run_1_race_type - 0.012943506773799898',
#  'Unnamed: 0 - run_1_win_lose - 0.005982037846742082',
#  'Unnamed: 0 - run_1_dsr - 0.03627524153679508',
#  'Unnamed: 0 - dslr - 0.036249063249597514',
#  'Unnamed: 0 - run_1_race_class - 0.013890582800678546',
#  'Unnamed: 0 - pre_race_master_rating_int - 0.04120806040698675',
#  'Unnamed: 0 - run_1_raw_post_race_rating_int - 0.013981943198125022',
#  'Unnamed: 0 - run_1_final_rating_int - 0.041450974493665006',
#  'Unnamed: 0 - margin - 0.03667814414028548',
#  'Unnamed: 0 - run_2_win_lose - 0.008738152440618187',
#  'Unnamed: 0 - run_2_dsr - 0.044648926300280625',
#  'Unnamed: 0 - run_2_race_type - 0.012815297015268923',
#  'Unnamed: 0 - run_2_race_class_normalised - 0.014200004699243292',
#  'Unnamed: 0 - run_2_final_rating_int - 0.04313076332158309',
#  'Unnamed: 0 - run_2_raw_post_race_rating_int - 0.012486964432871464',
#  'Unnamed: 0 - official rating - 0.003479867801799973',
#  'Unnamed: 0 - run_3_win_lose - 0.008742547165931605',
#  'Unnamed: 0 - run_3_dsr - 0.04589357825580638',
#  'Unnamed: 0 - run_3_race_type - 0.011389174032905814',
#  'Unnamed: 0 - run_3_race_class_normalised - 0.012885893629290754',
#  'Unnamed: 0 - run_3_final_rating_int - 0.04750155089703273',
#  'Unnamed: 0 - run_3_raw_post_race_rating_int - 0.009346471286536442',
#  'Unnamed: 0 - run_4_dsr - 0.04311193624672243',
#  'Unnamed: 0 - run_4_win_lose - 0.007862315137475796',
#  'Unnamed: 0 - run_4_race_type - 0.009935174107127133',
#  'Unnamed: 0 - run_4_race_class_normalised - 0.010282082417279945',
#  'Unnamed: 0 - run_4_final_rating_int - 0.0505338115181464',
#  'Unnamed: 0 - run_4_raw_post_race_rating_int - 0.005271728697134375',
#  'Unnamed: 0 - run_5_race_type - 0.008342949118299733',
#  'Unnamed: 0 - run_5_win_lose - 0.005098665699519362',
#  'Unnamed: 0 - run_5_dsr - 0.037854019722462065',
#  'Unnamed: 0 - run_5_race_class_normalised - 0.008309117803300953',
#  'Unnamed: 0 - run_5_raw_post_race_rating_int - 0.003238736857165804',
#  'meeting_id - Unnamed: 0 - 0.9506987836369463',
#  'meeting_id - event_number - 0.05318577500955232',
#  'meeting_id - distance - 0.02012196824976279',
#  'meeting_id - distance_raw_furlongs - 0.02018289208959502',
#  'meeting_id - race_class_normalised - 0.013465335979614931',
#  'meeting_id - total_prize_money - 0.047759586359688286',
#  'meeting_id - track_condition - 0.07081930534954008',
#  'meeting_id - race_type - 0.014957596174795822',
#  'meeting_id - track_type - 0.07829425743076115',
#  'meeting_id - barrier - 0.03655160481464671',
#  'meeting_id - number - 0.036164932562860234',
#  'meeting_id - finish_position - 0.031139351563726977',
#  'meeting_id - win_or_lose - 0.008943114243776085',
#  'meeting_id - failed_to_finish_reason - 0.004504974934450323',
#  'meeting_id - gear - 0.1873006325140582',
#  'meeting_id - jockey_allowance - 0.009497610842550441',
#  'meeting_id - handicap_weight - 0.13764275093504152',
#  'meeting_id - jockey_id - 0.12122831223539327',
#  'meeting_id - tainer_id - 0.17297141091231605',
#  'meeting_id - horse_id - 0.6413412696987265',
#  'meeting_id - age - 0.026092360457059167',
#  'meeting_id - wfa - 0.012383343482716623',
#  'meeting_id - weight_adjustment - 0.1898322444741607',
#  'meeting_id - post_race_master_rating_int - 0.0290045258156742',
#  'meeting_id - starting_price - 0.012105231296001898',
#  'meeting_id - run_1_track_type - 0.059080521675296115',
#  'meeting_id - run_2_track_type - 0.04307706569739873',
#  'meeting_id - run_3_track_type - 0.02696487560146587',
#  'meeting_id - run_4_track_type - 0.013859850072218901',
#  'meeting_id - run_5_final_rating_int - 0.059749075761265896',
#  'meeting_id - run_5_track_type - 0.003735992253744303',
#  'meeting_id - dam_id - 0.005010176658825866',
#  'meeting_id - sire_id - 0.013835142508199654',
#  'meeting_id - betfair_starting_price - 0.008533059437831536',
#  'meeting_id - run_1_race_type - 0.013889162039368536',
#  'meeting_id - run_1_win_lose - 0.009568187488623694',
#  'meeting_id - run_1_dsr - 0.028967753554571662',
#  'meeting_id - dslr - 0.02879283415830378',
#  'meeting_id - run_1_race_class - 0.016665648764697515',
#  'meeting_id - pre_race_master_rating_int - 0.029979995763201886',
#  'meeting_id - run_1_raw_post_race_rating_int - 0.017482999527417064',
#  'meeting_id - run_1_final_rating_int - 0.033765384706739184',
#  'meeting_id - margin - 0.037900775274961954',
#  'meeting_id - run_2_win_lose - 0.011963700166043319',
#  'meeting_id - run_2_dsr - 0.036980853434079836',
#  'meeting_id - run_2_race_type - 0.01522180020080693',
#  'meeting_id - run_2_race_class_normalised - 0.016646742393387964',
#  'meeting_id - run_2_final_rating_int - 0.034395814018801735',
#  'meeting_id - run_2_raw_post_race_rating_int - 0.016661908951163883',
#  'meeting_id - official rating - 0.009272275986193724',
#  'meeting_id - run_3_win_lose - 0.012434842105792435',
#  'meeting_id - run_3_dsr - 0.04038209110646931',
#  'meeting_id - run_3_race_type - 0.014525902892248706',
#  'meeting_id - run_3_race_class_normalised - 0.014802553900018469',
#  'meeting_id - run_3_final_rating_int - 0.03762383515142146',
#  'meeting_id - run_3_raw_post_race_rating_int - 0.014135880459752895',
#  'meeting_id - run_4_dsr - 0.04144789427962984',
#  'meeting_id - run_4_win_lose - 0.010965503596284079',
#  'meeting_id - run_4_race_type - 0.012546743765756768',
#  'meeting_id - run_4_race_class_normalised - 0.011758567758654068',
#  'meeting_id - run_4_final_rating_int - 0.04049519918455329',
#  'meeting_id - run_4_raw_post_race_rating_int - 0.010269052119558851',
#  'meeting_id - run_5_race_type - 0.010512954401717074',
#  'meeting_id - run_5_win_lose - 0.007690651202171092',
#  'meeting_id - run_5_dsr - 0.04041483080866307',
#  'meeting_id - run_5_race_class_normalised - 0.009200866708785813',
#  'meeting_id - run_5_raw_post_race_rating_int - 0.007145684397264231',
#  'event_number - Unnamed: 0 - 0.03610220204736725',
#  'event_number - meeting_id - 0.05318577500955232',
#  'event_number - distance - 0.2347357230624369',
#  'event_number - distance_raw_furlongs - 0.23466372324105464',
#  'event_number - race_class_normalised - 0.12799698355151046',
#  'event_number - total_prize_money - 0.036315040405060756',
#  'event_number - track_condition - 0.008401052841877206',
#  'event_number - race_type - 0.20329183796529532',
#  'event_number - track_type - 0.012365366714215991',
#  'event_number - barrier - 0.0323488557509078',
#  'event_number - number - 0.03179858711965647',
#  'event_number - finish_position - 0.02266245365368293',
#  'event_number - win_or_lose - 0.006531059426357919',
#  'event_number - failed_to_finish_reason - 0.01779096448243123',
#  'event_number - gear - 0.056074913458308034',
#  'event_number - jockey_allowance - 0.02648865782984173',
#  'event_number - handicap_weight - 0.1430872232787636',
#  'event_number - jockey_id - 0.006906999265063169',
#  'event_number - tainer_id - 0.014101064866883653',
#  'event_number - horse_id - 0.11826279523931524',
#  'event_number - age - 0.13868204473221069',
#  'event_number - wfa - 0.039881178149908825',
#  'event_number - weight_adjustment - 0.00948031453466548',
#  'event_number - post_race_master_rating_int - 0.00420805377810225',
#  'event_number - starting_price - 0.03036066692306725',
#  'event_number - run_1_track_type - 0.016162881417343535',
#  'event_number - run_2_track_type - 0.04155359508380973',
#  'event_number - run_3_track_type - 0.06723380232985628',
#  'event_number - run_4_track_type - 0.07895438897403632',
#  'event_number - run_5_final_rating_int - 0.030122199315617014',
#  'event_number - run_5_track_type - 0.08459392650129267',
#  'event_number - dam_id - 0.0041974905828821955',
#  'event_number - sire_id - 0.010187430038869825',
#  'event_number - betfair_starting_price - 0.03375733285747799',
#  'event_number - run_1_race_type - 0.03402743987981366',
#  'event_number - run_1_win_lose - 0.001414306180271971',
#  'event_number - run_1_dsr - 0.03758310264902277',
#  'event_number - dslr - 0.037627265301591356',
#  'event_number - run_1_race_class - 0.11742119832411888',
#  'event_number - pre_race_master_rating_int - 0.0034261387775546387',
#  'event_number - run_1_raw_post_race_rating_int - 0.014490892112556065',
#  'event_number - run_1_final_rating_int - 0.020856262180601385',
#  'event_number - margin - 0.06754562327171892',
#  'event_number - run_2_win_lose - 0.008184526641359999',
#  'event_number - run_2_dsr - 0.04021573111867492',
#  'event_number - run_2_race_type - 0.09951979218419084',
#  'event_number - run_2_race_class_normalised - 0.12354872193742984',
#  'event_number - run_2_final_rating_int - 0.006926636359498965',
#  'event_number - run_2_raw_post_race_rating_int - 0.00190332406398282',
#  'event_number - official rating - 0.03946303311884232',
#  'event_number - run_3_win_lose - 0.009350686813690771',
#  'event_number - run_3_dsr - 0.038536389631607194',
#  'event_number - run_3_race_type - 0.13935913026273322',
#  'event_number - run_3_race_class_normalised - 0.13363726990606417',
#  'event_number - run_3_final_rating_int - 0.0062387082406611186',
#  'event_number - run_3_raw_post_race_rating_int - 0.010482563110358953',
#  'event_number - run_4_dsr - 0.037541093663464364',
#  'event_number - run_4_win_lose - 0.006563817068992909',
#  'event_number - run_4_race_type - 0.14292997602889818',
#  'event_number - run_4_race_class_normalised - 0.13106794095412963',
#  'event_number - run_4_final_rating_int - 0.0018738236668681733',
#  'event_number - run_4_raw_post_race_rating_int - 0.0004569243254393131',
#  'event_number - run_5_race_type - 0.14089365467800102',
#  'event_number - run_5_win_lose - 0.0037196070553495975',
#  'event_number - run_5_dsr - 0.03526291839668132',
#  'event_number - run_5_race_class_normalised - 0.12703254515587825',
#  'event_number - run_5_raw_post_race_rating_int - 0.004559219211518876',
#  'distance - Unnamed: 0 - 0.02150568692720936',
#  'distance - meeting_id - 0.02012196824976279',
#  'distance - event_number - 0.2347357230624369',
#  'distance - distance_raw_furlongs - 0.9999739696509569',
#  'distance - race_class_normalised - 0.012542760042619363',
#  'distance - total_prize_money - 0.028610709375840485',
#  'distance - track_condition - 0.004231970284875041',
#  'distance - race_type - 0.5205119265425007',
#  'distance - track_type - 0.04147658787904607',
#  'distance - barrier - 0.017023711854707017',
#  'distance - number - 0.019509398326936177',
#  'distance - finish_position - 0.024752430729694068',
#  'distance - win_or_lose - 0.007320235861314469',
#  'distance - failed_to_finish_reason - 0.04344463957762443',
#  'distance - gear - 0.009768598555121608',
#  'distance - jockey_allowance - 0.02968895992356863',
#  'distance - handicap_weight - 0.37701136878348196',
#  'distance - jockey_id - 0.0438039903259748',
#  'distance - tainer_id - 0.02336033319818596',
#  'distance - horse_id - 0.034702481947531755',
#  'distance - age - 0.1571801405362733',
#  'distance - wfa - 0.09232758183151724',
#  'distance - weight_adjustment - 0.010674207119162407',
#  'distance - post_race_master_rating_int - 0.13824246624913444',
#  'distance - starting_price - 0.012596157380689683',
#  'distance - run_1_track_type - 0.01892507992435518',
#  'distance - run_2_track_type - 0.0014124584062445143',
#  'distance - run_3_track_type - 0.0029398102401630736',
#  'distance - run_4_track_type - 0.0063129510021794535',
#  'distance - run_5_final_rating_int - 0.0551592745841307',
#  'distance - run_5_track_type - 0.010102691973570981',
#  'distance - dam_id - 0.006119741073936828',
#  'distance - sire_id - 0.0634546704475805',
#  'distance - betfair_starting_price - 0.016326577133553052',
#  'distance - run_1_race_type - 0.16521090493247068',
#  'distance - run_1_win_lose - 0.02809537364600839',
#  'distance - run_1_dsr - 0.075221156261655',
#  'distance - dslr - 0.0752332400344855',
#  'distance - run_1_race_class - 0.041956133273964094',
#  'distance - pre_race_master_rating_int - 0.05865662684250294',
#  'distance - run_1_raw_post_race_rating_int - 0.14576299347856483',
#  'distance - run_1_final_rating_int - 0.12338506066604575',
#  'distance - margin - 0.2716064499746177',
#  'distance - run_2_win_lose - 0.031668128432240934',
#  'distance - run_2_dsr - 0.09893458590110829',
#  'distance - run_2_race_type - 0.10595216031657291',
#  'distance - run_2_race_class_normalised - 0.04773237643272241',
#  'distance - run_2_final_rating_int - 0.11509780704862974',
#  'distance - run_2_raw_post_race_rating_int - 0.14028877364170794',
#  'distance - official rating - 0.08026015597607475',
#  'distance - run_3_win_lose - 0.02959840237908712',
#  'distance - run_3_dsr - 0.11301926666473223',
#  'distance - run_3_race_type - 0.06408881468287307',
#  'distance - run_3_race_class_normalised - 0.04035591067015225',
#  'distance - run_3_final_rating_int - 0.10218059569196637',
#  'distance - run_3_raw_post_race_rating_int - 0.1274598094067279',
#  'distance - run_4_dsr - 0.1233525005387565',
#  'distance - run_4_win_lose - 0.028028372738842122',
#  'distance - run_4_race_type - 0.04629154728930517',
#  'distance - run_4_race_class_normalised - 0.03624073544685324',
#  'distance - run_4_final_rating_int - 0.10057037378253475',
#  'distance - run_4_raw_post_race_rating_int - 0.1258905386502811',
#  'distance - run_5_race_type - 0.03554050556489407',
#  'distance - run_5_win_lose - 0.032669395656790515',
#  'distance - run_5_dsr - 0.13479443713375977',
#  'distance - run_5_race_class_normalised - 0.031819750753833864',
#  'distance - run_5_raw_post_race_rating_int - 0.12564276515560768',
#  'distance_raw_furlongs - Unnamed: 0 - 0.02152113872469036',
#  'distance_raw_furlongs - meeting_id - 0.02018289208959502',
#  'distance_raw_furlongs - event_number - 0.23466372324105464',
#  'distance_raw_furlongs - distance - 0.9999739696509569',
#  'distance_raw_furlongs - race_class_normalised - 0.01250505470646167',
#  'distance_raw_furlongs - total_prize_money - 0.02884508069143409',
#  'distance_raw_furlongs - track_condition - 0.0034811325393806066',
#  'distance_raw_furlongs - race_type - 0.5204252265760553',
#  'distance_raw_furlongs - track_type - 0.04057679149722579',
#  'distance_raw_furlongs - barrier - 0.016917083704867164',
#  'distance_raw_furlongs - number - 0.01940539882940361',
#  'distance_raw_furlongs - finish_position - 0.024636818544867087',
#  'distance_raw_furlongs - win_or_lose - 0.007287227549235144',
#  'distance_raw_furlongs - failed_to_finish_reason - 0.043464345514017094',
#  'distance_raw_furlongs - gear - 0.009903108264505831',
#  'distance_raw_furlongs - jockey_allowance - 0.029784660413131728',
#  'distance_raw_furlongs - handicap_weight - 0.37681885534338005',
#  'distance_raw_furlongs - jockey_id - 0.04379182058996248',
#  'distance_raw_furlongs - tainer_id - 0.023286832716599364',
#  'distance_raw_furlongs - horse_id - 0.0348174666385871',
#  'distance_raw_furlongs - age - 0.15732610869415226',
#  'distance_raw_furlongs - wfa - 0.09233376928733943',
#  'distance_raw_furlongs - weight_adjustment - 0.010838062353274388',
#  'distance_raw_furlongs - post_race_master_rating_int - 0.13820261681353782',
#  'distance_raw_furlongs - starting_price - 0.012672685902102186',
#  'distance_raw_furlongs - run_1_track_type - 0.018561138912391924',
#  'distance_raw_furlongs - run_2_track_type - 0.0012214294632588347',
#  'distance_raw_furlongs - run_3_track_type - 0.0028491611935729582',
#  'distance_raw_furlongs - run_4_track_type - 0.006294881788623205',
#  'distance_raw_furlongs - run_5_final_rating_int - 0.055235477456785934',
#  'distance_raw_furlongs - run_5_track_type - 0.010136405778651261',
#  'distance_raw_furlongs - dam_id - 0.006134792393062919',
#  'distance_raw_furlongs - sire_id - 0.06342074107289698',
#  'distance_raw_furlongs - betfair_starting_price - 0.016366434101691727',
#  'distance_raw_furlongs - run_1_race_type - 0.1651251221139291',
#  'distance_raw_furlongs - run_1_win_lose - 0.028141592325143096',
#  'distance_raw_furlongs - run_1_dsr - 0.07515983940686202',
#  'distance_raw_furlongs - dslr - 0.07517196830065165',
#  'distance_raw_furlongs - run_1_race_class - 0.04183585267360863',
#  'distance_raw_furlongs - pre_race_master_rating_int - 0.05865818482102133',
#  'distance_raw_furlongs - run_1_raw_post_race_rating_int - 0.14573042651715606',
#  'distance_raw_furlongs - run_1_final_rating_int - 0.12340413225351766',
#  'distance_raw_furlongs - margin - 0.27158358697163937',
#  'distance_raw_furlongs - run_2_win_lose - 0.03169817747820661',
#  'distance_raw_furlongs - run_2_dsr - 0.09887695258698691',
#  'distance_raw_furlongs - run_2_race_type - 0.10582954481860564',
#  'distance_raw_furlongs - run_2_race_class_normalised - 0.047576338880526405',
#  'distance_raw_furlongs - run_2_final_rating_int - 0.11512534521522538',
#  'distance_raw_furlongs - run_2_raw_post_race_rating_int - 0.14025874459413518',
#  'distance_raw_furlongs - official rating - 0.0802290950761396',
#  'distance_raw_furlongs - run_3_win_lose - 0.029637168158005205',
#  'distance_raw_furlongs - run_3_dsr - 0.1129676034000374',
#  'distance_raw_furlongs - run_3_race_type - 0.06396726743748928',
#  'distance_raw_furlongs - run_3_race_class_normalised - 0.040198806780492785',
#  'distance_raw_furlongs - run_3_final_rating_int - 0.10224335637786759',
#  'distance_raw_furlongs - run_3_raw_post_race_rating_int - 0.12746197993696423',
#  'distance_raw_furlongs - run_4_dsr - 0.12330093132492546',
#  'distance_raw_furlongs - run_4_win_lose - 0.028058343042525843',
#  'distance_raw_furlongs - run_4_race_type - 0.04614926048803144',
#  'distance_raw_furlongs - run_4_race_class_normalised - 0.03607539715195929',
#  'distance_raw_furlongs - run_4_final_rating_int - 0.10061365877864566',
#  'distance_raw_furlongs - run_4_raw_post_race_rating_int - 0.1258711168116748',
#  'distance_raw_furlongs - run_5_race_type - 0.03537887626475552',
#  'distance_raw_furlongs - run_5_win_lose - 0.032676766003925224',
#  'distance_raw_furlongs - run_5_dsr - 0.13473747377218273',
#  'distance_raw_furlongs - run_5_race_class_normalised - 0.031651886121320374',
#  'distance_raw_furlongs - run_5_raw_post_race_rating_int - 0.1256126268641317',
#  'race_class_normalised - Unnamed: 0 - 0.010392371951843261',
#  'race_class_normalised - meeting_id - 0.013465335979614931',
#  'race_class_normalised - event_number - 0.12799698355151046',
#  'race_class_normalised - distance - 0.012542760042619363',
#  'race_class_normalised - distance_raw_furlongs - 0.01250505470646167',
#  'race_class_normalised - total_prize_money - 0.19626333513843455',
#  'race_class_normalised - track_condition - 0.008440284816805766',
#  'race_class_normalised - race_type - 0.2326337418992553',
#  'race_class_normalised - track_type - 0.02407205612455765',
#  'race_class_normalised - barrier - 0.014944800682943337',
#  'race_class_normalised - number - 0.015090401125944838',
#  'race_class_normalised - finish_position - 0.014113992040467573',
#  'race_class_normalised - win_or_lose - 1.4569220456194218e-05',
#  'race_class_normalised - failed_to_finish_reason - 0.008552068524860658',
#  'race_class_normalised - gear - 0.17649636639156682',
#  'race_class_normalised - jockey_allowance - 0.047742093179127',
#  'race_class_normalised - handicap_weight - 0.09778016128797906',
#  'race_class_normalised - jockey_id - 0.0066312564403748905',
#  'race_class_normalised - tainer_id - 0.024263979790084822',
#  'race_class_normalised - horse_id - 0.2680640643771588',
#  'race_class_normalised - age - 0.25498127374548885',
#  'race_class_normalised - wfa - 0.12153281391478439',
#  'race_class_normalised - weight_adjustment - 0.09502960607349327',
#  'race_class_normalised - post_race_master_rating_int - 0.06381566320964058',
#  'race_class_normalised - starting_price - 0.19273032803603643',
#  'race_class_normalised - run_1_track_type - 0.11643767596062912',
#  'race_class_normalised - run_2_track_type - 0.24079481508572262',
#  'race_class_normalised - run_3_track_type - 0.34147913302603633',
#  'race_class_normalised - run_4_track_type - 0.34309338418393254',
#  'race_class_normalised - run_5_final_rating_int - 0.10253861402444915',
#  'race_class_normalised - run_5_track_type - 0.3349235184921027',
#  'race_class_normalised - dam_id - 7.136937027320964e-05',
#  'race_class_normalised - sire_id - 0.025908123095647186',
#  'race_class_normalised - betfair_starting_price - 0.2073140183441952',
#  'race_class_normalised - run_1_race_type - 0.4419953566458175',
#  'race_class_normalised - run_1_win_lose - 0.0758678360463829',
#  'race_class_normalised - run_1_dsr - 0.07381887022911342',
#  'race_class_normalised - dslr - 0.07398192753459366',
#  'race_class_normalised - run_1_race_class - 0.5775997998144393',
#  'race_class_normalised - pre_race_master_rating_int - 0.12900007582011572',
#  'race_class_normalised - run_1_raw_post_race_rating_int - 0.02007993512239858',
#  'race_class_normalised - run_1_final_rating_int - 0.02383770477015051',
#  'race_class_normalised - margin - 0.12152312970338479',
#  'race_class_normalised - run_2_win_lose - 0.08916261831069631',
#  'race_class_normalised - run_2_dsr - 0.09224060247136617',
#  'race_class_normalised - run_2_race_type - 0.5934665135041777',
#  'race_class_normalised - run_2_race_class_normalised - 0.5890588719947945',
#  'race_class_normalised - run_2_final_rating_int - 0.04190379521511296',
#  'race_class_normalised - run_2_raw_post_race_rating_int - 0.03714815524084591',
#  'race_class_normalised - official rating - 0.010576639251227376',
#  'race_class_normalised - run_3_win_lose - 0.08621669619175965',
#  'race_class_normalised - run_3_dsr - 0.09782217189607102',
#  'race_class_normalised - run_3_race_type - 0.7001265074245422',
#  'race_class_normalised - run_3_race_class_normalised - 0.6055078604717055',
#  'race_class_normalised - run_3_final_rating_int - 0.10245626889175598',
#  'race_class_normalised - run_3_raw_post_race_rating_int - 0.09881732392740018',
#  'race_class_normalised - run_4_dsr - 0.08905271442148188',
#  'race_class_normalised - run_4_win_lose - 0.06748674361294717',
#  'race_class_normalised - run_4_race_type - 0.6327701013896387',
#  'race_class_normalised - run_4_race_class_normalised - 0.5560945152745672',
#  'race_class_normalised - run_4_final_rating_int - 0.07841078975603184',
#  'race_class_normalised - run_4_raw_post_race_rating_int - 0.07108260516998885',
#  'race_class_normalised - run_5_race_type - 0.5747327463703039',
#  'race_class_normalised - run_5_win_lose - 0.04320683283844517',
#  'race_class_normalised - run_5_dsr - 0.09676475666704087',
#  'race_class_normalised - run_5_race_class_normalised - 0.5114036977881501',
#  'race_class_normalised - run_5_raw_post_race_rating_int - 0.02694345088371276',
#  'total_prize_money - Unnamed: 0 - 0.04543058443178062',
#  'total_prize_money - meeting_id - 0.047759586359688286',
#  'total_prize_money - event_number - 0.036315040405060756',
#  'total_prize_money - distance - 0.028610709375840485',
#  'total_prize_money - distance_raw_furlongs - 0.02884508069143409',
#  'total_prize_money - race_class_normalised - 0.19626333513843455',
#  'total_prize_money - track_condition - 0.11299932503255102',
#  'total_prize_money - race_type - 0.043118459079927514',
#  'total_prize_money - track_type - 0.13233624011169412',
#  'total_prize_money - barrier - 0.08203822808887516',
#  'total_prize_money - number - 0.07850618618337857',
#  'total_prize_money - finish_position - 0.08150305037714956',
#  'total_prize_money - win_or_lose - 0.009871759719769384',
#  'total_prize_money - failed_to_finish_reason - 5.462090186694907e-05',
#  'total_prize_money - gear - 0.031305612533700365',
#  'total_prize_money - jockey_allowance - 0.07068742767463777',
#  'total_prize_money - handicap_weight - 0.05929839638468074',
#  'total_prize_money - jockey_id - 0.028631891840949792',
#  'total_prize_money - tainer_id - 0.003669128942887937',
#  'total_prize_money - horse_id - 0.002452006268980987',
#  'total_prize_money - age - 0.04261751196413018',
#  'total_prize_money - wfa - 0.010014487204233164',
#  'total_prize_money - weight_adjustment - 0.034941672395154',
#  'total_prize_money - post_race_master_rating_int - 0.2636686148212177',
#  'total_prize_money - starting_price - 0.007150291812207295',
#  'total_prize_money - run_1_track_type - 0.13013492110348693',
#  'total_prize_money - run_2_track_type - 0.13024679560432365',
#  'total_prize_money - run_3_track_type - 0.12226941257965616',
#  'total_prize_money - run_4_track_type - 0.11362404275708515',
#  'total_prize_money - run_5_final_rating_int - 0.30616707151873296',
#  'total_prize_money - run_5_track_type - 0.099590248416513',
#  'total_prize_money - dam_id - 0.004788040739783769',
#  'total_prize_money - sire_id - 0.001921937846978062',
#  'total_prize_money - betfair_starting_price - 0.005885830725405369',
#  'total_prize_money - run_1_race_type - 0.057446500155663195',
#  'total_prize_money - run_1_win_lose - 0.10733900464997163',
#  'total_prize_money - run_1_dsr - 0.00111393947686459',
#  'total_prize_money - dslr - 0.0012184409831108598',
#  'total_prize_money - run_1_race_class - 0.09638284098564494',
#  'total_prize_money - pre_race_master_rating_int - 0.3022527281753448',
#  'total_prize_money - run_1_raw_post_race_rating_int - 0.2652857661815444',
#  'total_prize_money - run_1_final_rating_int - 0.2741381752775296',
#  'total_prize_money - margin - 0.0016642476697430642',
#  'total_prize_money - run_2_win_lose - 0.12061013752501719',
#  'total_prize_money - run_2_dsr - 0.020087896254308655',
#  'total_prize_money - run_2_race_type - 0.06595902117039529',
#  'total_prize_money - run_2_race_class_normalised - 0.09169439486692833',
#  'total_prize_money - run_2_final_rating_int - 0.28256214333200375',
#  'total_prize_money - run_2_raw_post_race_rating_int - 0.2715229953259946',
#  'total_prize_money - official rating - 0.37900076256452164',
#  'total_prize_money - run_3_win_lose - 0.12405106842692992',
#  'total_prize_money - run_3_dsr - 0.03735189254053719',
#  'total_prize_money - run_3_race_type - 0.0629181914847645',
#  'total_prize_money - run_3_race_class_normalised - 0.07724279575963076',
#  'total_prize_money - run_3_final_rating_int - 0.29826422270720904',
#  'total_prize_money - run_3_raw_post_race_rating_int - 0.2861695476249165',
#  'total_prize_money - run_4_dsr - 0.05166320551215707',
#  'total_prize_money - run_4_win_lose - 0.11680200619577498',
#  'total_prize_money - run_4_race_type - 0.055031373978021825',
#  'total_prize_money - run_4_race_class_normalised - 0.06492433974443337',
#  'total_prize_money - run_4_final_rating_int - 0.29128470698722125',
#  'total_prize_money - run_4_raw_post_race_rating_int - 0.2793469163991608',
#  'total_prize_money - run_5_race_type - 0.04545392129644917',
#  'total_prize_money - run_5_win_lose - 0.11151992456141055',
#  'total_prize_money - run_5_dsr - 0.05938292973540187',
#  'total_prize_money - run_5_race_class_normalised - 0.052684218511807046',
#  'total_prize_money - run_5_raw_post_race_rating_int - 0.26856952684795293',
#  'track_condition - Unnamed: 0 - 0.03843198908719944',
#  'track_condition - meeting_id - 0.07081930534954008',
#  'track_condition - event_number - 0.008401052841877206',
#  'track_condition - distance - 0.004231970284875041',
#  'track_condition - distance_raw_furlongs - 0.0034811325393806066',
#  'track_condition - race_class_normalised - 0.008440284816805766',
#  'track_condition - total_prize_money - 0.11299932503255102',
#  'track_condition - race_type - 0.06857405164650507',
#  'track_condition - track_type - 0.8710681100384566',
#  'track_condition - barrier - 0.02022639601202184',
#  'track_condition - number - 0.014957438554781372',
#  'track_condition - finish_position - 0.004020225748740683',
#  'track_condition - win_or_lose - 0.006857371042217697',
#  'track_condition - failed_to_finish_reason - 0.002401153709458252',
#  'track_condition - gear - 0.09907041167359833',
#  'track_condition - jockey_allowance - 0.03595535283812181',
#  'track_condition - handicap_weight - 0.0444163799728426',
#  'track_condition - jockey_id - 0.034010115191125165',
#  'track_condition - tainer_id - 0.03158251604754185',
#  'track_condition - horse_id - 0.07125829938842558',
#  'track_condition - age - 0.041680563046713165',
#  'track_condition - wfa - 0.00016170616255627775',
#  'track_condition - weight_adjustment - 0.008107794593668319',
#  'track_condition - post_race_master_rating_int - 0.13729184498049787',
#  'track_condition - starting_price - 0.04558759361246815',
#  'track_condition - run_1_track_type - 0.3531858761774394',
#  'track_condition - run_2_track_type - 0.22083919818393893',
#  'track_condition - run_3_track_type - 0.13540910820549873',
#  'track_condition - run_4_track_type - 0.08288519123318011',
#  'track_condition - run_5_final_rating_int - 0.132107593948091',
#  'track_condition - run_5_track_type - 0.053966688290562385',
#  'track_condition - dam_id - 0.002101520167105502',
#  'track_condition - sire_id - 0.0030795765963354997',
#  'track_condition - betfair_starting_price - 0.04119769790063189',
#  'track_condition - run_1_race_type - 0.060558538497915364',
#  'track_condition - run_1_win_lose - 0.03675036123371094',
#  'track_condition - run_1_dsr - 0.0029396853951768435',
#  'track_condition - dslr - 0.0031319797068219395',
#  'track_condition - run_1_race_class - 0.03671220478397822',
#  'track_condition - pre_race_master_rating_int - 0.16146213661545353',
#  'track_condition - run_1_raw_post_race_rating_int - 0.15096887206716186',
#  'track_condition - run_1_final_rating_int - 0.1480620418906707',
#  'track_condition - margin - 0.024600796321795414',
#  'track_condition - run_2_win_lose - 0.044643799932326214',
#  'track_condition - run_2_dsr - 0.029477465903865685',
#  'track_condition - run_2_race_type - 0.060101637324372015',
#  'track_condition - run_2_race_class_normalised - 0.04655829319863753',
#  'track_condition - run_2_final_rating_int - 0.14137922894100974',
#  'track_condition - run_2_raw_post_race_rating_int - 0.14545236087408253',
#  'track_condition - official rating - 0.18492133367565078',
#  'track_condition - run_3_win_lose - 0.045013971032166776',
#  'track_condition - run_3_dsr - 0.04769421059075719',
#  'track_condition - run_3_race_type - 0.05537247891897564',
#  'track_condition - run_3_race_class_normalised - 0.05090043783539213',
#  'track_condition - run_3_final_rating_int - 0.1377069344976527',
#  'track_condition - run_3_raw_post_race_rating_int - 0.14182969543851448',
#  'track_condition - run_4_dsr - 0.05719899394692261',
#  'track_condition - run_4_win_lose - 0.04332792286979033',
#  'track_condition - run_4_race_type - 0.056985383300598026',
#  'track_condition - run_4_race_class_normalised - 0.054272247246748805',
#  'track_condition - run_4_final_rating_int - 0.1397065175162249',
#  'track_condition - run_4_raw_post_race_rating_int - 0.14513171652841403',
#  'track_condition - run_5_race_type - 0.059225328113612245',
#  'track_condition - run_5_win_lose - 0.04763029205870932',
#  'track_condition - run_5_dsr - 0.0637283580789942',
#  'track_condition - run_5_race_class_normalised - 0.05636342678338471',
#  'track_condition - run_5_raw_post_race_rating_int - 0.151578714181493',
#  'race_type - Unnamed: 0 - 0.015967083042205617',
#  'race_type - meeting_id - 0.014957596174795822',
#  'race_type - event_number - 0.20329183796529532',
#  'race_type - distance - 0.5205119265425007',
#  'race_type - distance_raw_furlongs - 0.5204252265760553',
#  'race_type - race_class_normalised - 0.2326337418992553',
#  'race_type - total_prize_money - 0.043118459079927514',
#  'race_type - track_condition - 0.06857405164650507',
#  'race_type - track_type - 0.12891135135132886',
#  'race_type - barrier - 0.008841102300679375',
#  'race_type - number - 0.007832777736325335',
#  'race_type - finish_position - 0.000203864125433265',
#  'race_type - win_or_lose - 0.0013718783043771144',
#  'race_type - failed_to_finish_reason - 0.05162650740995742',
#  'race_type - gear - 0.06030921953654423',
#  'race_type - jockey_allowance - 0.05094166342062757',
#  'race_type - handicap_weight - 0.6310206473916595',
#  'race_type - jockey_id - 0.10575948652312894',
#  'race_type - tainer_id - 0.004674694342526837',
#  'race_type - horse_id - 0.10225161135502932',
#  'race_type - age - 0.06306617809686173',
#  'race_type - wfa - 0.012520103599712883',
#  'race_type - weight_adjustment - 0.13959362547415943',
#  'race_type - post_race_master_rating_int - 0.2314723006338961',
#  'race_type - starting_price - 0.04518474451089672',
#  'race_type - run_1_track_type - 0.02397941210315116',
#  'race_type - run_2_track_type - 0.11428096659193608',
#  'race_type - run_3_track_type - 0.14788545862630836',
#  'race_type - run_4_track_type - 0.15381784188475384',
#  'race_type - run_5_final_rating_int - 0.06675436065937564',
#  'race_type - run_5_track_type - 0.14540091477457537',
#  'race_type - dam_id - 0.00045857138653476596',
#  'race_type - sire_id - 0.04400207681394504',
#  'race_type - betfair_starting_price - 0.04235178038048706',
#  'race_type - run_1_race_type - 0.45106898693543135',
#  'race_type - run_1_win_lose - 0.01310846231852604',
#  'race_type - run_1_dsr - 0.09395916044137924',
#  'race_type - dslr - 0.09409233814100391',
#  'race_type - run_1_race_class - 0.279272968357136',
#  'race_type - pre_race_master_rating_int - 0.16103390343189586',
#  'race_type - run_1_raw_post_race_rating_int - 0.2047219945768417',
#  'race_type - run_1_final_rating_int - 0.21709393197897986',
#  'race_type - margin - 0.2618341694660402',
#  'race_type - run_2_win_lose - 0.011805970709451014',
#  'race_type - run_2_dsr - 0.10478195256494212',
#  'race_type - run_2_race_type - 0.39187291715110606',
#  'race_type - run_2_race_class_normalised - 0.2924872973357301',
#  'race_type - run_2_final_rating_int - 0.16729084589079868',
#  'race_type - run_2_raw_post_race_rating_int - 0.16316181915687752',
#  'race_type - official rating - 0.13467993862450958',
#  'race_type - run_3_win_lose - 0.0021421215345333667',
#  'race_type - run_3_dsr - 0.10359610858737989',
#  'race_type - run_3_race_type - 0.3465103792231299',
#  'race_type - run_3_race_class_normalised - 0.2781913919827167',
#  'race_type - run_3_final_rating_int - 0.1111461200968491',
#  'race_type - run_3_raw_post_race_rating_int - 0.10789669731512778',
#  'race_type - run_4_dsr - 0.09465089491711856',
#  'race_type - run_4_win_lose - 0.010916738710316249',
#  'race_type - run_4_race_type - 0.30663022047739935',
#  'race_type - run_4_race_class_normalised - 0.2551408307536392',
#  'race_type - run_4_final_rating_int - 0.11804398512381797',
#  'race_type - run_4_raw_post_race_rating_int - 0.11738478275705995',
#  'race_type - run_5_race_type - 0.27139591606738844',
#  'race_type - run_5_win_lose - 0.025655439474935204',
#  'race_type - run_5_dsr - 0.10159291440670058',
#  'race_type - run_5_race_class_normalised - 0.23157151548438057',
#  'race_type - run_5_raw_post_race_rating_int - 0.13966691937614195',
#  'track_type - Unnamed: 0 - 0.05461420408979158',
#  'track_type - meeting_id - 0.07829425743076115',
#  'track_type - event_number - 0.012365366714215991',
#  'track_type - distance - 0.04147658787904607',
#  'track_type - distance_raw_furlongs - 0.04057679149722579',
#  'track_type - race_class_normalised - 0.02407205612455765',
#  'track_type - total_prize_money - 0.13233624011169412',
#  'track_type - track_condition - 0.8710681100384566',
#  'track_type - race_type - 0.12891135135132886',
#  'track_type - barrier - 0.03929288814845779',
#  'track_type - number - 0.03351185265701492',
#  'track_type - finish_position - 0.014113905230030525',
#  'track_type - win_or_lose - 0.005514557525508984',
#  'track_type - failed_to_finish_reason - 0.00572140140958421',
#  'track_type - gear - 0.11738113947432094',
#  'track_type - jockey_allowance - 0.046913670386214065',
#  'track_type - handicap_weight - 0.08204733994197765',
#  'track_type - jockey_id - 0.03675565813811337',
#  'track_type - tainer_id - 0.0350842865753144',
#  'track_type - horse_id - 0.08647700171707526',
#  'track_type - age - 0.049666878998752696',
#  'track_type - wfa - 0.004715695965958477',
#  'track_type - weight_adjustment - 0.01709484541113502',
#  'track_type - post_race_master_rating_int - 0.16228358765863443',
#  'track_type - starting_price - 0.04440276635623892',
#  'track_type - run_1_track_type - 0.4066477812703724',
#  'track_type - run_2_track_type - 0.2569891127275117',
#  'track_type - run_3_track_type - 0.1601249348125039',
#  'track_type - run_4_track_type - 0.10054072740327015',
#  'track_type - run_5_final_rating_int - 0.1702927486102423',
#  'track_type - run_5_track_type - 0.06712725702040494',
#  'track_type - dam_id - 0.0018982869987703682',
#  'track_type - sire_id - 0.009832093639030292',
#  'track_type - betfair_starting_price - 0.04027508979726647',
#  'track_type - run_1_race_type - 0.09570634605589357',
#  'track_type - run_1_win_lose - 0.04627107965470216',
#  'track_type - run_1_dsr - 0.01042288327449185',
#  'track_type - dslr - 0.010666060187516332',
#  'track_type - run_1_race_class - 0.06233633140646546',
#  'track_type - pre_race_master_rating_int - 0.20810887193858799',
#  'track_type - run_1_raw_post_race_rating_int - 0.19756906342100003',
#  'track_type - run_1_final_rating_int - 0.19578561193108113',
#  'track_type - margin - 0.0797575332799096',
#  'track_type - run_2_win_lose - 0.054998167866758506',
#  'track_type - run_2_dsr - 0.040232080316105825',
#  'track_type - run_2_race_type - 0.09235400943148486',
#  'track_type - run_2_race_class_normalised - 0.0742063021754792',
#  'track_type - run_2_final_rating_int - 0.1869546056183483',
#  'track_type - run_2_raw_post_race_rating_int - 0.19035913633023824',
#  'track_type - official rating - 0.23833074688589465',
#  'track_type - run_3_win_lose - 0.05508275189255541',
#  'track_type - run_3_dsr - 0.059860730572314856',
#  'track_type - run_3_race_type - 0.08604345733859585',
#  'track_type - run_3_race_class_normalised - 0.07783989573294262',
#  'track_type - run_3_final_rating_int - 0.1795364295181157',
#  'track_type - run_3_raw_post_race_rating_int - 0.18278465931335106',
#  'track_type - run_4_dsr - 0.07001721279469299',
#  'track_type - run_4_win_lose - 0.053947052467163775',
#  'track_type - run_4_race_type - 0.08598818907801117',
#  'track_type - run_4_race_class_normalised - 0.08028934947792402',
#  'track_type - run_4_final_rating_int - 0.1827847181368806',
#  'track_type - run_4_raw_post_race_rating_int - 0.18777817898268798',
#  'track_type - run_5_race_type - 0.08667061777099126',
#  'track_type - run_5_win_lose - 0.06045374035032698',
#  'track_type - run_5_dsr - 0.0785418739545969',
#  'track_type - run_5_race_class_normalised - 0.08146435116959908',
#  'track_type - run_5_raw_post_race_rating_int - 0.19539516040835508',
#  'barrier - Unnamed: 0 - 0.030637374139352858',
#  'barrier - meeting_id - 0.03655160481464671',
#  'barrier - event_number - 0.0323488557509078',
#  'barrier - distance - 0.017023711854707017',
#  'barrier - distance_raw_furlongs - 0.016917083704867164',
#  'barrier - race_class_normalised - 0.014944800682943337',
#  'barrier - total_prize_money - 0.08203822808887516',
#  'barrier - track_condition - 0.02022639601202184',
#  'barrier - race_type - 0.008841102300679375',
#  'barrier - track_type - 0.03929288814845779',
#  'barrier - number - 0.25885854145790443',
#  'barrier - finish_position - 0.2476729618859235',
#  'barrier - win_or_lose - 0.05953554123016105',
#  'barrier - failed_to_finish_reason - 0.00260402620855083',
#  'barrier - gear - 0.0008470378326270523',
#  'barrier - jockey_allowance - 0.00770041383315962',
#  'barrier - handicap_weight - 0.027230120977248782',
#  'barrier - jockey_id - 0.01088278187980711',
#  'barrier - tainer_id - 0.006300981895573734',
#  'barrier - horse_id - 0.04344358960468449',
#  'barrier - age - 0.0202980241225699',
#  'barrier - wfa - 0.004823008809507014',
#  'barrier - weight_adjustment - 0.043119763098095884',
#  'barrier - post_race_master_rating_int - 0.0374750979737469',
#  'barrier - starting_price - 0.09449562430565311',
#  'barrier - run_1_track_type - 0.022293407875963327',
#  'barrier - run_2_track_type - 0.024887428959795704',
#  'barrier - run_3_track_type - 0.028902768651933333',
#  'barrier - run_4_track_type - 0.03182335829696742',
#  'barrier - run_5_final_rating_int - 0.008884799599053268',
#  'barrier - run_5_track_type - 0.03521365113741482',
#  'barrier - dam_id - 0.0011881046849194225',
#  'barrier - sire_id - 0.0017695161219341425',
#  'barrier - betfair_starting_price - 0.06656235777536908',
#  'barrier - run_1_race_type - 0.001957684495975529',
#  'barrier - run_1_win_lose - 0.014828392167540318',
#  'barrier - run_1_dsr - 0.0010974826314861632',
#  'barrier - dslr - 0.001204192553841679',
#  'barrier - run_1_race_class - 0.02050485559602573',
#  'barrier - pre_race_master_rating_int - 0.0014658558681063423',
#  'barrier - run_1_raw_post_race_rating_int - 0.018583383762872642',
#  'barrier - run_1_final_rating_int - 0.00908176012675273',
#  'barrier - margin - 0.060240308725983925',
#  'barrier - run_2_win_lose - 0.011211935471313019',
#  'barrier - run_2_dsr - 0.0005531380852965558',
#  'barrier - run_2_race_type - 0.013434079270788993',
#  'barrier - run_2_race_class_normalised - 0.024550890839472383',
#  'barrier - run_2_final_rating_int - 0.007870124080431905',
#  'barrier - run_2_raw_post_race_rating_int - 0.017431918431284704',
#  'barrier - official rating - 0.014978790053527419',
#  'barrier - run_3_win_lose - 0.008504421177826764',
#  'barrier - run_3_dsr - 0.001394626489371781',
#  'barrier - run_3_race_type - 0.02384591985845199',
#  'barrier - run_3_race_class_normalised - 0.033525963873807484',
#  'barrier - run_3_final_rating_int - 0.00127544758082056',
#  'barrier - run_3_raw_post_race_rating_int - 0.01149195828062086',
#  'barrier - run_4_dsr - 0.0017570216551142893',
#  'barrier - run_4_win_lose - 0.0017247769500078097',
#  'barrier - run_4_race_type - 0.031051618095412035',
#  'barrier - run_4_race_class_normalised - 0.03617687417868863',
#  'barrier - run_4_final_rating_int - 0.0005163007081672283',
#  'barrier - run_4_raw_post_race_rating_int - 0.009913033607062199',
#  'barrier - run_5_race_type - 0.03559483235610873',
#  'barrier - run_5_win_lose - 0.0016440157353283128',
#  'barrier - run_5_dsr - 0.003402837724193523',
#  'barrier - run_5_race_class_normalised - 0.04055798666630144',
#  'barrier - run_5_raw_post_race_rating_int - 0.00828932760057989',
#  'number - Unnamed: 0 - 0.030463707887419512',
#  'number - meeting_id - 0.036164932562860234',
#  'number - event_number - 0.03179858711965647',
#  'number - distance - 0.019509398326936177',
#  'number - distance_raw_furlongs - 0.01940539882940361',
#  'number - race_class_normalised - 0.015090401125944838',
#  'number - total_prize_money - 0.07850618618337857',
#  'number - track_condition - 0.014957438554781372',
#  'number - race_type - 0.007832777736325335',
#  'number - track_type - 0.03351185265701492',
#  'number - barrier - 0.25885854145790443',
#  'number - finish_position - 0.2957794486115657',
#  'number - win_or_lose - 0.10004388022666356',
#  'number - failed_to_finish_reason - 0.005709126899164344',
#  'number - gear - 0.0038964079517358474',
#  'number - jockey_allowance - 0.01051359063629893',
#  'number - handicap_weight - 0.4216765218350822',
#  'number - jockey_id - 0.022190631321827903',
#  'number - tainer_id - 0.005829606084150732',
#  'number - horse_id - 0.005457675892767569',
#  'number - age - 0.018311526206958716',
#  'number - wfa - 0.12945244692371932',
#  'number - weight_adjustment - 0.5456412888362385',
#  'number - post_race_master_rating_int - 0.19349151192045314',
#  'number - starting_price - 0.1798558037066047',
#  'number - run_1_track_type - 0.0023635551720997488',
#  'number - run_2_track_type - 0.002889272991473932',
#  'number - run_3_track_type - 0.006739341264195195',
#  'number - run_4_track_type - 0.008867272884307454',
#  'number - run_5_final_rating_int - 0.00887162614304248',
#  'number - run_5_track_type - 0.005794344455472588',
#  'number - dam_id - 0.016241954386369255',
#  'number - sire_id - 0.0005244875196726588',
#  'number - betfair_starting_price - 0.12716647303928585',
#  'number - run_1_race_type - 0.009873926877700672',
#  'number - run_1_win_lose - 0.0757193972445768',
#  'number - run_1_dsr - 0.011666865117938963',
#  'number - dslr - 0.01169326028181845',
#  'number - run_1_race_class - 0.0010080103985187837',
#  'number - pre_race_master_rating_int - 0.02211486342720077',
#  'number - run_1_raw_post_race_rating_int - 0.15953947102727586',
#  'number - run_1_final_rating_int - 0.023790629264094754',
#  'number - margin - 0.08627361387357906',
#  'number - run_2_win_lose - 0.0510977456416069',
#  'number - run_2_dsr - 0.014656623409880514',
#  'number - run_2_race_type - 0.0016505205908312242',
#  'number - run_2_race_class_normalised - 0.003052513016694075',
#  'number - run_2_final_rating_int - 0.02367837572152454',
#  'number - run_2_raw_post_race_rating_int - 0.1624242681388744',
#  'number - official rating - 0.19637101442464852',
#  'number - run_3_win_lose - 0.050276681680016394',
#  'number - run_3_dsr - 0.012617896412873298',
#  'number - run_3_race_type - 0.018533992876086296',
#  'number - run_3_race_class_normalised - 0.0071940244244999',
#  'number - run_3_final_rating_int - 0.020288236983365047',
#  'number - run_3_raw_post_race_rating_int - 0.16307664808896663',
#  'number - run_4_dsr - 0.012395103308732598',
#  'number - run_4_win_lose - 0.04966155241581879',
#  'number - run_4_race_type - 0.018053288890180513',
#  'number - run_4_race_class_normalised - 0.005588770951402747',
#  'number - run_4_final_rating_int - 0.01864010708826844',
#  'number - run_4_raw_post_race_rating_int - 0.16040938348763298',
#  'number - run_5_race_type - 0.014674694149863506',
#  'number - run_5_win_lose - 0.04763891333926159',
#  'number - run_5_dsr - 0.01229829005909811',
#  'number - run_5_race_class_normalised - 0.0020863069676922883',
#  'number - run_5_raw_post_race_rating_int - 0.15289887840238006',
#  'finish_position - Unnamed: 0 - 0.02536718239232971',
#  'finish_position - meeting_id - 0.031139351563726977',
#  'finish_position - event_number - 0.02266245365368293',
#  'finish_position - distance - 0.024752430729694068',
#  'finish_position - distance_raw_furlongs - 0.024636818544867087',
#  'finish_position - race_class_normalised - 0.014113992040467573',
#  'finish_position - total_prize_money - 0.08150305037714956',
#  'finish_position - track_condition - 0.004020225748740683',
#  'finish_position - race_type - 0.000203864125433265',
#  'finish_position - track_type - 0.014113905230030525',
#  'finish_position - barrier - 0.2476729618859235',
#  'finish_position - number - 0.2957794486115657',
#  'finish_position - win_or_lose - 0.45989399776748147',
#  'finish_position - failed_to_finish_reason - 0.005676693354467752',
#  'finish_position - gear - 0.01610062505988069',
#  'finish_position - jockey_allowance - 0.0370612157534882',
#  'finish_position - handicap_weight - 0.07769972110980022',
#  'finish_position - jockey_id - 0.04408772841518072',
#  'finish_position - tainer_id - 0.007515331134842756',
#  'finish_position - horse_id - 0.0341912315786947',
#  'finish_position - age - 0.03350045463760677',
#  'finish_position - wfa - 0.023644125458925743',
#  'finish_position - weight_adjustment - 0.09876549605969762',
#  'finish_position - post_race_master_rating_int - 0.5059318393351159',
#  'finish_position - starting_price - 0.36347065316133165',
#  'finish_position - run_1_track_type - 0.007286297546603817',
#  'finish_position - run_2_track_type - 0.0075008156955455076',
#  'finish_position - run_3_track_type - 0.015526577368591593',
#  'finish_position - run_4_track_type - 0.018310877951042123',
#  'finish_position - run_5_final_rating_int - 0.006879662722919855',
#  'finish_position - run_5_track_type - 0.019980216511710412',
#  'finish_position - dam_id - 0.00371619081566765',
#  'finish_position - sire_id - 0.002709307705143795',
#  'finish_position - betfair_starting_price - 0.28546134592268435',
#  'finish_position - run_1_race_type - 0.02659004481822573',
#  'finish_position - run_1_win_lose - 0.10341398587997437',
#  'finish_position - run_1_dsr - 0.057855920727632494',
#  'finish_position - dslr - 0.05777714388708835',
#  'finish_position - run_1_race_class - 0.0052948204296351855',
#  'finish_position - pre_race_master_rating_int - 0.12501858232651478',
#  'finish_position - run_1_raw_post_race_rating_int - 0.19149542009151788',
#  'finish_position - run_1_final_rating_int - 0.1600397758313073',
#  'finish_position - margin - 0.43223332495348943',
#  'finish_position - run_2_win_lose - 0.057806936728021355',
#  'finish_position - run_2_dsr - 0.06555841409104622',
#  'finish_position - run_2_race_type - 0.004139565692464062',
#  'finish_position - run_2_race_class_normalised - 0.00048211743333528514',
#  'finish_position - run_2_final_rating_int - 0.12165296851527821',
#  'finish_position - run_2_raw_post_race_rating_int - 0.15209408402513422',
#  'finish_position - official rating - 0.11217242776376421',
#  'finish_position - run_3_win_lose - 0.041609101682412206',
#  'finish_position - run_3_dsr - 0.06915851141834739',
#  'finish_position - run_3_race_type - 0.009049073434312159',
#  'finish_position - run_3_race_class_normalised - 0.009255126427595758',
#  'finish_position - run_3_final_rating_int - 0.08449260383120541',
#  'finish_position - run_3_raw_post_race_rating_int - 0.11723389736636737',
#  'finish_position - run_4_dsr - 0.07200518402604754',
#  'finish_position - run_4_win_lose - 0.025151022512259105',
#  'finish_position - run_4_race_type - 0.01009419043990652',
#  'finish_position - run_4_race_class_normalised - 0.010835721125692737',
#  'finish_position - run_4_final_rating_int - 0.06392863660510792',
#  'finish_position - run_4_raw_post_race_rating_int - 0.09640917660567637',
#  'finish_position - run_5_race_type - 0.011498341335961677',
#  'finish_position - run_5_win_lose - 0.019615243951108762',
#  'finish_position - run_5_dsr - 0.06715769452850931',
#  'finish_position - run_5_race_class_normalised - 0.01458874077844461',
#  'finish_position - run_5_raw_post_race_rating_int - 0.08712036277388989',
#  'win_or_lose - Unnamed: 0 - 0.006554757784340701',
#  'win_or_lose - meeting_id - 0.008943114243776085',
#  'win_or_lose - event_number - 0.006531059426357919',
#  'win_or_lose - distance - 0.007320235861314469',
#  'win_or_lose - distance_raw_furlongs - 0.007287227549235144',
#  'win_or_lose - race_class_normalised - 1.4569220456194218e-05',
#  'win_or_lose - total_prize_money - 0.009871759719769384',
#  'win_or_lose - track_condition - 0.006857371042217697',
#  'win_or_lose - race_type - 0.0013718783043771144',
#  'win_or_lose - track_type - 0.005514557525508984',
#  'win_or_lose - barrier - 0.05953554123016105',
#  'win_or_lose - number - 0.10004388022666356',
#  'win_or_lose - finish_position - 0.45989399776748147',
#  'win_or_lose - failed_to_finish_reason - 0.02162402996529993',
#  'win_or_lose - gear - 0.01779580586797756',
#  'win_or_lose - jockey_allowance - 0.02824073180537352',
#  'win_or_lose - handicap_weight - 0.04478583582970136',
#  'win_or_lose - jockey_id - 0.029957149803685544',
#  'win_or_lose - tainer_id - 0.007419841525052786',
#  'win_or_lose - horse_id - 0.011905598010132067',
#  'win_or_lose - age - 0.022401510778758037',
#  'win_or_lose - wfa - 0.017178040842037376',
#  'win_or_lose - weight_adjustment - 0.05847768197850022',
#  'win_or_lose - post_race_master_rating_int - 0.31560203241910145',
#  'win_or_lose - starting_price - 0.15433596395045587',
#  'win_or_lose - run_1_track_type - 0.01966897587821736',
#  'win_or_lose - run_2_track_type - 0.011294645092878267',
#  'win_or_lose - run_3_track_type - 0.0050163053121397875',
#  'win_or_lose - run_4_track_type - 0.0006717295249385012',
#  'win_or_lose - run_5_final_rating_int - 0.007568554463975447',
#  'win_or_lose - run_5_track_type - 0.002061074094587537',
#  'win_or_lose - dam_id - 0.002800726114068315',
#  'win_or_lose - sire_id - 0.0038120552370004023',
#  'win_or_lose - betfair_starting_price - 0.10521168091898973',
#  'win_or_lose - run_1_race_type - 0.026842472334901925',
#  'win_or_lose - run_1_win_lose - 0.09289144094843081',
#  'win_or_lose - run_1_dsr - 0.01933460485756697',
#  'win_or_lose - dslr - 0.01916531096316857',
#  'win_or_lose - run_1_race_class - 0.0113079716754029',
#  'win_or_lose - pre_race_master_rating_int - 0.09833097618721935',
#  'win_or_lose - run_1_raw_post_race_rating_int - 0.13767836447096038',
#  'win_or_lose - run_1_final_rating_int - 0.11872641552350209',
#  'win_or_lose - margin - 0.003385797379355018',
#  'win_or_lose - run_2_win_lose - 0.046547897615239295',
#  'win_or_lose - run_2_dsr - 0.019317118041051726',
#  'win_or_lose - run_2_race_type - 0.015049617510404265',
#  'win_or_lose - run_2_race_class_normalised - 0.006381471597629046',
#  'win_or_lose - run_2_final_rating_int - 0.09536396601357593',
#  'win_or_lose - run_2_raw_post_race_rating_int - 0.11303188793322692',
#  'win_or_lose - official rating - 0.08692802684496956',
#  'win_or_lose - run_3_win_lose - 0.03429702457988422',
#  'win_or_lose - run_3_dsr - 0.015751330268434185',
#  'win_or_lose - run_3_race_type - 0.006589956552157888',
#  'win_or_lose - run_3_race_class_normalised - 0.0028307287542850804',
#  'win_or_lose - run_3_final_rating_int - 0.07319641945084508',
#  'win_or_lose - run_3_raw_post_race_rating_int - 0.09213733521445237',
#  'win_or_lose - run_4_dsr - 0.015406183633089883',
#  'win_or_lose - run_4_win_lose - 0.022859286182137683',
#  'win_or_lose - run_4_race_type - 0.002241136987402438',
#  'win_or_lose - run_4_race_class_normalised - 0.00587473513926173',
#  'win_or_lose - run_4_final_rating_int - 0.053228986138082586',
#  'win_or_lose - run_4_raw_post_race_rating_int - 0.07273980506732657',
#  'win_or_lose - run_5_race_type - 0.00553983096637018',
#  'win_or_lose - run_5_win_lose - 0.01900654608203492',
#  'win_or_lose - run_5_dsr - 0.012507253032074093',
#  'win_or_lose - run_5_race_class_normalised - 0.009970682714737326',
#  'win_or_lose - run_5_raw_post_race_rating_int - 0.06807474716283883',
#  'failed_to_finish_reason - Unnamed: 0 - 0.003642010728211993',
#  'failed_to_finish_reason - meeting_id - 0.004504974934450323',
#  'failed_to_finish_reason - event_number - 0.01779096448243123',
#  'failed_to_finish_reason - distance - 0.04344463957762443',
#  'failed_to_finish_reason - distance_raw_furlongs - 0.043464345514017094',
#  'failed_to_finish_reason - race_class_normalised - 0.008552068524860658',
#  'failed_to_finish_reason - total_prize_money - 5.462090186694907e-05',
#  'failed_to_finish_reason - track_condition - 0.002401153709458252',
#  'failed_to_finish_reason - race_type - 0.05162650740995742',
#  'failed_to_finish_reason - track_type - 0.00572140140958421',
#  'failed_to_finish_reason - barrier - 0.00260402620855083',
#  'failed_to_finish_reason - number - 0.005709126899164344',
#  'failed_to_finish_reason - finish_position - 0.005676693354467752',
#  'failed_to_finish_reason - win_or_lose - 0.02162402996529993',
#  'failed_to_finish_reason - gear - 0.0009013780467293227',
#  'failed_to_finish_reason - jockey_allowance - 0.010854086842480033',
#  'failed_to_finish_reason - handicap_weight - 0.031162485387735042',
#  'failed_to_finish_reason - jockey_id - 0.009034108200596752',
#  'failed_to_finish_reason - tainer_id - 0.0022655622738743312',
#  'failed_to_finish_reason - horse_id - 0.0012656539468096726',
#  'failed_to_finish_reason - age - 0.009917205785339306',
#  'failed_to_finish_reason - wfa - 0.000851583948236518',
#  'failed_to_finish_reason - weight_adjustment - 0.009013036455206458',
#  'failed_to_finish_reason - post_race_master_rating_int - 0.02233886599167054',
#  'failed_to_finish_reason - starting_price - 0.015597233269079303',
#  'failed_to_finish_reason - run_1_track_type - 0.008145638602575498',
#  'failed_to_finish_reason - run_2_track_type - 0.007404417828121521',
#  'failed_to_finish_reason - run_3_track_type - 0.0083283117519136',
#  'failed_to_finish_reason - run_4_track_type - 0.008954913167859749',
#  'failed_to_finish_reason - run_5_final_rating_int - 0.001597499638884717',
#  'failed_to_finish_reason - run_5_track_type - 0.009525748036364419',
#  'failed_to_finish_reason - dam_id - 0.0007650394159880135',
#  'failed_to_finish_reason - sire_id - 0.004353590632827457',
#  'failed_to_finish_reason - betfair_starting_price - 0.017996224485858858',
#  'failed_to_finish_reason - run_1_race_type - 0.024633222081912657',
#  'failed_to_finish_reason - run_1_win_lose - 0.0015650813530821552',
#  'failed_to_finish_reason - run_1_dsr - 0.013046129076917152',
#  'failed_to_finish_reason - dslr - 0.01311948347961443',
#  'failed_to_finish_reason - run_1_race_class - 0.012510924605767535',
#  'failed_to_finish_reason - pre_race_master_rating_int - 0.0013456469497513347',
#  'failed_to_finish_reason - run_1_raw_post_race_rating_int - 0.004586168652396792',
#  'failed_to_finish_reason - run_1_final_rating_int - 0.005570802087368559',
#  'failed_to_finish_reason - margin - 0.022409299479146615',
#  'failed_to_finish_reason - run_2_win_lose - 0.0012086675323241356',
#  'failed_to_finish_reason - run_2_dsr - 0.016648269228120433',
#  'failed_to_finish_reason - run_2_race_type - 0.018129581325353784',
#  'failed_to_finish_reason - run_2_race_class_normalised - 0.013140666985498125',
#  'failed_to_finish_reason - run_2_final_rating_int - 0.004111592172988916',
#  'failed_to_finish_reason - run_2_raw_post_race_rating_int - 0.0035139025162461437',
#  'failed_to_finish_reason - official rating - 0.0029028557068665065',
#  'failed_to_finish_reason - run_3_win_lose - 0.0030816493850947895',
#  'failed_to_finish_reason - run_3_dsr - 0.01899946090245346',
#  'failed_to_finish_reason - run_3_race_type - 0.015030315715154959',
#  'failed_to_finish_reason - run_3_race_class_normalised - 0.011191787980815122',
#  'failed_to_finish_reason - run_3_final_rating_int - 0.00016648171241429494',
#  'failed_to_finish_reason - run_3_raw_post_race_rating_int - 4.665836003800815e-05',
#  'failed_to_finish_reason - run_4_dsr - 0.020514591573211345',
#  'failed_to_finish_reason - run_4_win_lose - 4.773716685851063e-05',
#  'failed_to_finish_reason - run_4_race_type - 0.01231039040609271',
#  'failed_to_finish_reason - run_4_race_class_normalised - 0.010584826717786568',
#  'failed_to_finish_reason - run_4_final_rating_int - 0.0015523000399250918',
#  'failed_to_finish_reason - run_4_raw_post_race_rating_int - 0.0018047630851350993',
#  ...]
