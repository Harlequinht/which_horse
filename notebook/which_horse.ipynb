# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder

# %%
# !pwd
# Out:
# /Users/jubba/Downloads

# %%
file_csv = '/Users/jubba/Downloads/jumper.csv'

# %%
df_jump = pd.read_csv(file_csv)
df_jump
# Out:
# /var/folders/y1/7l27jzt92cs7ljtj5xn5sd3h0000gn/T/ipykernel_28287/1112610063.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_jump = pd.read_csv(file_csv)
#        Unnamed: 0  meeting_id meeting_name        date country_code  \
# 0               0       28883     FONTWELL  2021-10-01          GBR
# 1               1       28883     FONTWELL  2021-10-01          GBR
# 2               2       28883     FONTWELL  2021-10-01          GBR
# 3               3       28883     FONTWELL  2021-10-01          GBR
# 4               4       28883     FONTWELL  2021-10-01          GBR
# ...           ...         ...          ...         ...          ...
# 81634      409633        9975        PERTH  2019-09-26          GBR
# 81635      409634        9975        PERTH  2019-09-26          GBR
# 81636      409635        9975        PERTH  2019-09-26          GBR
# 81637      409636        9975        PERTH  2019-09-26          GBR
# 81638      409637        9975        PERTH  2019-09-26          GBR
#
#        event_number  distance distance_unit distance_furlongs  \
# 0                 1      3902         yards            2m1.5f
# 1                 1      3902         yards            2m1.5f
# 2                 1      3902         yards            2m1.5f
# 3                 1      3902         yards            2m1.5f
# 4                 1      3902         yards            2m1.5f
# ...             ...       ...           ...               ...
# 81634             7      5267         yards              2m8f
# 81635             7      5267         yards              2m8f
# 81636             7      5267         yards              2m8f
# 81637             7      5267         yards              2m8f
# 81638             7      5267         yards              2m8f
#
#        distance_raw_furlongs  ... run_7_dsr run_8_raw_post_race_rating_int  \
# 0                       17.7  ...       NaN                            NaN
# 1                       17.7  ...       NaN                            NaN
# 2                       17.7  ...     197.0                           69.0
# 3                       17.7  ...       NaN                            NaN
# 4                       17.7  ...    1463.0                            NaN
# ...                      ...  ...       ...                            ...
# 81634                   23.9  ...     298.0                            NaN
# 81635                   23.9  ...     249.0                           85.0
# 81636                   23.9  ...     193.0                            NaN
# 81637                   23.9  ...     364.0                            NaN
# 81638                   23.9  ...     214.0                           76.0
#
#       run_8_raw_post_race_rating_symbol  run_8_final_rating_int  \
# 0                                   NaN                     NaN
# 1                                   NaN                     NaN
# 2                                   NaN                    85.0
# 3                                   NaN                     NaN
# 4                                   NaN                     NaN
# ...                                 ...                     ...
# 81634                               NaN                     NaN
# 81635                               NaN                    90.0
# 81636                               NaN                     NaN
# 81637                               NaN                     NaN
# 81638                               NaN                   103.0
#
#           run_8_race_type run_8_race_class run_8_race_class_normalised  \
# 0                     NaN              NaN                         NaN
# 1                     NaN              NaN                         NaN
# 2      NATIONAL_HUNT_FLAT                4                         NHF
# 3                     NaN              NaN                         NaN
# 4                    FLAT              NaN                         NaN
# ...                   ...              ...                         ...
# 81634        STEEPLECHASE              4.0                    Handicap
# 81635                JUMP              5.0                    Handicap
# 81636                JUMP              NaN                    Handicap
# 81637  NATIONAL_HUNT_FLAT              4.0                         NHF
# 81638                JUMP              5.0                    Handicap
#
#        run_8_track_type  run_8_win_lose  run_8_dsr
# 0                   NaN             NaN        NaN
# 1                   NaN             NaN        NaN
# 2                  TURF             0.0      348.0
# 3                   NaN             NaN        NaN
# 4                  TURF             0.0     1515.0
# ...                 ...             ...        ...
# 81634              TURF             1.0      348.0
# 81635              TURF             0.0      273.0
# 81636              TURF             0.0      214.0
# 81637              TURF             0.0      381.0
# 81638              TURF             0.0      261.0
#
# [81639 rows x 122 columns]

# %%
df_columns = list(df_jump.columns)
df_columns
# Out:
# ['Unnamed: 0',
#  'meeting_id',
#  'meeting_name',
#  'date',
#  'country_code',
#  'event_number',
#  'distance',
#  'distance_unit',
#  'distance_furlongs',
#  'distance_raw_furlongs',
#  'race_class',
#  'race_class_normalised',
#  'prize_money_currency',
#  'total_prize_money',
#  'track_condition',
#  'race_type',
#  'track_type',
#  'barrier',
#  'number',
#  'finish_position',
#  'win_or_lose',
#  'failed_to_finish_reason',
#  'margin',
#  'gear',
#  'jockey_allowance',
#  'jockey_allowance_unit',
#  'handicap_weight',
#  'handicap_weight_unit',
#  'jockey_id',
#  'jockey_name',
#  'tainer_id',
#  'trainer_name',
#  'dslr',
#  'horse_id',
#  'horse_name',
#  'sire',
#  'dam',
#  'age',
#  'birth_date',
#  'official rating',
#  'wfa',
#  'weight_adjustment',
#  'bet365_odds',
#  'pmu_odds',
#  'betfair_starting_price',
#  'pre_race_master_rating_int',
#  'pre_race_master_rating_symbol',
#  'post_race_master_rating_int',
#  'post_race_master_rating_symbol',
#  'starting_price',
#  'run_1_raw_post_race_rating_int',
#  'run_1_raw_post_race_rating_symbol',
#  'run_1_final_rating_int',
#  'run_1_race_type',
#  'run_1_race_class_normalised',
#  'run_1_race_class',
#  'run_1_track_type',
#  'run_1_win_lose',
#  'run_1_dsr',
#  'run_2_raw_post_race_rating_int',
#  'run_2_raw_post_race_rating_symbol',
#  'run_2_final_rating_int',
#  'run_2_race_type',
#  'run_2_race_class',
#  'run_2_race_class_normalised',
#  'run_2_track_type',
#  'run_2_win_lose',
#  'run_2_dsr',
#  'run_3_raw_post_race_rating_int',
#  'run_3_raw_post_race_rating_symbol',
#  'run_3_final_rating_int',
#  'run_3_race_type',
#  'run_3_race_class',
#  'run_3_race_class_normalised',
#  'run_3_track_type',
#  'run_3_win_lose',
#  'run_3_dsr',
#  'run_4_raw_post_race_rating_int',
#  'run_4_raw_post_race_rating_symbol',
#  'run_4_final_rating_int',
#  'run_4_race_type',
#  'run_4_race_class',
#  'run_4_race_class_normalised',
#  'run_4_track_type',
#  'run_4_win_lose',
#  'run_4_dsr',
#  'run_5_raw_post_race_rating_int',
#  'run_5_raw_post_race_rating_symbol',
#  'run_5_final_rating_int',
#  'run_5_race_type',
#  'run_5_race_class',
#  'run_5_race_class_normalised',
#  'run_5_track_type',
#  'run_5_win_lose',
#  'run_5_dsr',
#  'run_6_raw_post_race_rating_int',
#  'run_6_raw_post_race_rating_symbol',
#  'run_6_final_rating_int',
#  'run_6_race_type',
#  'run_6_race_class',
#  'run_6_race_class_normalised',
#  'run_6_track_type',
#  'run_6_win_lose',
#  'run_6_dsr',
#  'run_7_raw_post_race_rating_int',
#  'run_7_raw_post_race_rating_symbol',
#  'run_7_final_rating_int',
#  'run_7_race_type',
#  'run_7_race_class',
#  'run_7_race_class_normalised',
#  'run_7_track_type',
#  'run_7_win_lose',
#  'run_7_dsr',
#  'run_8_raw_post_race_rating_int',
#  'run_8_raw_post_race_rating_symbol',
#  'run_8_final_rating_int',
#  'run_8_race_type',
#  'run_8_race_class',
#  'run_8_race_class_normalised',
#  'run_8_track_type',
#  'run_8_win_lose',
#  'run_8_dsr']

# %%
df_jump.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81639 entries, 0 to 81638
# Columns: 122 entries, Unnamed: 0 to run_8_dsr
# dtypes: float64(48), int64(11), object(63)
# memory usage: 76.0+ MB

# %% [markdown]
# **JUMPER**

# %%
df_jump = df_jump.drop(columns=['run_6_raw_post_race_rating_int',
 'run_6_raw_post_race_rating_symbol',
 'run_6_final_rating_int',
 'run_6_race_type',
 'run_6_race_class',
 'run_6_race_class_normalised',
 'run_6_track_type',
 'run_6_win_lose',
 'run_6_dsr',
 'run_7_raw_post_race_rating_int',
 'run_7_raw_post_race_rating_symbol',
 'run_7_final_rating_int',
 'run_7_race_type',
 'run_7_race_class',
 'run_7_race_class_normalised',
 'run_7_track_type',
 'run_7_win_lose',
 'run_7_dsr',
 'run_8_raw_post_race_rating_int',
 'run_8_raw_post_race_rating_symbol',
 'run_8_final_rating_int',
 'run_8_race_type',
 'run_8_race_class',
 'run_8_race_class_normalised',
 'run_8_track_type',
 'run_8_win_lose',
 'run_8_dsr'])
#races from 6 7 8 droped master rating on cureent race
#only applicable to previous 5 races or races in the last 365 days

# %%
df_jump['date']
# Out:
# 0        2021-10-01
# 1        2021-10-01
# 2        2021-10-01
# 3        2021-10-01
# 4        2021-10-01
#             ...
# 81634    2019-09-26
# 81635    2019-09-26
# 81636    2019-09-26
# 81637    2019-09-26
# 81638    2019-09-26
# Name: date, Length: 81639, dtype: object

# %%
df_jump['date'] = pd.to_datetime(df_jump['date'])

# %%
df_jump['year'] = df_jump['date'].dt.year

# %%
df_jump
# Out:
#        Unnamed: 0  meeting_id meeting_name       date country_code  \
# 0               0       28883     FONTWELL 2021-10-01          GBR
# 1               1       28883     FONTWELL 2021-10-01          GBR
# 2               2       28883     FONTWELL 2021-10-01          GBR
# 3               3       28883     FONTWELL 2021-10-01          GBR
# 4               4       28883     FONTWELL 2021-10-01          GBR
# ...           ...         ...          ...        ...          ...
# 81634      409633        9975        PERTH 2019-09-26          GBR
# 81635      409634        9975        PERTH 2019-09-26          GBR
# 81636      409635        9975        PERTH 2019-09-26          GBR
# 81637      409636        9975        PERTH 2019-09-26          GBR
# 81638      409637        9975        PERTH 2019-09-26          GBR
#
#        event_number  distance distance_unit distance_furlongs  \
# 0                 1      3902         yards            2m1.5f
# 1                 1      3902         yards            2m1.5f
# 2                 1      3902         yards            2m1.5f
# 3                 1      3902         yards            2m1.5f
# 4                 1      3902         yards            2m1.5f
# ...             ...       ...           ...               ...
# 81634             7      5267         yards              2m8f
# 81635             7      5267         yards              2m8f
# 81636             7      5267         yards              2m8f
# 81637             7      5267         yards              2m8f
# 81638             7      5267         yards              2m8f
#
#        distance_raw_furlongs  ... run_5_raw_post_race_rating_int  \
# 0                       17.7  ...                            NaN
# 1                       17.7  ...                            NaN
# 2                       17.7  ...                           49.0
# 3                       17.7  ...                            NaN
# 4                       17.7  ...                            NaN
# ...                      ...  ...                            ...
# 81634                   23.9  ...                           95.0
# 81635                   23.9  ...                           90.0
# 81636                   23.9  ...                            NaN
# 81637                   23.9  ...                           83.0
# 81638                   23.9  ...                           71.0
#
#       run_5_raw_post_race_rating_symbol run_5_final_rating_int  \
# 0                                   NaN                    NaN
# 1                                   NaN                    NaN
# 2                                   NaN                   65.0
# 3                                   NaN                    NaN
# 4                                   NaN                    NaN
# ...                                 ...                    ...
# 81634                               NaN                   97.0
# 81635                                ++                   95.0
# 81636                               NaN                    NaN
# 81637                               NaN                  106.0
# 81638                               NaN                   98.0
#
#        run_5_race_type run_5_race_class run_5_race_class_normalised  \
# 0                  NaN              NaN                         NaN
# 1                 FLAT              NaN                         NaN
# 2                 FLAT                5                      Novice
# 3                  NaN              NaN                         NaN
# 4                 FLAT           LISTED                         NaN
# ...                ...              ...                         ...
# 81634             JUMP              5.0                    Handicap
# 81635             JUMP              5.0                    Handicap
# 81636             JUMP              4.0                    Handicap
# 81637             JUMP              4.0                      Maiden
# 81638             JUMP              5.0                    Handicap
#
#       run_5_track_type  run_5_win_lose  run_5_dsr  year
# 0                  NaN             NaN        NaN  2021
# 1                 TURF             0.0      415.0  2021
# 2                 TURF             0.0      116.0  2021
# 3                  NaN             NaN        NaN  2021
# 4                 TURF             1.0     1251.0  2021
# ...                ...             ...        ...   ...
# 81634             TURF             0.0      280.0  2019
# 81635             TURF             1.0      122.0  2019
# 81636             TURF             0.0      154.0  2019
# 81637             TURF             0.0      291.0  2019
# 81638             TURF             0.0      117.0  2019
#
# [81639 rows x 96 columns]

# %%
df_jump['year'].unique()
# Out:
# array([2021, 2023, 2020, 2019, 2022], dtype=int32)

# %%
mask2021 = df_jump['year'] == 2021
df_jump_2021 = df_jump[mask2021]
df_jump_2021
# Out:
#        Unnamed: 0  meeting_id meeting_name       date country_code  \
# 0               0       28883     FONTWELL 2021-10-01          GBR
# 1               1       28883     FONTWELL 2021-10-01          GBR
# 2               2       28883     FONTWELL 2021-10-01          GBR
# 3               3       28883     FONTWELL 2021-10-01          GBR
# 4               4       28883     FONTWELL 2021-10-01          GBR
# ...           ...         ...          ...        ...          ...
# 80089      393267       26512    NEWCASTLE 2021-03-30          GBR
# 80090      393268       26512    NEWCASTLE 2021-03-30          GBR
# 80091      393269       26512    NEWCASTLE 2021-03-30          GBR
# 80092      393270       26512    NEWCASTLE 2021-03-30          GBR
# 80093      393271       26512    NEWCASTLE 2021-03-30          GBR
#
#        event_number  distance distance_unit distance_furlongs  \
# 0                 1      3902         yards            2m1.5f
# 1                 1      3902         yards            2m1.5f
# 2                 1      3902         yards            2m1.5f
# 3                 1      3902         yards            2m1.5f
# 4                 1      3902         yards            2m1.5f
# ...             ...       ...           ...               ...
# 80089             8      5209         yards            2m7.5f
# 80090             8      5209         yards            2m7.5f
# 80091             8      5209         yards            2m7.5f
# 80092             8      5209         yards            2m7.5f
# 80093             8      5209         yards            2m7.5f
#
#        distance_raw_furlongs  ... run_5_raw_post_race_rating_int  \
# 0                       17.7  ...                            NaN
# 1                       17.7  ...                            NaN
# 2                       17.7  ...                           49.0
# 3                       17.7  ...                            NaN
# 4                       17.7  ...                            NaN
# ...                      ...  ...                            ...
# 80089                   23.7  ...                           55.0
# 80090                   23.7  ...                            NaN
# 80091                   23.7  ...                           55.0
# 80092                   23.7  ...                           25.0
# 80093                   23.7  ...                           55.0
#
#       run_5_raw_post_race_rating_symbol run_5_final_rating_int  \
# 0                                   NaN                    NaN
# 1                                   NaN                    NaN
# 2                                   NaN                   65.0
# 3                                   NaN                    NaN
# 4                                   NaN                    NaN
# ...                                 ...                    ...
# 80089                               NaN                   73.0
# 80090                               NaN                    NaN
# 80091                               NaN                   79.0
# 80092                               NaN                   53.0
# 80093                               NaN                   83.0
#
#        run_5_race_type run_5_race_class run_5_race_class_normalised  \
# 0                  NaN              NaN                         NaN
# 1                 FLAT              NaN                         NaN
# 2                 FLAT                5                      Novice
# 3                  NaN              NaN                         NaN
# 4                 FLAT           LISTED                         NaN
# ...                ...              ...                         ...
# 80089             JUMP                4                      Novice
# 80090              NaN              NaN                         NaN
# 80091             JUMP                5                    Handicap
# 80092             FLAT                6                    Handicap
# 80093             JUMP                5                    Handicap
#
#       run_5_track_type  run_5_win_lose  run_5_dsr  year
# 0                  NaN             NaN        NaN  2021
# 1                 TURF             0.0      415.0  2021
# 2                 TURF             0.0      116.0  2021
# 3                  NaN             NaN        NaN  2021
# 4                 TURF             1.0     1251.0  2021
# ...                ...             ...        ...   ...
# 80089             TURF             0.0      541.0  2021
# 80090              NaN             NaN        NaN  2021
# 80091             TURF             0.0      501.0  2021
# 80092             TURF             0.0      175.0  2021
# 80093             TURF             0.0      156.0  2021
#
# [18673 rows x 96 columns]

# %%
mask2022 = df_jump['year'] == 2022
df_jump_2022 = df_jump[mask2022]
df_jump_2022
# Out:
#        Unnamed: 0  meeting_id meeting_name       date country_code  \
# 25643      125419       30058    NEWCASTLE 2022-02-01          GBR
# 25644      125420       30058    NEWCASTLE 2022-02-01          GBR
# 25645      125421       30058    NEWCASTLE 2022-02-01          GBR
# 25646      125422       30058    NEWCASTLE 2022-02-01          GBR
# 25647      125423       30058    NEWCASTLE 2022-02-01          GBR
# ...           ...         ...          ...        ...          ...
# 75124      379356       34950      HAYDOCK 2022-11-30          GBR
# 75125      379366       34950      HAYDOCK 2022-11-30          GBR
# 75126      379367       34950      HAYDOCK 2022-11-30          GBR
# 75127      379368       34950      HAYDOCK 2022-11-30          GBR
# 75128      379369       34950      HAYDOCK 2022-11-30          GBR
#
#        event_number  distance distance_unit distance_furlongs  \
# 25643             2      4840         yards              2m6f
# 25644             2      4840         yards              2m6f
# 25645             2      4840         yards              2m6f
# 25646             2      4840         yards              2m6f
# 25647             2      4840         yards              2m6f
# ...             ...       ...           ...               ...
# 75124             4      3444         yards            1m7.5f
# 75125             6      4151         yards              2m3f
# 75126             6      4151         yards              2m3f
# 75127             6      4151         yards              2m3f
# 75128             6      4151         yards              2m3f
#
#        distance_raw_furlongs  ... run_5_raw_post_race_rating_int  \
# 25643                   22.0  ...                            NaN
# 25644                   22.0  ...                            NaN
# 25645                   22.0  ...                            NaN
# 25646                   22.0  ...                            NaN
# 25647                   22.0  ...                           81.0
# ...                      ...  ...                            ...
# 75124                   15.7  ...                           68.0
# 75125                   18.9  ...                            NaN
# 75126                   18.9  ...                          106.0
# 75127                   18.9  ...                            NaN
# 75128                   18.9  ...                          105.0
#
#       run_5_raw_post_race_rating_symbol run_5_final_rating_int  \
# 25643                               NaN                    NaN
# 25644                               NaN                    NaN
# 25645                               NaN                    NaN
# 25646                               NaN                    NaN
# 25647                               NaN                   92.0
# ...                                 ...                    ...
# 75124                               NaN                   80.0
# 75125                               NaN                    NaN
# 75126                               NaN                  106.0
# 75127                               NaN                    NaN
# 75128                               NaN                  112.0
#
#           run_5_race_type run_5_race_class run_5_race_class_normalised  \
# 25643                JUMP                4                    Handicap
# 25644  NATIONAL_HUNT_FLAT                5                         NHF
# 25645                JUMP                4                      Novice
# 25646                JUMP                5                    Handicap
# 25647  NATIONAL_HUNT_FLAT                4                         NHF
# ...                   ...              ...                         ...
# 75124                FLAT                4                    Handicap
# 75125                 NaN              NaN                         NaN
# 75126        STEEPLECHASE                2                    Handicap
# 75127                 NaN              NaN                         NaN
# 75128  NATIONAL_HUNT_FLAT                5                         NHF
#
#       run_5_track_type  run_5_win_lose  run_5_dsr  year
# 25643             TURF             0.0      350.0  2022
# 25644              AWT             1.0      355.0  2022
# 25645             TURF             0.0      272.0  2022
# 25646             TURF             0.0      297.0  2022
# 25647             TURF             0.0      188.0  2022
# ...                ...             ...        ...   ...
# 75124             TURF             0.0      422.0  2022
# 75125              NaN             NaN        NaN  2022
# 75126             TURF             0.0      389.0  2022
# 75127              NaN             NaN        NaN  2022
# 75128             TURF             0.0      366.0  2022
#
# [17574 rows x 96 columns]

# %%
mask2023 = df_jump['year'] == 2023
df_jump_2023 = df_jump[mask2023]
df_jump_2023
# Out:
#        Unnamed: 0  meeting_id meeting_name       date country_code  \
# 1771         8631       36297    UTTOXETER 2023-04-01          GBR
# 1772         8632       36297    UTTOXETER 2023-04-01          GBR
# 1773         8633       36297    UTTOXETER 2023-04-01          GBR
# 1774         8634       36297    UTTOXETER 2023-04-01          GBR
# 1775         8635       36297    UTTOXETER 2023-04-01          GBR
# ...           ...         ...          ...        ...          ...
# 77323      385805       36293     WETHERBY 2023-03-31          GBR
# 77324      385806       36293     WETHERBY 2023-03-31          GBR
# 77325      385807       36293     WETHERBY 2023-03-31          GBR
# 77326      385808       36293     WETHERBY 2023-03-31          GBR
# 77327      385809       36293     WETHERBY 2023-03-31          GBR
#
#        event_number  distance distance_unit distance_furlongs  \
# 1771              1      3468         yards              1m8f
# 1772              1      3468         yards              1m8f
# 1773              1      3468         yards              1m8f
# 1774              1      3468         yards              1m8f
# 1775              1      3468         yards              1m8f
# ...             ...       ...           ...               ...
# 77323             4      3520         yards              2m0f
# 77324             4      3520         yards              2m0f
# 77325             4      3520         yards              2m0f
# 77326             4      3520         yards              2m0f
# 77327             4      3520         yards              2m0f
#
#        distance_raw_furlongs  ... run_5_raw_post_race_rating_int  \
# 1771                    15.8  ...                            NaN
# 1772                    15.8  ...                           96.0
# 1773                    15.8  ...                           98.0
# 1774                    15.8  ...                           55.0
# 1775                    15.8  ...                           55.0
# ...                      ...  ...                            ...
# 77323                   16.0  ...                            NaN
# 77324                   16.0  ...                          130.0
# 77325                   16.0  ...                           98.0
# 77326                   16.0  ...                           92.0
# 77327                   16.0  ...                           98.0
#
#       run_5_raw_post_race_rating_symbol run_5_final_rating_int  \
# 1771                                NaN                    NaN
# 1772                                NaN                   96.0
# 1773                                  +                  102.0
# 1774                                NaN                   63.0
# 1775                                NaN                   71.0
# ...                                 ...                    ...
# 77323                               NaN                    NaN
# 77324                               NaN                  139.0
# 77325                               NaN                  110.0
# 77326                               NaN                  110.0
# 77327                               NaN                  117.0
#
#           run_5_race_type run_5_race_class run_5_race_class_normalised  \
# 1771         STEEPLECHASE                5                    Handicap
# 1772                 JUMP                5                      Novice
# 1773                 JUMP                4                    Handicap
# 1774   NATIONAL_HUNT_FLAT                5                         NHF
# 1775                 JUMP                5                    Handicap
# ...                   ...              ...                         ...
# 77323                 NaN              NaN                         NaN
# 77324                JUMP                1                      Listed
# 77325        STEEPLECHASE                1                     Grade 2
# 77326                JUMP                3                    Handicap
# 77327                JUMP                4                    Handicap
#
#       run_5_track_type  run_5_win_lose  run_5_dsr  year
# 1771              TURF             0.0       86.0  2023
# 1772              TURF             1.0      385.0  2023
# 1773              TURF             0.0      229.0  2023
# 1774              TURF             0.0      477.0  2023
# 1775              TURF             0.0      132.0  2023
# ...                ...             ...        ...   ...
# 77323              NaN             NaN        NaN  2023
# 77324             TURF             0.0      132.0  2023
# 77325             TURF             0.0      146.0  2023
# 77326             TURF             0.0      139.0  2023
# 77327             TURF             0.0      143.0  2023
#
# [12076 rows x 96 columns]

# %%
mask2019 = df_jump['year'] == 2019
df_jump_2019 = df_jump[mask2019]
df_jump_2019
# Out:
#        Unnamed: 0  meeting_id meeting_name       date country_code  \
# 14161       58323        7437       LUDLOW 2019-04-01          GBR
# 14162       58324        7437       LUDLOW 2019-04-01          GBR
# 14163       58325        7437       LUDLOW 2019-04-01          GBR
# 14164       58326        7437       LUDLOW 2019-04-01          GBR
# 14165       58327        7437       LUDLOW 2019-04-01          GBR
# ...           ...         ...          ...        ...          ...
# 81634      409633        9975        PERTH 2019-09-26          GBR
# 81635      409634        9975        PERTH 2019-09-26          GBR
# 81636      409635        9975        PERTH 2019-09-26          GBR
# 81637      409636        9975        PERTH 2019-09-26          GBR
# 81638      409637        9975        PERTH 2019-09-26          GBR
#
#        event_number  distance distance_unit distance_furlongs  \
# 14161             1      4675         yards              2m5f
# 14162             1      4675         yards              2m5f
# 14163             1      4675         yards              2m5f
# 14164             1      4675         yards              2m5f
# 14165             1      4675         yards              2m5f
# ...             ...       ...           ...               ...
# 81634             7      5267         yards              2m8f
# 81635             7      5267         yards              2m8f
# 81636             7      5267         yards              2m8f
# 81637             7      5267         yards              2m8f
# 81638             7      5267         yards              2m8f
#
#        distance_raw_furlongs  ... run_5_raw_post_race_rating_int  \
# 14161                   21.2  ...                            NaN
# 14162                   21.2  ...                            NaN
# 14163                   21.2  ...                            NaN
# 14164                   21.2  ...                            NaN
# 14165                   21.2  ...                            NaN
# ...                      ...  ...                            ...
# 81634                   23.9  ...                           95.0
# 81635                   23.9  ...                           90.0
# 81636                   23.9  ...                            NaN
# 81637                   23.9  ...                           83.0
# 81638                   23.9  ...                           71.0
#
#       run_5_raw_post_race_rating_symbol run_5_final_rating_int  \
# 14161                               NaN                    NaN
# 14162                               NaN                    NaN
# 14163                               NaN                    NaN
# 14164                               NaN                    NaN
# 14165                               NaN                    NaN
# ...                                 ...                    ...
# 81634                               NaN                   97.0
# 81635                                ++                   95.0
# 81636                               NaN                    NaN
# 81637                               NaN                  106.0
# 81638                               NaN                   98.0
#
#           run_5_race_type run_5_race_class run_5_race_class_normalised  \
# 14161                 NaN              NaN                         NaN
# 14162  NATIONAL_HUNT_FLAT                5                         NHF
# 14163                JUMP                4                      Novice
# 14164                 NaN              NaN                         NaN
# 14165                 NaN              NaN                         NaN
# ...                   ...              ...                         ...
# 81634                JUMP              5.0                    Handicap
# 81635                JUMP              5.0                    Handicap
# 81636                JUMP              4.0                    Handicap
# 81637                JUMP              4.0                      Maiden
# 81638                JUMP              5.0                    Handicap
#
#       run_5_track_type  run_5_win_lose  run_5_dsr  year
# 14161              NaN             NaN        NaN  2019
# 14162             TURF             0.0      159.0  2019
# 14163             TURF             0.0      142.0  2019
# 14164              NaN             NaN        NaN  2019
# 14165              NaN             NaN        NaN  2019
# ...                ...             ...        ...   ...
# 81634             TURF             0.0      280.0  2019
# 81635             TURF             1.0      122.0  2019
# 81636             TURF             0.0      154.0  2019
# 81637             TURF             0.0      291.0  2019
# 81638             TURF             0.0      117.0  2019
#
# [18474 rows x 96 columns]

# %%
len(df_jump.columns)
# Out:
# 96

# %%
mask2020 = df_jump['year'] == 2020
df_jump_2020 = df_jump[mask2020]
df_jump_2020
# Out:
#        Unnamed: 0  meeting_id meeting_name       date country_code  \
# 3604        16301       10503   HUNTINGDON 2020-11-01          GBR
# 3605        16302       10503   HUNTINGDON 2020-11-01          GBR
# 3606        16303       10503   HUNTINGDON 2020-11-01          GBR
# 3607        16304       10503   HUNTINGDON 2020-11-01          GBR
# 3608        16305       10503   HUNTINGDON 2020-11-01          GBR
# ...           ...         ...          ...        ...          ...
# 80991      402088        9980        PERTH 2020-07-21          GBR
# 80992      402089        9980        PERTH 2020-07-21          GBR
# 80993      402090        9980        PERTH 2020-07-21          GBR
# 80994      402091        9980        PERTH 2020-07-21          GBR
# 80995      402092        9980        PERTH 2020-07-21          GBR
#
#        event_number  distance distance_unit distance_furlongs  \
# 3604              1      3471         yards              1m8f
# 3605              1      3471         yards              1m8f
# 3606              1      3471         yards              1m8f
# 3607              1      3471         yards              1m8f
# 3608              1      3471         yards              1m8f
# ...             ...       ...           ...               ...
# 80991             9      4435         yards              2m4f
# 80992             9      4435         yards              2m4f
# 80993             9      4435         yards              2m4f
# 80994             9      4435         yards              2m4f
# 80995             9      4435         yards              2m4f
#
#        distance_raw_furlongs  ... run_5_raw_post_race_rating_int  \
# 3604                    15.8  ...                          116.0
# 3605                    15.8  ...                           87.0
# 3606                    15.8  ...                            NaN
# 3607                    15.8  ...                            NaN
# 3608                    15.8  ...                           25.0
# ...                      ...  ...                            ...
# 80991                   20.2  ...                            NaN
# 80992                   20.2  ...                            NaN
# 80993                   20.2  ...                           57.0
# 80994                   20.2  ...                            NaN
# 80995                   20.2  ...                            NaN
#
#       run_5_raw_post_race_rating_symbol run_5_final_rating_int  \
# 3604                                NaN                  120.0
# 3605                                  S                  101.0
# 3606                                NaN                    NaN
# 3607                                NaN                    NaN
# 3608                                NaN                   43.0
# ...                                 ...                    ...
# 80991                               NaN                    NaN
# 80992                               NaN                    NaN
# 80993                               NaN                   72.0
# 80994                               NaN                    NaN
# 80995                               NaN                    NaN
#
#        run_5_race_type run_5_race_class run_5_race_class_normalised  \
# 3604              JUMP                2                    Handicap
# 3605              JUMP                4                      Novice
# 3606              JUMP              NaN                      Maiden
# 3607              JUMP                5                      Maiden
# 3608              FLAT                6                    Handicap
# ...                ...              ...                         ...
# 80991             JUMP                5                      Novice
# 80992              NaN              NaN                         NaN
# 80993             JUMP                4                    Handicap
# 80994             JUMP              NaN                      Maiden
# 80995              NaN              NaN                         NaN
#
#       run_5_track_type  run_5_win_lose  run_5_dsr  year
# 3604              TURF             0.0      442.0  2020
# 3605              TURF             1.0      592.0  2020
# 3606              TURF             0.0      323.0  2020
# 3607              TURF             0.0     1327.0  2020
# 3608               AWT             0.0      261.0  2020
# ...                ...             ...        ...   ...
# 80991             TURF             0.0      355.0  2020
# 80992              NaN             NaN        NaN  2020
# 80993             TURF             0.0      300.0  2020
# 80994             TURF             0.0      759.0  2020
# 80995              NaN             NaN        NaN  2020
#
# [14842 rows x 96 columns]

# %%
df_jump['distance_unit'].nunique()
df_jump
# Out:
#        Unnamed: 0  meeting_id meeting_name       date country_code  \
# 0               0       28883     FONTWELL 2021-10-01          GBR
# 1               1       28883     FONTWELL 2021-10-01          GBR
# 2               2       28883     FONTWELL 2021-10-01          GBR
# 3               3       28883     FONTWELL 2021-10-01          GBR
# 4               4       28883     FONTWELL 2021-10-01          GBR
# ...           ...         ...          ...        ...          ...
# 81634      409633        9975        PERTH 2019-09-26          GBR
# 81635      409634        9975        PERTH 2019-09-26          GBR
# 81636      409635        9975        PERTH 2019-09-26          GBR
# 81637      409636        9975        PERTH 2019-09-26          GBR
# 81638      409637        9975        PERTH 2019-09-26          GBR
#
#        event_number  distance distance_unit distance_furlongs  \
# 0                 1      3902         yards            2m1.5f
# 1                 1      3902         yards            2m1.5f
# 2                 1      3902         yards            2m1.5f
# 3                 1      3902         yards            2m1.5f
# 4                 1      3902         yards            2m1.5f
# ...             ...       ...           ...               ...
# 81634             7      5267         yards              2m8f
# 81635             7      5267         yards              2m8f
# 81636             7      5267         yards              2m8f
# 81637             7      5267         yards              2m8f
# 81638             7      5267         yards              2m8f
#
#        distance_raw_furlongs  ... run_5_raw_post_race_rating_int  \
# 0                       17.7  ...                            NaN
# 1                       17.7  ...                            NaN
# 2                       17.7  ...                           49.0
# 3                       17.7  ...                            NaN
# 4                       17.7  ...                            NaN
# ...                      ...  ...                            ...
# 81634                   23.9  ...                           95.0
# 81635                   23.9  ...                           90.0
# 81636                   23.9  ...                            NaN
# 81637                   23.9  ...                           83.0
# 81638                   23.9  ...                           71.0
#
#       run_5_raw_post_race_rating_symbol run_5_final_rating_int  \
# 0                                   NaN                    NaN
# 1                                   NaN                    NaN
# 2                                   NaN                   65.0
# 3                                   NaN                    NaN
# 4                                   NaN                    NaN
# ...                                 ...                    ...
# 81634                               NaN                   97.0
# 81635                                ++                   95.0
# 81636                               NaN                    NaN
# 81637                               NaN                  106.0
# 81638                               NaN                   98.0
#
#        run_5_race_type run_5_race_class run_5_race_class_normalised  \
# 0                  NaN              NaN                         NaN
# 1                 FLAT              NaN                         NaN
# 2                 FLAT                5                      Novice
# 3                  NaN              NaN                         NaN
# 4                 FLAT           LISTED                         NaN
# ...                ...              ...                         ...
# 81634             JUMP              5.0                    Handicap
# 81635             JUMP              5.0                    Handicap
# 81636             JUMP              4.0                    Handicap
# 81637             JUMP              4.0                      Maiden
# 81638             JUMP              5.0                    Handicap
#
#       run_5_track_type  run_5_win_lose  run_5_dsr  year
# 0                  NaN             NaN        NaN  2021
# 1                 TURF             0.0      415.0  2021
# 2                 TURF             0.0      116.0  2021
# 3                  NaN             NaN        NaN  2021
# 4                 TURF             1.0     1251.0  2021
# ...                ...             ...        ...   ...
# 81634             TURF             0.0      280.0  2019
# 81635             TURF             1.0      122.0  2019
# 81636             TURF             0.0      154.0  2019
# 81637             TURF             0.0      291.0  2019
# 81638             TURF             0.0      117.0  2019
#
# [81639 rows x 96 columns]

# %%
df_jump['distance'].nunique()

#158 differentrce distances
# Out:
# 158

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
#6 Different Data Frames
#1 with all jump race data
#5 which are segregated by year fron 2019-2023
jump_dataframes = [df_jump, df_jump_2019, df_jump_2020, df_jump_2021, df_jump_2022, df_jump_2023]
jump_dataframes
# Out:
# [       Unnamed: 0  meeting_id meeting_name       date country_code  \
#  0               0       28883     FONTWELL 2021-10-01          GBR
#  1               1       28883     FONTWELL 2021-10-01          GBR
#  2               2       28883     FONTWELL 2021-10-01          GBR
#  3               3       28883     FONTWELL 2021-10-01          GBR
#  4               4       28883     FONTWELL 2021-10-01          GBR
#  ...           ...         ...          ...        ...          ...
#  81634      409633        9975        PERTH 2019-09-26          GBR
#  81635      409634        9975        PERTH 2019-09-26          GBR
#  81636      409635        9975        PERTH 2019-09-26          GBR
#  81637      409636        9975        PERTH 2019-09-26          GBR
#  81638      409637        9975        PERTH 2019-09-26          GBR
#
#         event_number  distance distance_unit distance_furlongs  \
#  0                 1      3902         yards            2m1.5f
#  1                 1      3902         yards            2m1.5f
#  2                 1      3902         yards            2m1.5f
#  3                 1      3902         yards            2m1.5f
#  4                 1      3902         yards            2m1.5f
#  ...             ...       ...           ...               ...
#  81634             7      5267         yards              2m8f
#  81635             7      5267         yards              2m8f
#  81636             7      5267         yards              2m8f
#  81637             7      5267         yards              2m8f
#  81638             7      5267         yards              2m8f
#
#         distance_raw_furlongs  ... run_5_raw_post_race_rating_int  \
#  0                       17.7  ...                            NaN
#  1                       17.7  ...                            NaN
#  2                       17.7  ...                           49.0
#  3                       17.7  ...                            NaN
#  4                       17.7  ...                            NaN
#  ...                      ...  ...                            ...
#  81634                   23.9  ...                           95.0
#  81635                   23.9  ...                           90.0
#  81636                   23.9  ...                            NaN
#  81637                   23.9  ...                           83.0
#  81638                   23.9  ...                           71.0
#
#        run_5_raw_post_race_rating_symbol run_5_final_rating_int  \
#  0                                   NaN                    NaN
#  1                                   NaN                    NaN
#  2                                   NaN                   65.0
#  3                                   NaN                    NaN
#  4                                   NaN                    NaN
#  ...                                 ...                    ...
#  81634                               NaN                   97.0
#  81635                                ++                   95.0
#  81636                               NaN                    NaN
#  81637                               NaN                  106.0
#  81638                               NaN                   98.0
#
#         run_5_race_type run_5_race_class run_5_race_class_normalised  \
#  0                  NaN              NaN                         NaN
#  1                 FLAT              NaN                         NaN
#  2                 FLAT                5                      Novice
#  3                  NaN              NaN                         NaN
#  4                 FLAT           LISTED                         NaN
#  ...                ...              ...                         ...
#  81634             JUMP              5.0                    Handicap
#  81635             JUMP              5.0                    Handicap
#  81636             JUMP              4.0                    Handicap
#  81637             JUMP              4.0                      Maiden
#  81638             JUMP              5.0                    Handicap
#
#        run_5_track_type  run_5_win_lose  run_5_dsr  year
#  0                  NaN             NaN        NaN  2021
#  1                 TURF             0.0      415.0  2021
#  2                 TURF             0.0      116.0  2021
#  3                  NaN             NaN        NaN  2021
#  4                 TURF             1.0     1251.0  2021
#  ...                ...             ...        ...   ...
#  81634             TURF             0.0      280.0  2019
#  81635             TURF             1.0      122.0  2019
#  81636             TURF             0.0      154.0  2019
#  81637             TURF             0.0      291.0  2019
#  81638             TURF             0.0      117.0  2019
#
#  [81639 rows x 96 columns],
#         Unnamed: 0  meeting_id meeting_name       date country_code  \
#  14161       58323        7437       LUDLOW 2019-04-01          GBR
#  14162       58324        7437       LUDLOW 2019-04-01          GBR
#  14163       58325        7437       LUDLOW 2019-04-01          GBR
#  14164       58326        7437       LUDLOW 2019-04-01          GBR
#  14165       58327        7437       LUDLOW 2019-04-01          GBR
#  ...           ...         ...          ...        ...          ...
#  81634      409633        9975        PERTH 2019-09-26          GBR
#  81635      409634        9975        PERTH 2019-09-26          GBR
#  81636      409635        9975        PERTH 2019-09-26          GBR
#  81637      409636        9975        PERTH 2019-09-26          GBR
#  81638      409637        9975        PERTH 2019-09-26          GBR
#
#         event_number  distance distance_unit distance_furlongs  \
#  14161             1      4675         yards              2m5f
#  14162             1      4675         yards              2m5f
#  14163             1      4675         yards              2m5f
#  14164             1      4675         yards              2m5f
#  14165             1      4675         yards              2m5f
#  ...             ...       ...           ...               ...
#  81634             7      5267         yards              2m8f
#  81635             7      5267         yards              2m8f
#  81636             7      5267         yards              2m8f
#  81637             7      5267         yards              2m8f
#  81638             7      5267         yards              2m8f
#
#         distance_raw_furlongs  ... run_5_raw_post_race_rating_int  \
#  14161                   21.2  ...                            NaN
#  14162                   21.2  ...                            NaN
#  14163                   21.2  ...                            NaN
#  14164                   21.2  ...                            NaN
#  14165                   21.2  ...                            NaN
#  ...                      ...  ...                            ...
#  81634                   23.9  ...                           95.0
#  81635                   23.9  ...                           90.0
#  81636                   23.9  ...                            NaN
#  81637                   23.9  ...                           83.0
#  81638                   23.9  ...                           71.0
#
#        run_5_raw_post_race_rating_symbol run_5_final_rating_int  \
#  14161                               NaN                    NaN
#  14162                               NaN                    NaN
#  14163                               NaN                    NaN
#  14164                               NaN                    NaN
#  14165                               NaN                    NaN
#  ...                                 ...                    ...
#  81634                               NaN                   97.0
#  81635                                ++                   95.0
#  81636                               NaN                    NaN
#  81637                               NaN                  106.0
#  81638                               NaN                   98.0
#
#            run_5_race_type run_5_race_class run_5_race_class_normalised  \
#  14161                 NaN              NaN                         NaN
#  14162  NATIONAL_HUNT_FLAT                5                         NHF
#  14163                JUMP                4                      Novice
#  14164                 NaN              NaN                         NaN
#  14165                 NaN              NaN                         NaN
#  ...                   ...              ...                         ...
#  81634                JUMP              5.0                    Handicap
#  81635                JUMP              5.0                    Handicap
#  81636                JUMP              4.0                    Handicap
#  81637                JUMP              4.0                      Maiden
#  81638                JUMP              5.0                    Handicap
#
#        run_5_track_type  run_5_win_lose  run_5_dsr  year
#  14161              NaN             NaN        NaN  2019
#  14162             TURF             0.0      159.0  2019
#  14163             TURF             0.0      142.0  2019
#  14164              NaN             NaN        NaN  2019
#  14165              NaN             NaN        NaN  2019
#  ...                ...             ...        ...   ...
#  81634             TURF             0.0      280.0  2019
#  81635             TURF             1.0      122.0  2019
#  81636             TURF             0.0      154.0  2019
#  81637             TURF             0.0      291.0  2019
#  81638             TURF             0.0      117.0  2019
#
#  [18474 rows x 96 columns],
#         Unnamed: 0  meeting_id meeting_name       date country_code  \
#  3604        16301       10503   HUNTINGDON 2020-11-01          GBR
#  3605        16302       10503   HUNTINGDON 2020-11-01          GBR
#  3606        16303       10503   HUNTINGDON 2020-11-01          GBR
#  3607        16304       10503   HUNTINGDON 2020-11-01          GBR
#  3608        16305       10503   HUNTINGDON 2020-11-01          GBR
#  ...           ...         ...          ...        ...          ...
#  80991      402088        9980        PERTH 2020-07-21          GBR
#  80992      402089        9980        PERTH 2020-07-21          GBR
#  80993      402090        9980        PERTH 2020-07-21          GBR
#  80994      402091        9980        PERTH 2020-07-21          GBR
#  80995      402092        9980        PERTH 2020-07-21          GBR
#
#         event_number  distance distance_unit distance_furlongs  \
#  3604              1      3471         yards              1m8f
#  3605              1      3471         yards              1m8f
#  3606              1      3471         yards              1m8f
#  3607              1      3471         yards              1m8f
#  3608              1      3471         yards              1m8f
#  ...             ...       ...           ...               ...
#  80991             9      4435         yards              2m4f
#  80992             9      4435         yards              2m4f
#  80993             9      4435         yards              2m4f
#  80994             9      4435         yards              2m4f
#  80995             9      4435         yards              2m4f
#
#         distance_raw_furlongs  ... run_5_raw_post_race_rating_int  \
#  3604                    15.8  ...                          116.0
#  3605                    15.8  ...                           87.0
#  3606                    15.8  ...                            NaN
#  3607                    15.8  ...                            NaN
#  3608                    15.8  ...                           25.0
#  ...                      ...  ...                            ...
#  80991                   20.2  ...                            NaN
#  80992                   20.2  ...                            NaN
#  80993                   20.2  ...                           57.0
#  80994                   20.2  ...                            NaN
#  80995                   20.2  ...                            NaN
#
#        run_5_raw_post_race_rating_symbol run_5_final_rating_int  \
#  3604                                NaN                  120.0
#  3605                                  S                  101.0
#  3606                                NaN                    NaN
#  3607                                NaN                    NaN
#  3608                                NaN                   43.0
#  ...                                 ...                    ...
#  80991                               NaN                    NaN
#  80992                               NaN                    NaN
#  80993                               NaN                   72.0
#  80994                               NaN                    NaN
#  80995                               NaN                    NaN
#
#         run_5_race_type run_5_race_class run_5_race_class_normalised  \
#  3604              JUMP                2                    Handicap
#  3605              JUMP                4                      Novice
#  3606              JUMP              NaN                      Maiden
#  3607              JUMP                5                      Maiden
#  3608              FLAT                6                    Handicap
#  ...                ...              ...                         ...
#  80991             JUMP                5                      Novice
#  80992              NaN              NaN                         NaN
#  80993             JUMP                4                    Handicap
#  80994             JUMP              NaN                      Maiden
#  80995              NaN              NaN                         NaN
#
#        run_5_track_type  run_5_win_lose  run_5_dsr  year
#  3604              TURF             0.0      442.0  2020
#  3605              TURF             1.0      592.0  2020
#  3606              TURF             0.0      323.0  2020
#  3607              TURF             0.0     1327.0  2020
#  3608               AWT             0.0      261.0  2020
#  ...                ...             ...        ...   ...
#  80991             TURF             0.0      355.0  2020
#  80992              NaN             NaN        NaN  2020
#  80993             TURF             0.0      300.0  2020
#  80994             TURF             0.0      759.0  2020
#  80995              NaN             NaN        NaN  2020
#
#  [14842 rows x 96 columns],
#         Unnamed: 0  meeting_id meeting_name       date country_code  \
#  0               0       28883     FONTWELL 2021-10-01          GBR
#  1               1       28883     FONTWELL 2021-10-01          GBR
#  2               2       28883     FONTWELL 2021-10-01          GBR
#  3               3       28883     FONTWELL 2021-10-01          GBR
#  4               4       28883     FONTWELL 2021-10-01          GBR
#  ...           ...         ...          ...        ...          ...
#  80089      393267       26512    NEWCASTLE 2021-03-30          GBR
#  80090      393268       26512    NEWCASTLE 2021-03-30          GBR
#  80091      393269       26512    NEWCASTLE 2021-03-30          GBR
#  80092      393270       26512    NEWCASTLE 2021-03-30          GBR
#  80093      393271       26512    NEWCASTLE 2021-03-30          GBR
#
#         event_number  distance distance_unit distance_furlongs  \
#  0                 1      3902         yards            2m1.5f
#  1                 1      3902         yards            2m1.5f
#  2                 1      3902         yards            2m1.5f
#  3                 1      3902         yards            2m1.5f
#  4                 1      3902         yards            2m1.5f
#  ...             ...       ...           ...               ...
#  80089             8      5209         yards            2m7.5f
#  80090             8      5209         yards            2m7.5f
#  80091             8      5209         yards            2m7.5f
#  80092             8      5209         yards            2m7.5f
#  80093             8      5209         yards            2m7.5f
#
#         distance_raw_furlongs  ... run_5_raw_post_race_rating_int  \
#  0                       17.7  ...                            NaN
#  1                       17.7  ...                            NaN
#  2                       17.7  ...                           49.0
#  3                       17.7  ...                            NaN
#  4                       17.7  ...                            NaN
#  ...                      ...  ...                            ...
#  80089                   23.7  ...                           55.0
#  80090                   23.7  ...                            NaN
#  80091                   23.7  ...                           55.0
#  80092                   23.7  ...                           25.0
#  80093                   23.7  ...                           55.0
#
#        run_5_raw_post_race_rating_symbol run_5_final_rating_int  \
#  0                                   NaN                    NaN
#  1                                   NaN                    NaN
#  2                                   NaN                   65.0
#  3                                   NaN                    NaN
#  4                                   NaN                    NaN
#  ...                                 ...                    ...
#  80089                               NaN                   73.0
#  80090                               NaN                    NaN
#  80091                               NaN                   79.0
#  80092                               NaN                   53.0
#  80093                               NaN                   83.0
#
#         run_5_race_type run_5_race_class run_5_race_class_normalised  \
#  0                  NaN              NaN                         NaN
#  1                 FLAT              NaN                         NaN
#  2                 FLAT                5                      Novice
#  3                  NaN              NaN                         NaN
#  4                 FLAT           LISTED                         NaN
#  ...                ...              ...                         ...
#  80089             JUMP                4                      Novice
#  80090              NaN              NaN                         NaN
#  80091             JUMP                5                    Handicap
#  80092             FLAT                6                    Handicap
#  80093             JUMP                5                    Handicap
#
#        run_5_track_type  run_5_win_lose  run_5_dsr  year
#  0                  NaN             NaN        NaN  2021
#  1                 TURF             0.0      415.0  2021
#  2                 TURF             0.0      116.0  2021
#  3                  NaN             NaN        NaN  2021
#  4                 TURF             1.0     1251.0  2021
#  ...                ...             ...        ...   ...
#  80089             TURF             0.0      541.0  2021
#  80090              NaN             NaN        NaN  2021
#  80091             TURF             0.0      501.0  2021
#  80092             TURF             0.0      175.0  2021
#  80093             TURF             0.0      156.0  2021
#
#  [18673 rows x 96 columns],
#         Unnamed: 0  meeting_id meeting_name       date country_code  \
#  25643      125419       30058    NEWCASTLE 2022-02-01          GBR
#  25644      125420       30058    NEWCASTLE 2022-02-01          GBR
#  25645      125421       30058    NEWCASTLE 2022-02-01          GBR
#  25646      125422       30058    NEWCASTLE 2022-02-01          GBR
#  25647      125423       30058    NEWCASTLE 2022-02-01          GBR
#  ...           ...         ...          ...        ...          ...
#  75124      379356       34950      HAYDOCK 2022-11-30          GBR
#  75125      379366       34950      HAYDOCK 2022-11-30          GBR
#  75126      379367       34950      HAYDOCK 2022-11-30          GBR
#  75127      379368       34950      HAYDOCK 2022-11-30          GBR
#  75128      379369       34950      HAYDOCK 2022-11-30          GBR
#
#         event_number  distance distance_unit distance_furlongs  \
#  25643             2      4840         yards              2m6f
#  25644             2      4840         yards              2m6f
#  25645             2      4840         yards              2m6f
#  25646             2      4840         yards              2m6f
#  25647             2      4840         yards              2m6f
#  ...             ...       ...           ...               ...
#  75124             4      3444         yards            1m7.5f
#  75125             6      4151         yards              2m3f
#  75126             6      4151         yards              2m3f
#  75127             6      4151         yards              2m3f
#  75128             6      4151         yards              2m3f
#
#         distance_raw_furlongs  ... run_5_raw_post_race_rating_int  \
#  25643                   22.0  ...                            NaN
#  25644                   22.0  ...                            NaN
#  25645                   22.0  ...                            NaN
#  25646                   22.0  ...                            NaN
#  25647                   22.0  ...                           81.0
#  ...                      ...  ...                            ...
#  75124                   15.7  ...                           68.0
#  75125                   18.9  ...                            NaN
#  75126                   18.9  ...                          106.0
#  75127                   18.9  ...                            NaN
#  75128                   18.9  ...                          105.0
#
#        run_5_raw_post_race_rating_symbol run_5_final_rating_int  \
#  25643                               NaN                    NaN
#  25644                               NaN                    NaN
#  25645                               NaN                    NaN
#  25646                               NaN                    NaN
#  25647                               NaN                   92.0
#  ...                                 ...                    ...
#  75124                               NaN                   80.0
#  75125                               NaN                    NaN
#  75126                               NaN                  106.0
#  75127                               NaN                    NaN
#  75128                               NaN                  112.0
#
#            run_5_race_type run_5_race_class run_5_race_class_normalised  \
#  25643                JUMP                4                    Handicap
#  25644  NATIONAL_HUNT_FLAT                5                         NHF
#  25645                JUMP                4                      Novice
#  25646                JUMP                5                    Handicap
#  25647  NATIONAL_HUNT_FLAT                4                         NHF
#  ...                   ...              ...                         ...
#  75124                FLAT                4                    Handicap
#  75125                 NaN              NaN                         NaN
#  75126        STEEPLECHASE                2                    Handicap
#  75127                 NaN              NaN                         NaN
#  75128  NATIONAL_HUNT_FLAT                5                         NHF
#
#        run_5_track_type  run_5_win_lose  run_5_dsr  year
#  25643             TURF             0.0      350.0  2022
#  25644              AWT             1.0      355.0  2022
#  25645             TURF             0.0      272.0  2022
#  25646             TURF             0.0      297.0  2022
#  25647             TURF             0.0      188.0  2022
#  ...                ...             ...        ...   ...
#  75124             TURF             0.0      422.0  2022
#  75125              NaN             NaN        NaN  2022
#  75126             TURF             0.0      389.0  2022
#  75127              NaN             NaN        NaN  2022
#  75128             TURF             0.0      366.0  2022
#
#  [17574 rows x 96 columns],
#         Unnamed: 0  meeting_id meeting_name       date country_code  \
#  1771         8631       36297    UTTOXETER 2023-04-01          GBR
#  1772         8632       36297    UTTOXETER 2023-04-01          GBR
#  1773         8633       36297    UTTOXETER 2023-04-01          GBR
#  1774         8634       36297    UTTOXETER 2023-04-01          GBR
#  1775         8635       36297    UTTOXETER 2023-04-01          GBR
#  ...           ...         ...          ...        ...          ...
#  77323      385805       36293     WETHERBY 2023-03-31          GBR
#  77324      385806       36293     WETHERBY 2023-03-31          GBR
#  77325      385807       36293     WETHERBY 2023-03-31          GBR
#  77326      385808       36293     WETHERBY 2023-03-31          GBR
#  77327      385809       36293     WETHERBY 2023-03-31          GBR
#
#         event_number  distance distance_unit distance_furlongs  \
#  1771              1      3468         yards              1m8f
#  1772              1      3468         yards              1m8f
#  1773              1      3468         yards              1m8f
#  1774              1      3468         yards              1m8f
#  1775              1      3468         yards              1m8f
#  ...             ...       ...           ...               ...
#  77323             4      3520         yards              2m0f
#  77324             4      3520         yards              2m0f
#  77325             4      3520         yards              2m0f
#  77326             4      3520         yards              2m0f
#  77327             4      3520         yards              2m0f
#
#         distance_raw_furlongs  ... run_5_raw_post_race_rating_int  \
#  1771                    15.8  ...                            NaN
#  1772                    15.8  ...                           96.0
#  1773                    15.8  ...                           98.0
#  1774                    15.8  ...                           55.0
#  1775                    15.8  ...                           55.0
#  ...                      ...  ...                            ...
#  77323                   16.0  ...                            NaN
#  77324                   16.0  ...                          130.0
#  77325                   16.0  ...                           98.0
#  77326                   16.0  ...                           92.0
#  77327                   16.0  ...                           98.0
#
#        run_5_raw_post_race_rating_symbol run_5_final_rating_int  \
#  1771                                NaN                    NaN
#  1772                                NaN                   96.0
#  1773                                  +                  102.0
#  1774                                NaN                   63.0
#  1775                                NaN                   71.0
#  ...                                 ...                    ...
#  77323                               NaN                    NaN
#  77324                               NaN                  139.0
#  77325                               NaN                  110.0
#  77326                               NaN                  110.0
#  77327                               NaN                  117.0
#
#            run_5_race_type run_5_race_class run_5_race_class_normalised  \
#  1771         STEEPLECHASE                5                    Handicap
#  1772                 JUMP                5                      Novice
#  1773                 JUMP                4                    Handicap
#  1774   NATIONAL_HUNT_FLAT                5                         NHF
#  1775                 JUMP                5                    Handicap
#  ...                   ...              ...                         ...
#  77323                 NaN              NaN                         NaN
#  77324                JUMP                1                      Listed
#  77325        STEEPLECHASE                1                     Grade 2
#  77326                JUMP                3                    Handicap
#  77327                JUMP                4                    Handicap
#
#        run_5_track_type  run_5_win_lose  run_5_dsr  year
#  1771              TURF             0.0       86.0  2023
#  1772              TURF             1.0      385.0  2023
#  1773              TURF             0.0      229.0  2023
#  1774              TURF             0.0      477.0  2023
#  1775              TURF             0.0      132.0  2023
#  ...                ...             ...        ...   ...
#  77323              NaN             NaN        NaN  2023
#  77324             TURF             0.0      132.0  2023
#  77325             TURF             0.0      146.0  2023
#  77326             TURF             0.0      139.0  2023
#  77327             TURF             0.0      143.0  2023
#
#  [12076 rows x 96 columns]]

# %%
resultados_jump.drop(columns=['gear_nan'])

# %%
resultados_jump['gear'] = resultados_jump['gear'].apply(lambda x: 0 if pd.isna(x) else 1)
# Out:
# <ipython-input-17-c6cd08286eab>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   resultados_jump['gear'] = resultados_jump['gear'].apply(lambda x: 0 if pd.isna(x) else 1)

# %%
num_nan_per_columns = resultados_jump.isna().sum()
pd.set_option("display.max_rows", None, "display.max_columns", None) #show all the lines
num_nan_per_columns
# Out:
# meeting_id                               0
# meeting_name                             0
# date                                     0
# country_code                             0
# event_number                             0
# distance                                 0
# distance_unit                            0
# distance_furlongs                        0
# distance_raw_furlongs                    0
# race_class                               0
# race_class_normalised                 2087
# prize_money_currency                     0
# total_prize_money                        0
# track_condition                          0
# race_type                                0
# track_type                               0
# barrier                                  0
# number                                   0
# finish_position                      11020
# win_or_lose                              0
# failed_to_finish_reason              70616
# margin                               20041
# gear                                 51724
# jockey_allowance                         0
# jockey_allowance_unit                    0
# handicap_weight                          0
# handicap_weight_unit                     0
# jockey_id                                0
# jockey_name                              0
# tainer_id                                0
# trainer_name                             0
# dslr                                  2010
# horse_id                                 0
# horse_name                               0
# sire                                     0
# dam                                      0
# age                                      0
# birth_date                               0
# official rating                      24157
# wfa                                      0
# weight_adjustment                        0
# bet365_odds                          28703
# pmu_odds                             81639
# betfair_starting_price                2374
# pre_race_master_rating_int           16319
# pre_race_master_rating_symbol        60442
# post_race_master_rating_int          12124
# post_race_master_rating_symbol       66912
# starting_price                           0
# run_1_raw_post_race_rating_int       16951
# run_1_raw_post_race_rating_symbol    67666
# run_1_final_rating_int               16951
# run_1_race_type                       2011
# run_1_race_class_normalised           4985
# run_1_race_class                      4556
# run_1_track_type                      2011
# run_1_win_lose                        2011
# run_1_dsr                             2011
# run_2_raw_post_race_rating_int       22481
# run_2_raw_post_race_rating_symbol    68772
# run_2_final_rating_int               22481
# run_2_race_type                       5939
# run_2_race_class                     10210
# run_2_race_class_normalised           8835
# run_2_track_type                      5939
# run_2_win_lose                        5939
# run_2_dsr                             5939
# run_3_raw_post_race_rating_int       28772
# run_3_raw_post_race_rating_symbol    69867
# run_3_final_rating_int               28772
# run_3_race_type                      11267
# run_3_race_class                     16446
# run_3_race_class_normalised          14374
# run_3_track_type                     11267
# run_3_win_lose                       11267
# run_3_dsr                            11267
# run_4_raw_post_race_rating_int       34880
# run_4_raw_post_race_rating_symbol    71007
# run_4_final_rating_int               34880
# run_4_race_type                      16997
# run_4_race_class                     22688
# run_4_race_class_normalised          20156
# run_4_track_type                     16997
# run_4_win_lose                       16997
# run_4_dsr                            16997
# run_5_raw_post_race_rating_int       40474
# run_5_raw_post_race_rating_symbol    72244
# run_5_final_rating_int               40474
# run_5_race_type                      22617
# run_5_race_class                     28569
# run_5_race_class_normalised          25702
# run_5_track_type                     22617
# run_5_win_lose                       22617
# run_5_dsr                            22617
# run_6_raw_post_race_rating_int       45223
# run_6_raw_post_race_rating_symbol    73299
# run_6_final_rating_int               45223
# run_6_race_type                      27691
# run_6_race_class                     33719
# run_6_race_class_normalised          30673
# run_6_track_type                     27691
# run_6_win_lose                       27691
# run_6_dsr                            27691
# run_7_raw_post_race_rating_int       49310
# run_7_raw_post_race_rating_symbol    74194
# run_7_final_rating_int               49310
# run_7_race_type                      32180
# run_7_race_class                     38090
# run_7_race_class_normalised          35080
# run_7_track_type                     32180
# run_7_win_lose                       32180
# run_7_dsr                            32180
# run_8_raw_post_race_rating_int       52770
# run_8_raw_post_race_rating_symbol    74984
# run_8_final_rating_int               52770
# run_8_race_type                      36253
# run_8_race_class                     41943
# run_8_race_class_normalised          38980
# run_8_track_type                     36253
# run_8_win_lose                       36253
# run_8_dsr                            36253
# dtype: int64

# %%
num_nan_per_columns = ((df_jump.isna().sum())/len(df_jump['starting_price']))*100
pd.set_option("display.max_rows", None, "display.max_columns", None) #show all the lines
num_nan_per_columns.sort_values()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-33cc46c6ec69> in <cell line: 1>()
# ----> 1 num_nan_per_columns = ((df_jump.isna().sum())/len(df_jump['starting_price']))*100
#       2 pd.set_option("display.max_rows", None, "display.max_columns", None) #show all the lines
#       3 num_nan_per_columns.sort_values()
#
# NameError: name 'df_jump' is not defined

# %%
correlation_matrix = resultados_jump.corr()
# Out:
# <ipython-input-39-3413d4ea64c1>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = resultados_jump.corr()

# %%
correlation_matrix
# Out:
#                                 meeting_id  event_number  distance  \
# meeting_id                        1.000000      0.028719  0.017380
# event_number                      0.028719      1.000000  0.159623
# distance                          0.017380      0.159623  1.000000
# distance_raw_furlongs             0.017217      0.159364  0.999960
# total_prize_money                 0.039130      0.000990  0.016950
# barrier                          -0.040030      0.030320  0.003291
# number                           -0.040030      0.030320  0.003291
# finish_position                  -0.062951      0.014539 -0.044796
# win_or_lose                       0.015835     -0.007746  0.003516
# margin                           -0.064994     -0.057217 -0.020532
# jockey_allowance                 -0.000740      0.037784  0.053778
# handicap_weight                   0.121486      0.062120  0.067591
# jockey_id                         0.174963      0.008755  0.024462
# tainer_id                         0.150070      0.012989 -0.002897
# dslr                             -0.039699     -0.004398 -0.017801
# horse_id                          0.561333     -0.114050 -0.074598
# age                               0.004683      0.178931  0.332514
# official rating                  -0.124925     -0.085134 -0.003907
# wfa                               0.004118     -0.030180 -0.110764
# weight_adjustment                -0.121486     -0.062120 -0.067591
# bet365_odds                      -0.059606     -0.139571 -0.114332
# pmu_odds                               NaN           NaN       NaN
# betfair_starting_price           -0.042160     -0.149009 -0.123638
# pre_race_master_rating_int       -0.063983      0.046762  0.111031
# post_race_master_rating_int      -0.016391     -0.004168  0.029601
# starting_price                    0.003524     -0.135181 -0.112486
# run_1_raw_post_race_rating_int   -0.023643      0.032504  0.129200
# run_1_final_rating_int           -0.057832      0.018560  0.122866
# run_1_win_lose                    0.015891      0.008310  0.024538
# run_1_dsr                        -0.039506     -0.004393 -0.017872
# run_2_raw_post_race_rating_int   -0.002795      0.032969  0.138287
# run_2_final_rating_int           -0.033599      0.020780  0.133359
# run_2_win_lose                    0.011895     -0.000811  0.010929
# run_2_dsr                        -0.054727     -0.004491 -0.008774
# run_3_raw_post_race_rating_int    0.020177      0.044989  0.144968
# run_3_final_rating_int           -0.008482      0.034294  0.141595
# run_3_win_lose                    0.008240     -0.007134  0.007571
# run_3_dsr                        -0.063714     -0.008497  0.004698
# run_4_raw_post_race_rating_int    0.044992      0.051583  0.159868
# run_4_final_rating_int            0.017476      0.041864  0.157414
# run_4_win_lose                    0.010861     -0.002722 -0.003816
# run_4_dsr                        -0.063644      0.011519  0.029949
# run_5_raw_post_race_rating_int    0.062235      0.066076  0.182220
# run_5_final_rating_int            0.034674      0.057685  0.181678
# run_5_win_lose                    0.015307     -0.008761  0.008456
# run_5_dsr                        -0.060141      0.028777  0.055036
# run_6_raw_post_race_rating_int    0.075346      0.081298  0.202682
# run_6_final_rating_int            0.047521      0.071550  0.201875
# run_6_win_lose                    0.008881      0.000926  0.007731
# run_6_dsr                        -0.053513      0.037426  0.073846
# run_7_raw_post_race_rating_int    0.088969      0.082500  0.215040
# run_7_final_rating_int            0.059623      0.072455  0.216627
# run_7_win_lose                    0.013588      0.001932  0.011218
# run_7_dsr                        -0.048260      0.044255  0.090391
# run_8_raw_post_race_rating_int    0.107522      0.074327  0.222585
# run_8_final_rating_int            0.078079      0.065553  0.222043
# run_8_win_lose                    0.010708     -0.001294  0.009345
# run_8_dsr                        -0.041807      0.050399  0.103189
#
#                                 distance_raw_furlongs  total_prize_money  \
# meeting_id                                   0.017217           0.039130
# event_number                                 0.159364           0.000990
# distance                                     0.999960           0.016950
# distance_raw_furlongs                        1.000000           0.017370
# total_prize_money                            0.017370           1.000000
# barrier                                      0.003442           0.087650
# number                                       0.003442           0.087650
# finish_position                             -0.044725           0.090139
# win_or_lose                                  0.003486          -0.012162
# margin                                      -0.020563          -0.057072
# jockey_allowance                             0.053846          -0.078644
# handicap_weight                              0.067645           0.034728
# jockey_id                                    0.024536          -0.058396
# tainer_id                                   -0.002900          -0.019563
# dslr                                        -0.017876          -0.032499
# horse_id                                    -0.074760          -0.026986
# age                                          0.332626           0.035043
# official rating                             -0.003555           0.479981
# wfa                                         -0.110646          -0.030344
# weight_adjustment                           -0.067645          -0.034728
# bet365_odds                                 -0.114308          -0.034171
# pmu_odds                                          NaN                NaN
# betfair_starting_price                      -0.123621          -0.038857
# pre_race_master_rating_int                   0.111325           0.402358
# post_race_master_rating_int                  0.029680           0.149952
# starting_price                              -0.112436          -0.025357
# run_1_raw_post_race_rating_int               0.129427           0.340407
# run_1_final_rating_int                       0.123089           0.353525
# run_1_win_lose                               0.024641           0.146200
# run_1_dsr                                   -0.017947          -0.032544
# run_2_raw_post_race_rating_int               0.138510           0.332871
# run_2_final_rating_int                       0.133581           0.348039
# run_2_win_lose                               0.011040           0.159407
# run_2_dsr                                   -0.008896          -0.038305
# run_3_raw_post_race_rating_int               0.145166           0.324739
# run_3_final_rating_int                       0.141798           0.342317
# run_3_win_lose                               0.007692           0.160498
# run_3_dsr                                    0.004592          -0.031444
# run_4_raw_post_race_rating_int               0.160015           0.301460
# run_4_final_rating_int                       0.157567           0.315822
# run_4_win_lose                              -0.003794           0.154131
# run_4_dsr                                    0.029886          -0.017275
# run_5_raw_post_race_rating_int               0.182384           0.294148
# run_5_final_rating_int                       0.181856           0.307668
# run_5_win_lose                               0.008528           0.146112
# run_5_dsr                                    0.054996          -0.000648
# run_6_raw_post_race_rating_int               0.202870           0.288904
# run_6_final_rating_int                       0.202077           0.300813
# run_6_win_lose                               0.007798           0.149148
# run_6_dsr                                    0.073859           0.007112
# run_7_raw_post_race_rating_int               0.215193           0.268545
# run_7_final_rating_int                       0.216782           0.277671
# run_7_win_lose                               0.011342           0.134986
# run_7_dsr                                    0.090413           0.011674
# run_8_raw_post_race_rating_int               0.222753           0.261698
# run_8_final_rating_int                       0.222209           0.269161
# run_8_win_lose                               0.009461           0.127444
# run_8_dsr                                    0.103218           0.019559
#
#                                  barrier    number  finish_position  \
# meeting_id                     -0.040030 -0.040030        -0.062951
# event_number                    0.030320  0.030320         0.014539
# distance                        0.003291  0.003291        -0.044796
# distance_raw_furlongs           0.003442  0.003442        -0.044725
# total_prize_money               0.087650  0.087650         0.090139
# barrier                         1.000000  1.000000         0.279582
# number                          1.000000  1.000000         0.279582
# finish_position                 0.279582  0.279582         1.000000
# win_or_lose                    -0.105641 -0.105641        -0.483547
# margin                          0.095235  0.095235         0.621061
# jockey_allowance                0.006593  0.006593         0.028479
# handicap_weight                -0.618917 -0.618917        -0.097328
# jockey_id                       0.008948  0.008948         0.008811
# tainer_id                       0.024261  0.024261         0.021196
# dslr                            0.007179  0.007179         0.061288
# horse_id                       -0.006529 -0.006529        -0.045023
# age                             0.008127  0.008127         0.044504
# official rating                -0.341428 -0.341428        -0.073075
# wfa                             0.116651  0.116651         0.004167
# weight_adjustment               0.618917  0.618917         0.097328
# bet365_odds                     0.153659  0.153659         0.328700
# pmu_odds                             NaN       NaN              NaN
# betfair_starting_price          0.143498  0.143498         0.325145
# pre_race_master_rating_int     -0.080173 -0.080173        -0.184166
# post_race_master_rating_int    -0.115664 -0.115664        -0.281531
# starting_price                  0.174824  0.174824         0.379517
# run_1_raw_post_race_rating_int -0.211725 -0.211725        -0.233713
# run_1_final_rating_int         -0.046067 -0.046067        -0.215155
# run_1_win_lose                 -0.106021 -0.106021        -0.140977
# run_1_dsr                       0.007203  0.007203         0.061291
# run_2_raw_post_race_rating_int -0.205428 -0.205428        -0.165092
# run_2_final_rating_int         -0.033060 -0.033060        -0.144209
# run_2_win_lose                 -0.082468 -0.082468        -0.084071
# run_2_dsr                       0.014335  0.014335         0.070584
# run_3_raw_post_race_rating_int -0.208944 -0.208944        -0.125485
# run_3_final_rating_int         -0.029213 -0.029213        -0.103087
# run_3_win_lose                 -0.073705 -0.073705        -0.050676
# run_3_dsr                       0.012682  0.012682         0.068922
# run_4_raw_post_race_rating_int -0.210190 -0.210190        -0.102480
# run_4_final_rating_int         -0.025364 -0.025364        -0.078830
# run_4_win_lose                 -0.075290 -0.075290        -0.037450
# run_4_dsr                       0.017951  0.017951         0.067105
# run_5_raw_post_race_rating_int -0.202583 -0.202583        -0.083884
# run_5_final_rating_int         -0.015321 -0.015321        -0.059668
# run_5_win_lose                 -0.069129 -0.069129        -0.021275
# run_5_dsr                       0.022442  0.022442         0.068815
# run_6_raw_post_race_rating_int -0.194342 -0.194342        -0.080000
# run_6_final_rating_int         -0.004967 -0.004967        -0.056624
# run_6_win_lose                 -0.066572 -0.066572        -0.017358
# run_6_dsr                       0.021486  0.021486         0.063743
# run_7_raw_post_race_rating_int -0.200326 -0.200326        -0.068486
# run_7_final_rating_int         -0.008844 -0.008844        -0.045365
# run_7_win_lose                 -0.064129 -0.064129         0.004254
# run_7_dsr                       0.022430  0.022430         0.063945
# run_8_raw_post_race_rating_int -0.198338 -0.198338        -0.058300
# run_8_final_rating_int         -0.005742 -0.005742        -0.035942
# run_8_win_lose                 -0.067132 -0.067132        -0.011530
# run_8_dsr                       0.020768  0.020768         0.061849
#
#                                 win_or_lose    margin  jockey_allowance  \
# meeting_id                         0.015835 -0.064994         -0.000740
# event_number                      -0.007746 -0.057217          0.037784
# distance                           0.003516 -0.020532          0.053778
# distance_raw_furlongs              0.003486 -0.020563          0.053846
# total_prize_money                 -0.012162 -0.057072         -0.078644
# barrier                           -0.105641  0.095235          0.006593
# number                            -0.105641  0.095235          0.006593
# finish_position                   -0.483547  0.621061          0.028479
# win_or_lose                        1.000000 -0.023390         -0.021811
# margin                            -0.023390  1.000000          0.003271
# jockey_allowance                  -0.021811  0.003271          1.000000
# handicap_weight                    0.065825 -0.095312         -0.083961
# jockey_id                         -0.020822 -0.007085          0.326552
# tainer_id                         -0.016587  0.032129          0.037981
# dslr                              -0.038894  0.082121         -0.023588
# horse_id                           0.013883  0.031344         -0.080334
# age                               -0.030934 -0.034691          0.157477
# official rating                    0.076787 -0.109376         -0.132629
# wfa                               -0.006867  0.009919         -0.017497
# weight_adjustment                 -0.065825  0.095312          0.083961
# bet365_odds                       -0.140395  0.383296          0.041751
# pmu_odds                                NaN       NaN               NaN
# betfair_starting_price            -0.133245  0.390231          0.039115
# pre_race_master_rating_int         0.134617 -0.260561         -0.035756
# post_race_master_rating_int        0.186210 -0.279338         -0.024998
# starting_price                    -0.168470  0.416794          0.046380
# run_1_raw_post_race_rating_int     0.172661 -0.265767         -0.066128
# run_1_final_rating_int             0.161125 -0.250802         -0.047074
# run_1_win_lose                     0.128492 -0.126628         -0.028397
# run_1_dsr                         -0.038962  0.082077         -0.023481
# run_2_raw_post_race_rating_int     0.120448 -0.217840         -0.057523
# run_2_final_rating_int             0.107637 -0.201743         -0.038248
# run_2_win_lose                     0.075685 -0.094321         -0.036017
# run_2_dsr                         -0.044692  0.099440         -0.031307
# run_3_raw_post_race_rating_int     0.095647 -0.178460         -0.049494
# run_3_final_rating_int             0.082155 -0.161982         -0.030928
# run_3_win_lose                     0.044542 -0.063127         -0.031753
# run_3_dsr                         -0.044424  0.101083         -0.033135
# run_4_raw_post_race_rating_int     0.078850 -0.152952         -0.043761
# run_4_final_rating_int             0.064940 -0.136207         -0.025497
# run_4_win_lose                     0.036544 -0.049997         -0.037825
# run_4_dsr                         -0.039821  0.089790         -0.037070
# run_5_raw_post_race_rating_int     0.059434 -0.135654         -0.035205
# run_5_final_rating_int             0.045566 -0.117938         -0.019540
# run_5_win_lose                     0.020448 -0.032773         -0.038720
# run_5_dsr                         -0.033387  0.086170         -0.038367
# run_6_raw_post_race_rating_int     0.050825 -0.135543         -0.027683
# run_6_final_rating_int             0.036706 -0.119060         -0.012077
# run_6_win_lose                     0.021012 -0.026534         -0.037534
# run_6_dsr                         -0.028699  0.076430         -0.035202
# run_7_raw_post_race_rating_int     0.043906 -0.124084         -0.016134
# run_7_final_rating_int             0.030440 -0.107020         -0.001121
# run_7_win_lose                     0.004635 -0.020119         -0.030189
# run_7_dsr                         -0.029162  0.072686         -0.028848
# run_8_raw_post_race_rating_int     0.039158 -0.113229         -0.009360
# run_8_final_rating_int             0.025939 -0.097121          0.004365
# run_8_win_lose                     0.011778 -0.025814         -0.033844
# run_8_dsr                         -0.029053  0.067067         -0.027229
#
#                                 handicap_weight  jockey_id  tainer_id  \
# meeting_id                             0.121486   0.174963   0.150070
# event_number                           0.062120   0.008755   0.012989
# distance                               0.067591   0.024462  -0.002897
# distance_raw_furlongs                  0.067645   0.024536  -0.002900
# total_prize_money                      0.034728  -0.058396  -0.019563
# barrier                               -0.618917   0.008948   0.024261
# number                                -0.618917   0.008948   0.024261
# finish_position                       -0.097328   0.008811   0.021196
# win_or_lose                            0.065825  -0.020822  -0.016587
# margin                                -0.095312  -0.007085   0.032129
# jockey_allowance                      -0.083961   0.326552   0.037981
# handicap_weight                        1.000000   0.004298  -0.025712
# jockey_id                              0.004298   1.000000   0.051127
# tainer_id                             -0.025712   0.051127   1.000000
# dslr                                  -0.007553  -0.025132   0.008687
# horse_id                               0.023606   0.070352   0.116497
# age                                    0.080431   0.080596   0.032818
# official rating                        0.429345  -0.136808  -0.099766
# wfa                                   -0.166750  -0.005566  -0.005434
# weight_adjustment                     -1.000000  -0.004298   0.025712
# bet365_odds                           -0.140792   0.001799   0.057641
# pmu_odds                                    NaN        NaN        NaN
# betfair_starting_price                -0.149921   0.011944   0.055666
# pre_race_master_rating_int             0.077966  -0.071347  -0.069679
# post_race_master_rating_int            0.146470  -0.021046  -0.016507
# starting_price                        -0.164545   0.019949   0.068697
# run_1_raw_post_race_rating_int         0.301479  -0.062130  -0.058375
# run_1_final_rating_int                 0.037375  -0.066554  -0.052727
# run_1_win_lose                         0.111156  -0.024405  -0.016612
# run_1_dsr                             -0.007542  -0.025189   0.008712
# run_2_raw_post_race_rating_int         0.309311  -0.058082  -0.056020
# run_2_final_rating_int                 0.042816  -0.062589  -0.049875
# run_2_win_lose                         0.099883  -0.032545  -0.020859
# run_2_dsr                             -0.008209  -0.026861   0.010372
# run_3_raw_post_race_rating_int         0.310813  -0.052756  -0.052941
# run_3_final_rating_int                 0.040946  -0.056995  -0.045716
# run_3_win_lose                         0.094791  -0.026190  -0.026679
# run_3_dsr                              0.001939  -0.031589   0.012814
# run_4_raw_post_race_rating_int         0.315131  -0.043419  -0.041950
# run_4_final_rating_int                 0.042198  -0.046750  -0.034124
# run_4_win_lose                         0.094291  -0.036982  -0.024422
# run_4_dsr                              0.013872  -0.034552   0.013433
# run_5_raw_post_race_rating_int         0.315499  -0.037190  -0.034498
# run_5_final_rating_int                 0.042622  -0.040334  -0.026909
# run_5_win_lose                         0.095860  -0.026437  -0.021638
# run_5_dsr                              0.022735  -0.035847   0.013812
# run_6_raw_post_race_rating_int         0.304987  -0.023524  -0.023806
# run_6_final_rating_int                 0.031051  -0.027027  -0.016670
# run_6_win_lose                         0.090296  -0.029852  -0.014148
# run_6_dsr                              0.030657  -0.032149   0.013716
# run_7_raw_post_race_rating_int         0.305920  -0.019993  -0.018824
# run_7_final_rating_int                 0.031146  -0.023103  -0.011540
# run_7_win_lose                         0.089051  -0.027416  -0.015078
# run_7_dsr                              0.032773  -0.029529   0.013480
# run_8_raw_post_race_rating_int         0.303966  -0.007089  -0.016944
# run_8_final_rating_int                 0.029003  -0.011654  -0.010158
# run_8_win_lose                         0.091818  -0.022032  -0.017298
# run_8_dsr                              0.036092  -0.026865   0.016717
#
#                                     dslr  horse_id       age  official rating  \
# meeting_id                     -0.039699  0.561333  0.004683        -0.124925
# event_number                   -0.004398 -0.114050  0.178931        -0.085134
# distance                       -0.017801 -0.074598  0.332514        -0.003907
# distance_raw_furlongs          -0.017876 -0.074760  0.332626        -0.003555
# total_prize_money              -0.032499 -0.026986  0.035043         0.479981
# barrier                         0.007179 -0.006529  0.008127        -0.341428
# number                          0.007179 -0.006529  0.008127        -0.341428
# finish_position                 0.061288 -0.045023  0.044504        -0.073075
# win_or_lose                    -0.038894  0.013883 -0.030934         0.076787
# margin                          0.082121  0.031344 -0.034691        -0.109376
# jockey_allowance               -0.023588 -0.080334  0.157477        -0.132629
# handicap_weight                -0.007553  0.023606  0.080431         0.429345
# jockey_id                      -0.025132  0.070352  0.080596        -0.136808
# tainer_id                       0.008687  0.116497  0.032818        -0.099766
# dslr                            1.000000 -0.059486  0.094504         0.015164
# horse_id                       -0.059486  1.000000 -0.342434        -0.129496
# age                             0.094504 -0.342434  1.000000        -0.033624
# official rating                 0.015164 -0.129496 -0.033624         1.000000
# wfa                            -0.038960  0.052994 -0.224184        -0.026082
# weight_adjustment               0.007553 -0.023606 -0.080431        -0.429345
# bet365_odds                     0.065199  0.111428 -0.068824        -0.185344
# pmu_odds                             NaN       NaN       NaN              NaN
# betfair_starting_price          0.064083  0.100247 -0.087740        -0.167059
# pre_race_master_rating_int      0.015084 -0.197595  0.112142         0.751970
# post_race_master_rating_int    -0.023813 -0.035476  0.006325         0.618022
# starting_price                  0.080415  0.113669 -0.061139        -0.196922
# run_1_raw_post_race_rating_int -0.022195 -0.054744  0.084801         0.706389
# run_1_final_rating_int         -0.022394 -0.068348  0.078983         0.601992
# run_1_win_lose                 -0.026124  0.017545 -0.034864         0.222927
# run_1_dsr                       0.999708 -0.059532  0.094565         0.015066
# run_2_raw_post_race_rating_int  0.030898 -0.048919  0.129450         0.707139
# run_2_final_rating_int          0.032570 -0.062609  0.127999         0.602232
# run_2_win_lose                  0.015820  0.007766 -0.024817         0.264462
# run_2_dsr                       0.693065 -0.079750  0.132008         0.010121
# run_3_raw_post_race_rating_int  0.036545 -0.045189  0.171062         0.681259
# run_3_final_rating_int          0.035688 -0.057996  0.172864         0.574471
# run_3_win_lose                  0.021125  0.000295 -0.009780         0.272361
# run_3_dsr                       0.565466 -0.091792  0.171944         0.021677
# run_4_raw_post_race_rating_int  0.027500 -0.044293  0.209247         0.641008
# run_4_final_rating_int          0.025462 -0.056542  0.213337         0.530897
# run_4_win_lose                  0.018365 -0.006640  0.000766         0.265854
# run_4_dsr                       0.503293 -0.099009  0.204712         0.025239
# run_5_raw_post_race_rating_int  0.032697 -0.053960  0.249538         0.607220
# run_5_final_rating_int          0.029769 -0.065419  0.255216         0.495415
# run_5_win_lose                  0.008599 -0.013810  0.016798         0.255809
# run_5_dsr                       0.465594 -0.106449  0.233643         0.030438
# run_6_raw_post_race_rating_int  0.031739 -0.060753  0.285844         0.578044
# run_6_final_rating_int          0.027646 -0.071227  0.290763         0.462771
# run_6_win_lose                  0.014346 -0.023877  0.027193         0.243652
# run_6_dsr                       0.445971 -0.111447  0.257380         0.035087
# run_7_raw_post_race_rating_int  0.027436 -0.066802  0.311311         0.554231
# run_7_final_rating_int          0.023370 -0.077987  0.318014         0.436595
# run_7_win_lose                  0.013315 -0.027802  0.032955         0.232331
# run_7_dsr                       0.426791 -0.118044  0.280719         0.038244
# run_8_raw_post_race_rating_int  0.025472 -0.070646  0.330570         0.531968
# run_8_final_rating_int          0.020729 -0.082319  0.338453         0.411357
# run_8_win_lose                  0.016399 -0.029017  0.036091         0.221381
# run_8_dsr                       0.405799 -0.125093  0.301979         0.046961
#
#                                      wfa  weight_adjustment  bet365_odds  \
# meeting_id                      0.004118          -0.121486    -0.059606
# event_number                   -0.030180          -0.062120    -0.139571
# distance                       -0.110764          -0.067591    -0.114332
# distance_raw_furlongs          -0.110646          -0.067645    -0.114308
# total_prize_money              -0.030344          -0.034728    -0.034171
# barrier                         0.116651           0.618917     0.153659
# number                          0.116651           0.618917     0.153659
# finish_position                 0.004167           0.097328     0.328700
# win_or_lose                    -0.006867          -0.065825    -0.140395
# margin                          0.009919           0.095312     0.383296
# jockey_allowance               -0.017497           0.083961     0.041751
# handicap_weight                -0.166750          -1.000000    -0.140792
# jockey_id                      -0.005566          -0.004298     0.001799
# tainer_id                      -0.005434           0.025712     0.057641
# dslr                           -0.038960           0.007553     0.065199
# horse_id                        0.052994          -0.023606     0.111428
# age                            -0.224184          -0.080431    -0.068824
# official rating                -0.026082          -0.429345    -0.185344
# wfa                             1.000000           0.166750     0.015855
# weight_adjustment               0.166750           1.000000     0.140792
# bet365_odds                     0.015855           0.140792     1.000000
# pmu_odds                             NaN                NaN          NaN
# betfair_starting_price          0.029001           0.149921     0.900991
# pre_race_master_rating_int     -0.059935          -0.077966    -0.384681
# post_race_master_rating_int    -0.021524          -0.146470    -0.111051
# starting_price                  0.022050           0.164545     0.915662
# run_1_raw_post_race_rating_int -0.056694          -0.301479    -0.337499
# run_1_final_rating_int         -0.067537          -0.037375    -0.313998
# run_1_win_lose                 -0.011626          -0.111156    -0.138953
# run_1_dsr                      -0.038961           0.007542     0.065785
# run_2_raw_post_race_rating_int -0.063297          -0.309311    -0.293189
# run_2_final_rating_int         -0.074359          -0.042816    -0.266765
# run_2_win_lose                 -0.008157          -0.099883    -0.114867
# run_2_dsr                      -0.058265           0.008209     0.108464
# run_3_raw_post_race_rating_int -0.093489          -0.310813    -0.266578
# run_3_final_rating_int         -0.105737          -0.040946    -0.238401
# run_3_win_lose                 -0.012553          -0.094791    -0.093033
# run_3_dsr                      -0.070565          -0.001939     0.145345
# run_4_raw_post_race_rating_int -0.124024          -0.315131    -0.248683
# run_4_final_rating_int         -0.137539          -0.042198    -0.218898
# run_4_win_lose                 -0.015633          -0.094291    -0.075350
# run_4_dsr                      -0.081707          -0.013872     0.139753
# run_5_raw_post_race_rating_int -0.138338          -0.315499    -0.234518
# run_5_final_rating_int         -0.152621          -0.042622    -0.203259
# run_5_win_lose                 -0.013335          -0.095860    -0.063036
# run_5_dsr                      -0.093106          -0.022735     0.127465
# run_6_raw_post_race_rating_int -0.154094          -0.304987    -0.222643
# run_6_final_rating_int         -0.168647          -0.031051    -0.192479
# run_6_win_lose                 -0.018095          -0.090296    -0.051942
# run_6_dsr                      -0.101358          -0.030657     0.118862
# run_7_raw_post_race_rating_int -0.161178          -0.305920    -0.212652
# run_7_final_rating_int         -0.176000          -0.031146    -0.181245
# run_7_win_lose                 -0.021049          -0.089051    -0.038823
# run_7_dsr                      -0.108248          -0.032773     0.114828
# run_8_raw_post_race_rating_int -0.161667          -0.303966    -0.199198
# run_8_final_rating_int         -0.176741          -0.029003    -0.167802
# run_8_win_lose                 -0.023963          -0.091818    -0.036714
# run_8_dsr                      -0.112399          -0.036092     0.105714
#
#                                 pmu_odds  betfair_starting_price  \
# meeting_id                           NaN               -0.042160
# event_number                         NaN               -0.149009
# distance                             NaN               -0.123638
# distance_raw_furlongs                NaN               -0.123621
# total_prize_money                    NaN               -0.038857
# barrier                              NaN                0.143498
# number                               NaN                0.143498
# finish_position                      NaN                0.325145
# win_or_lose                          NaN               -0.133245
# margin                               NaN                0.390231
# jockey_allowance                     NaN                0.039115
# handicap_weight                      NaN               -0.149921
# jockey_id                            NaN                0.011944
# tainer_id                            NaN                0.055666
# dslr                                 NaN                0.064083
# horse_id                             NaN                0.100247
# age                                  NaN               -0.087740
# official rating                      NaN               -0.167059
# wfa                                  NaN                0.029001
# weight_adjustment                    NaN                0.149921
# bet365_odds                          NaN                0.900991
# pmu_odds                             NaN                     NaN
# betfair_starting_price               NaN                1.000000
# pre_race_master_rating_int           NaN               -0.381383
# post_race_master_rating_int          NaN               -0.137736
# starting_price                       NaN                0.900110
# run_1_raw_post_race_rating_int       NaN               -0.328753
# run_1_final_rating_int               NaN               -0.304941
# run_1_win_lose                       NaN               -0.130174
# run_1_dsr                            NaN                0.064408
# run_2_raw_post_race_rating_int       NaN               -0.297314
# run_2_final_rating_int               NaN               -0.272289
# run_2_win_lose                       NaN               -0.109318
# run_2_dsr                            NaN                0.100463
# run_3_raw_post_race_rating_int       NaN               -0.274150
# run_3_final_rating_int               NaN               -0.248529
# run_3_win_lose                       NaN               -0.087446
# run_3_dsr                            NaN                0.130294
# run_4_raw_post_race_rating_int       NaN               -0.260355
# run_4_final_rating_int               NaN               -0.233783
# run_4_win_lose                       NaN               -0.072240
# run_4_dsr                            NaN                0.123686
# run_5_raw_post_race_rating_int       NaN               -0.251575
# run_5_final_rating_int               NaN               -0.224737
# run_5_win_lose                       NaN               -0.059583
# run_5_dsr                            NaN                0.108848
# run_6_raw_post_race_rating_int       NaN               -0.243558
# run_6_final_rating_int               NaN               -0.217155
# run_6_win_lose                       NaN               -0.051044
# run_6_dsr                            NaN                0.097552
# run_7_raw_post_race_rating_int       NaN               -0.234141
# run_7_final_rating_int               NaN               -0.207072
# run_7_win_lose                       NaN               -0.040887
# run_7_dsr                            NaN                0.090451
# run_8_raw_post_race_rating_int       NaN               -0.218019
# run_8_final_rating_int               NaN               -0.190935
# run_8_win_lose                       NaN               -0.036709
# run_8_dsr                            NaN                0.081198
#
#                                 pre_race_master_rating_int  \
# meeting_id                                       -0.063983
# event_number                                      0.046762
# distance                                          0.111031
# distance_raw_furlongs                             0.111325
# total_prize_money                                 0.402358
# barrier                                          -0.080173
# number                                           -0.080173
# finish_position                                  -0.184166
# win_or_lose                                       0.134617
# margin                                           -0.260561
# jockey_allowance                                 -0.035756
# handicap_weight                                   0.077966
# jockey_id                                        -0.071347
# tainer_id                                        -0.069679
# dslr                                              0.015084
# horse_id                                         -0.197595
# age                                               0.112142
# official rating                                   0.751970
# wfa                                              -0.059935
# weight_adjustment                                -0.077966
# bet365_odds                                      -0.384681
# pmu_odds                                               NaN
# betfair_starting_price                           -0.381383
# pre_race_master_rating_int                        1.000000
# post_race_master_rating_int                       0.528789
# starting_price                                   -0.414123
# run_1_raw_post_race_rating_int                    0.735289
# run_1_final_rating_int                            0.751099
# run_1_win_lose                                    0.243905
# run_1_dsr                                         0.015000
# run_2_raw_post_race_rating_int                    0.664753
# run_2_final_rating_int                            0.679727
# run_2_win_lose                                    0.241436
# run_2_dsr                                        -0.088020
# run_3_raw_post_race_rating_int                    0.615188
# run_3_final_rating_int                            0.628745
# run_3_win_lose                                    0.229868
# run_3_dsr                                        -0.116362
# run_4_raw_post_race_rating_int                    0.576839
# run_4_final_rating_int                            0.589393
# run_4_win_lose                                    0.211572
# run_4_dsr                                        -0.115282
# run_5_raw_post_race_rating_int                    0.551101
# run_5_final_rating_int                            0.562299
# run_5_win_lose                                    0.201994
# run_5_dsr                                        -0.102161
# run_6_raw_post_race_rating_int                    0.526601
# run_6_final_rating_int                            0.535667
# run_6_win_lose                                    0.188212
# run_6_dsr                                        -0.087012
# run_7_raw_post_race_rating_int                    0.506825
# run_7_final_rating_int                            0.514241
# run_7_win_lose                                    0.178631
# run_7_dsr                                        -0.075278
# run_8_raw_post_race_rating_int                    0.487451
# run_8_final_rating_int                            0.492777
# run_8_win_lose                                    0.162831
# run_8_dsr                                        -0.062327
#
#                                 post_race_master_rating_int  starting_price  \
# meeting_id                                        -0.016391        0.003524
# event_number                                      -0.004168       -0.135181
# distance                                           0.029601       -0.112486
# distance_raw_furlongs                              0.029680       -0.112436
# total_prize_money                                  0.149952       -0.025357
# barrier                                           -0.115664        0.174824
# number                                            -0.115664        0.174824
# finish_position                                   -0.281531        0.379517
# win_or_lose                                        0.186210       -0.168470
# margin                                            -0.279338        0.416794
# jockey_allowance                                  -0.024998        0.046380
# handicap_weight                                    0.146470       -0.164545
# jockey_id                                         -0.021046        0.019949
# tainer_id                                         -0.016507        0.068697
# dslr                                              -0.023813        0.080415
# horse_id                                          -0.035476        0.113669
# age                                                0.006325       -0.061139
# official rating                                    0.618022       -0.196922
# wfa                                               -0.021524        0.022050
# weight_adjustment                                 -0.146470        0.164545
# bet365_odds                                       -0.111051        0.915662
# pmu_odds                                                NaN             NaN
# betfair_starting_price                            -0.137736        0.900110
# pre_race_master_rating_int                         0.528789       -0.414123
# post_race_master_rating_int                        1.000000       -0.160700
# starting_price                                    -0.160700        1.000000
# run_1_raw_post_race_rating_int                     0.531809       -0.379766
# run_1_final_rating_int                             0.478109       -0.351620
# run_1_win_lose                                     0.124299       -0.161474
# run_1_dsr                                         -0.023839        0.080864
# run_2_raw_post_race_rating_int                     0.476748       -0.326967
# run_2_final_rating_int                             0.421069       -0.295840
# run_2_win_lose                                     0.107727       -0.127928
# run_2_dsr                                         -0.027545        0.121080
# run_3_raw_post_race_rating_int                     0.438356       -0.294282
# run_3_final_rating_int                             0.380204       -0.260981
# run_3_win_lose                                     0.092523       -0.099783
# run_3_dsr                                         -0.022481        0.154065
# run_4_raw_post_race_rating_int                     0.179712       -0.274608
# run_4_final_rating_int                             0.151611       -0.238981
# run_4_win_lose                                     0.081603       -0.080356
# run_4_dsr                                         -0.015122        0.152079
# run_5_raw_post_race_rating_int                     0.421679       -0.256713
# run_5_final_rating_int                             0.351827       -0.219368
# run_5_win_lose                                     0.152084       -0.065655
# run_5_dsr                                         -0.016408        0.141701
# run_6_raw_post_race_rating_int                     0.364934       -0.244240
# run_6_final_rating_int                             0.301658       -0.207637
# run_6_win_lose                                     0.144247       -0.053664
# run_6_dsr                                         -0.003463        0.131834
# run_7_raw_post_race_rating_int                     0.344285       -0.237485
# run_7_final_rating_int                             0.280545       -0.199708
# run_7_win_lose                                     0.130238       -0.039359
# run_7_dsr                                          0.000159        0.125725
# run_8_raw_post_race_rating_int                     0.333469       -0.219866
# run_8_final_rating_int                             0.268816       -0.182512
# run_8_win_lose                                     0.128823       -0.038363
# run_8_dsr                                          0.007813        0.117224
#
#                                 run_1_raw_post_race_rating_int  \
# meeting_id                                           -0.023643
# event_number                                          0.032504
# distance                                              0.129200
# distance_raw_furlongs                                 0.129427
# total_prize_money                                     0.340407
# barrier                                              -0.211725
# number                                               -0.211725
# finish_position                                      -0.233713
# win_or_lose                                           0.172661
# margin                                               -0.265767
# jockey_allowance                                     -0.066128
# handicap_weight                                       0.301479
# jockey_id                                            -0.062130
# tainer_id                                            -0.058375
# dslr                                                 -0.022195
# horse_id                                             -0.054744
# age                                                   0.084801
# official rating                                       0.706389
# wfa                                                  -0.056694
# weight_adjustment                                    -0.301479
# bet365_odds                                          -0.337499
# pmu_odds                                                   NaN
# betfair_starting_price                               -0.328753
# pre_race_master_rating_int                            0.735289
# post_race_master_rating_int                           0.531809
# starting_price                                       -0.379766
# run_1_raw_post_race_rating_int                        1.000000
# run_1_final_rating_int                                0.962568
# run_1_win_lose                                        0.372944
# run_1_dsr                                            -0.022348
# run_2_raw_post_race_rating_int                        0.606894
# run_2_final_rating_int                                0.550797
# run_2_win_lose                                        0.240572
# run_2_dsr                                            -0.038172
# run_3_raw_post_race_rating_int                        0.549663
# run_3_final_rating_int                                0.490005
# run_3_win_lose                                        0.203268
# run_3_dsr                                            -0.030454
# run_4_raw_post_race_rating_int                        0.517057
# run_4_final_rating_int                                0.453514
# run_4_win_lose                                        0.177024
# run_4_dsr                                            -0.012780
# run_5_raw_post_race_rating_int                        0.487702
# run_5_final_rating_int                                0.421820
# run_5_win_lose                                        0.169145
# run_5_dsr                                             0.009287
# run_6_raw_post_race_rating_int                        0.462692
# run_6_final_rating_int                                0.395398
# run_6_win_lose                                        0.154119
# run_6_dsr                                             0.027697
# run_7_raw_post_race_rating_int                        0.454081
# run_7_final_rating_int                                0.384790
# run_7_win_lose                                        0.141044
# run_7_dsr                                             0.039894
# run_8_raw_post_race_rating_int                        0.431160
# run_8_final_rating_int                                0.361027
# run_8_win_lose                                        0.132838
# run_8_dsr                                             0.050141
#
#                                 run_1_final_rating_int  run_1_win_lose  \
# meeting_id                                   -0.057832        0.015891
# event_number                                  0.018560        0.008310
# distance                                      0.122866        0.024538
# distance_raw_furlongs                         0.123089        0.024641
# total_prize_money                             0.353525        0.146200
# barrier                                      -0.046067       -0.106021
# number                                       -0.046067       -0.106021
# finish_position                              -0.215155       -0.140977
# win_or_lose                                   0.161125        0.128492
# margin                                       -0.250802       -0.126628
# jockey_allowance                             -0.047074       -0.028397
# handicap_weight                               0.037375        0.111156
# ...
# run_8_dsr                        0.882926                        0.151465
#
#                                 run_7_final_rating_int  run_7_win_lose  \
# meeting_id                                    0.059623        0.013588
# event_number                                  0.072455        0.001932
# distance                                      0.216627        0.011218
# distance_raw_furlongs                         0.216782        0.011342
# total_prize_money                             0.277671        0.134986
# barrier                                      -0.008844       -0.064129
# number                                       -0.008844       -0.064129
# finish_position                              -0.045365        0.004254
# win_or_lose                                   0.030440        0.004635
# margin                                       -0.107020       -0.020119
# jockey_allowance                             -0.001121       -0.030189
# handicap_weight                               0.031146        0.089051
# jockey_id                                    -0.023103       -0.027416
# tainer_id                                    -0.011540       -0.015078
# dslr                                          0.023370        0.013315
# horse_id                                     -0.077987       -0.027802
# age                                           0.318014        0.032955
# official rating                               0.436595        0.232331
# wfa                                          -0.176000       -0.021049
# weight_adjustment                            -0.031146       -0.089051
# bet365_odds                                  -0.181245       -0.038823
# pmu_odds                                           NaN             NaN
# betfair_starting_price                       -0.207072       -0.040887
# pre_race_master_rating_int                    0.514241        0.178631
# post_race_master_rating_int                   0.280545        0.130238
# starting_price                               -0.199708       -0.039359
# run_1_raw_post_race_rating_int                0.384790        0.141044
# run_1_final_rating_int                        0.406786        0.123510
# run_1_win_lose                                0.027663        0.019418
# run_1_dsr                                     0.023449        0.013494
# run_2_raw_post_race_rating_int                0.406616        0.139352
# run_2_final_rating_int                        0.429414        0.122023
# run_2_win_lose                                0.027776        0.018948
# run_2_dsr                                     0.046575        0.019477
# run_3_raw_post_race_rating_int                0.437898        0.149106
# run_3_final_rating_int                        0.461978        0.131608
# run_3_win_lose                                0.041128        0.029727
# run_3_dsr                                     0.071695        0.027432
# run_4_raw_post_race_rating_int                0.484430        0.157786
# run_4_final_rating_int                        0.509600        0.139857
# run_4_win_lose                                0.048842        0.029898
# run_4_dsr                                     0.097915        0.040878
# run_5_raw_post_race_rating_int                0.528755        0.169120
# run_5_final_rating_int                        0.554911        0.151405
# run_5_win_lose                                0.069384        0.056400
# run_5_dsr                                     0.130311        0.053407
# run_6_raw_post_race_rating_int                0.599992        0.199722
# run_6_final_rating_int                        0.626472        0.182637
# run_6_win_lose                                0.118981        0.112143
# run_6_dsr                                     0.153010        0.059881
# run_7_raw_post_race_rating_int                0.959575        0.318111
# run_7_final_rating_int                        1.000000        0.303423
# run_7_win_lose                                0.303423        1.000000
# run_7_dsr                                     0.149167        0.046773
# run_8_raw_post_race_rating_int                0.609093        0.135211
# run_8_final_rating_int                        0.633377        0.114707
# run_8_win_lose                                0.180094        0.106057
# run_8_dsr                                     0.143966        0.035536
#
#                                 run_7_dsr  run_8_raw_post_race_rating_int  \
# meeting_id                      -0.048260                        0.107522
# event_number                     0.044255                        0.074327
# distance                         0.090391                        0.222585
# distance_raw_furlongs            0.090413                        0.222753
# total_prize_money                0.011674                        0.261698
# barrier                          0.022430                       -0.198338
# number                           0.022430                       -0.198338
# finish_position                  0.063945                       -0.058300
# win_or_lose                     -0.029162                        0.039158
# margin                           0.072686                       -0.113229
# jockey_allowance                -0.028848                       -0.009360
# handicap_weight                  0.032773                        0.303966
# jockey_id                       -0.029529                       -0.007089
# tainer_id                        0.013480                       -0.016944
# dslr                             0.426791                        0.025472
# horse_id                        -0.118044                       -0.070646
# age                              0.280719                        0.330570
# official rating                  0.038244                        0.531968
# wfa                             -0.108248                       -0.161667
# weight_adjustment               -0.032773                       -0.303966
# bet365_odds                      0.114828                       -0.199198
# pmu_odds                              NaN                             NaN
# betfair_starting_price           0.090451                       -0.218019
# pre_race_master_rating_int      -0.075278                        0.487451
# post_race_master_rating_int      0.000159                        0.333469
# starting_price                   0.125725                       -0.219866
# run_1_raw_post_race_rating_int   0.039894                        0.431160
# run_1_final_rating_int           0.035670                        0.370345
# run_1_win_lose                  -0.037576                        0.045875
# run_1_dsr                        0.426867                        0.025662
# run_2_raw_post_race_rating_int   0.066344                        0.463298
# run_2_final_rating_int           0.062831                        0.405240
# run_2_win_lose                  -0.025270                        0.041953
# run_2_dsr                        0.587631                        0.037280
# run_3_raw_post_race_rating_int   0.090445                        0.484711
# run_3_final_rating_int           0.085726                        0.429670
# run_3_win_lose                  -0.013901                        0.052047
# run_3_dsr                        0.701079                        0.060991
# run_4_raw_post_race_rating_int   0.105843                        0.514209
# run_4_final_rating_int           0.101172                        0.458359
# run_4_win_lose                  -0.003236                        0.059124
# run_4_dsr                        0.789249                        0.088513
# run_5_raw_post_race_rating_int   0.123159                        0.554984
# run_5_final_rating_int           0.116456                        0.502052
# run_5_win_lose                   0.016235                        0.073939
# run_5_dsr                        0.862926                        0.114532
# run_6_raw_post_race_rating_int   0.135605                        0.593211
# run_6_final_rating_int           0.127632                        0.540318
# run_6_win_lose                   0.027294                        0.086409
# run_6_dsr                        0.931028                        0.139433
# run_7_raw_post_race_rating_int   0.156042                        0.659956
# run_7_final_rating_int           0.149167                        0.609093
# run_7_win_lose                   0.046773                        0.135211
# run_7_dsr                        1.000000                        0.160137
# run_8_raw_post_race_rating_int   0.160137                        1.000000
# run_8_final_rating_int           0.153268                        0.959560
# run_8_win_lose                   0.063808                        0.312217
# run_8_dsr                        0.940484                        0.157740
#
#                                 run_8_final_rating_int  run_8_win_lose  \
# meeting_id                                    0.078079        0.010708
# event_number                                  0.065553       -0.001294
# distance                                      0.222043        0.009345
# distance_raw_furlongs                         0.222209        0.009461
# total_prize_money                             0.269161        0.127444
# barrier                                      -0.005742       -0.067132
# number                                       -0.005742       -0.067132
# finish_position                              -0.035942       -0.011530
# win_or_lose                                   0.025939        0.011778
# margin                                       -0.097121       -0.025814
# jockey_allowance                              0.004365       -0.033844
# handicap_weight                               0.029003        0.091818
# jockey_id                                    -0.011654       -0.022032
# tainer_id                                    -0.010158       -0.017298
# dslr                                          0.020729        0.016399
# horse_id                                     -0.082319       -0.029017
# age                                           0.338453        0.036091
# official rating                               0.411357        0.221381
# wfa                                          -0.176741       -0.023963
# weight_adjustment                            -0.029003       -0.091818
# bet365_odds                                  -0.167802       -0.036714
# pmu_odds                                           NaN             NaN
# betfair_starting_price                       -0.190935       -0.036709
# pre_race_master_rating_int                    0.492777        0.162831
# post_race_master_rating_int                   0.268816        0.128823
# starting_price                               -0.182512       -0.038363
# run_1_raw_post_race_rating_int                0.361027        0.132838
# run_1_final_rating_int                        0.382298        0.113362
# run_1_win_lose                                0.023835        0.005568
# run_1_dsr                                     0.020910        0.016337
# run_2_raw_post_race_rating_int                0.392141        0.133118
# run_2_final_rating_int                        0.415031        0.113825
# run_2_win_lose                                0.017349        0.017564
# run_2_dsr                                     0.033516        0.022353
# run_3_raw_post_race_rating_int                0.414659        0.137984
# run_3_final_rating_int                        0.439150        0.119324
# run_3_win_lose                                0.028559        0.014183
# run_3_dsr                                     0.055826        0.029050
# run_4_raw_post_race_rating_int                0.447954        0.148394
# run_4_final_rating_int                        0.472274        0.129301
# run_4_win_lose                                0.034071        0.028123
# run_4_dsr                                     0.082864        0.037297
# run_5_raw_post_race_rating_int                0.490454        0.154995
# run_5_final_rating_int                        0.516810        0.135325
# run_5_win_lose                                0.047031        0.031556
# run_5_dsr                                     0.108337        0.050396
# run_6_raw_post_race_rating_int                0.534451        0.165372
# run_6_final_rating_int                        0.560729        0.145105
# run_6_win_lose                                0.063362        0.055067
# run_6_dsr                                     0.132716        0.059485
# run_7_raw_post_race_rating_int                0.605118        0.198498
# run_7_final_rating_int                        0.633377        0.180094
# run_7_win_lose                                0.114707        0.106057
# run_7_dsr                                     0.153268        0.063808
# run_8_raw_post_race_rating_int                0.959560        0.312217
# run_8_final_rating_int                        1.000000        0.295884
# run_8_win_lose                                0.295884        1.000000
# run_8_dsr                                     0.149886        0.051882
#
#                                 run_8_dsr
# meeting_id                      -0.041807
# event_number                     0.050399
# distance                         0.103189
# distance_raw_furlongs            0.103218
# total_prize_money                0.019559
# barrier                          0.020768
# number                           0.020768
# finish_position                  0.061849
# win_or_lose                     -0.029053
# margin                           0.067067
# jockey_allowance                -0.027229
# handicap_weight                  0.036092
# jockey_id                       -0.026865
# tainer_id                        0.016717
# dslr                             0.405799
# horse_id                        -0.125093
# age                              0.301979
# official rating                  0.046961
# wfa                             -0.112399
# weight_adjustment               -0.036092
# bet365_odds                      0.105714
# pmu_odds                              NaN
# betfair_starting_price           0.081198
# pre_race_master_rating_int      -0.062327
# post_race_master_rating_int      0.007813
# starting_price                   0.117224
# run_1_raw_post_race_rating_int   0.050141
# run_1_final_rating_int           0.045601
# run_1_win_lose                  -0.037343
# run_1_dsr                        0.405880
# run_2_raw_post_race_rating_int   0.079786
# run_2_final_rating_int           0.077119
# run_2_win_lose                  -0.021910
# run_2_dsr                        0.561220
# run_3_raw_post_race_rating_int   0.103632
# run_3_final_rating_int           0.100222
# run_3_win_lose                  -0.009707
# run_3_dsr                        0.673619
# run_4_raw_post_race_rating_int   0.119612
# run_4_final_rating_int           0.115384
# run_4_win_lose                   0.001886
# run_4_dsr                        0.757382
# run_5_raw_post_race_rating_int   0.135221
# run_5_final_rating_int           0.129362
# run_5_win_lose                   0.014617
# run_5_dsr                        0.823986
# run_6_raw_post_race_rating_int   0.144686
# run_6_final_rating_int           0.137156
# run_6_win_lose                   0.024742
# run_6_dsr                        0.882926
# run_7_raw_post_race_rating_int   0.151465
# run_7_final_rating_int           0.143966
# run_7_win_lose                   0.035536
# run_7_dsr                        0.940484
# run_8_raw_post_race_rating_int   0.157740
# run_8_final_rating_int           0.149886
# run_8_win_lose                   0.051882
# run_8_dsr                        1.000000

# %%
plt.figure(figsize=(12, 10))  # Ajuste o tamanho da figura conforme necessário
sns.heatmap(correlation_matrix, center=0, cmap='coolwarm', fmt=".2f")
plt.show()

# %%
porcentagem_nan = resultados_jump.isna().mean() * 100

# Filtrar as colunas com mais de 80% de NaN
colunas_com_nan_mais_de_80 = porcentagem_nan[porcentagem_nan > 80]

# Obter os nomes das colunas
nomes_colunas_com_nan_mais_de_80 = colunas_com_nan_mais_de_80.index.tolist()
nomes_colunas_com_nan_mais_de_80
# Out:
# ['failed_to_finish_reason',
#  'pmu_odds',
#  'post_race_master_rating_symbol',
#  'run_1_raw_post_race_rating_symbol',
#  'run_2_raw_post_race_rating_symbol',
#  'run_3_raw_post_race_rating_symbol',
#  'run_4_raw_post_race_rating_symbol',
#  'run_5_raw_post_race_rating_symbol',
#  'run_6_raw_post_race_rating_symbol',
#  'run_7_raw_post_race_rating_symbol',
#  'run_8_raw_post_race_rating_symbol']

# %%
resultados_jump
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-5c5c89576fb9> in <cell line: 1>()
# ----> 1 resultados_jump
#
# NameError: name 'resultados_jump' is not defined

# %%
df_jump = df_jump.drop(columns=['failed_to_finish_reason',
 'pmu_odds',
 'post_race_master_rating_symbol',
 'run_1_raw_post_race_rating_symbol',
 'run_2_raw_post_race_rating_symbol',
 'run_3_raw_post_race_rating_symbol',
 'run_4_raw_post_race_rating_symbol',
 'run_5_raw_post_race_rating_symbol',
 'run_6_raw_post_race_rating_symbol',
 'run_7_raw_post_race_rating_symbol',
 'run_8_raw_post_race_rating_symbol'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ef20eb154519> in <cell line: 1>()
# ----> 1 df_jump = df_jump.drop(columns=['failed_to_finish_reason',
#       2  'pmu_odds',
#       3  'post_race_master_rating_symbol',
#       4  'run_1_raw_post_race_rating_symbol',
#       5  'run_2_raw_post_race_rating_symbol',
#
# NameError: name 'df_jump' is not defined

# %%
df_jump
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5963186d2288> in <cell line: 1>()
# ----> 1 df_jump
#
# NameError: name 'df_jump' is not defined

# %%
'''THIS IS DAVIDS SPACE'''
# Out:
# 'THIS IS DAVIDS SPACE'

# %%
num_nan_per_columns_race = ((resultados_race.isna().sum())/len(resultados_race['starting_price']))*100
pd.set_option("display.max_rows", None, "display.max_columns", None) #show all the lines
num_nan_per_columns_race
# Out:
# meeting_id                             0.000000
# meeting_name                           0.000000
# date                                   0.000000
# country_code                           0.000000
# event_number                           0.000000
# distance                               0.000000
# distance_unit                          0.000000
# distance_furlongs                      0.000000
# distance_raw_furlongs                  0.000000
# race_class                             0.000000
# race_class_normalised                  0.185247
# prize_money_currency                   0.000000
# total_prize_money                      0.000000
# track_condition                        0.000000
# race_type                              0.000000
# track_type                             0.000000
# barrier                                0.000000
# number                                 0.000000
# finish_position                        0.310474
# win_or_lose                            0.000000
# failed_to_finish_reason               99.688415
# margin                                11.245600
# gear                                  72.834649
# jockey_allowance                       0.000000
# jockey_allowance_unit                  0.000000
# handicap_weight                        0.000370
# handicap_weight_unit                   0.000000
# jockey_id                              0.000000
# jockey_name                            0.000000
# tainer_id                              0.000000
# trainer_name                           0.000000
# dslr                                   7.135712
# horse_id                               0.000000
# horse_name                             0.000000
# sire                                   0.000000
# dam                                    0.000000
# age                                    0.000000
# birth_date                             0.000000
# official rating                       20.120040
# wfa                                    0.000000
# weight_adjustment                      0.000000
# bet365_odds                           38.627320
# pmu_odds                             100.000000
# betfair_starting_price                 2.071431
# pre_race_master_rating_int             9.116743
# pre_race_master_rating_symbol         63.408173
# post_race_master_rating_int            0.398281
# post_race_master_rating_symbol        75.647068
# starting_price                         0.000000
# run_1_raw_post_race_rating_int         9.129339
# run_1_raw_post_race_rating_symbol     77.191286
# run_1_final_rating_int                 9.129339
# run_1_race_type                        7.130895
# run_1_race_class_normalised            8.472454
# run_1_race_class                       8.033048
# run_1_track_type                       7.130895
# run_1_win_lose                         7.130895
# run_1_dsr                              7.130895
# run_2_raw_post_race_rating_int        16.489200
# run_2_raw_post_race_rating_symbol     78.718832
# run_2_final_rating_int                16.489200
# run_2_race_type                       13.977252
# run_2_race_class                      15.685969
# run_2_race_class_normalised           15.009448
# run_2_track_type                      13.977252
# run_2_win_lose                        13.977252
# run_2_dsr                             13.977252
# run_3_raw_post_race_rating_int        23.335927
# run_3_raw_post_race_rating_symbol     80.307510
# run_3_final_rating_int                23.335927
# run_3_race_type                       20.417917
# run_3_race_class                      22.395984
# run_3_race_class_normalised           21.529028
# run_3_track_type                      20.417917
# run_3_win_lose                        20.417917
# run_3_dsr                             20.417917
# run_4_raw_post_race_rating_int        29.738061
# run_4_raw_post_race_rating_symbol     81.932126
# run_4_final_rating_int                29.738061
# run_4_race_type                       26.498462
# run_4_race_class                      28.642140
# run_4_race_class_normalised           27.636990
# run_4_track_type                      26.498462
# run_4_win_lose                        26.498462
# run_4_dsr                             26.498462
# run_5_raw_post_race_rating_int        35.488126
# run_5_raw_post_race_rating_symbol     83.467082
# run_5_final_rating_int                35.488496
# run_5_race_type                       32.018080
# run_5_race_class                      34.255863
# run_5_race_class_normalised           33.158090
# run_5_track_type                      32.018080
# run_5_win_lose                        32.018080
# run_5_dsr                             32.018080
# run_6_raw_post_race_rating_int        40.620207
# run_6_raw_post_race_rating_symbol     84.861991
# run_6_final_rating_int                40.620577
# run_6_race_type                       36.958245
# run_6_race_class                      39.231966
# run_6_race_class_normalised           38.087140
# run_6_track_type                      36.958245
# run_6_win_lose                        36.958245
# run_6_dsr                             36.958245
# run_7_raw_post_race_rating_int        45.130970
# run_7_raw_post_race_rating_symbol     86.133526
# run_7_final_rating_int                45.130970
# run_7_race_type                       41.338224
# run_7_race_class                      43.616020
# run_7_race_class_normalised           42.410063
# run_7_track_type                      41.338224
# run_7_win_lose                        41.338224
# run_7_dsr                             41.338224
# run_8_raw_post_race_rating_int        49.166759
# run_8_raw_post_race_rating_symbol     87.275018
# run_8_final_rating_int                49.166759
# run_8_race_type                       45.272869
# run_8_race_class                      47.525471
# run_8_race_class_normalised           46.309140
# run_8_track_type                      45.272869
# run_8_win_lose                        45.272869
# run_8_dsr                             45.272869
# dtype: float64
